# %% [markdown]
# Copyright (c) European Space Agency, 2025.
#
# <small><em>This file is subject to the terms and conditions defined in file 'LICENCE.txt', which is part of this source code package. No part of the package, including this file, may be copied, modified, propagated, or distributed except according to the terms contained in the file ‘LICENCE.txt’.</em></small>
# ***

# %% [markdown]
# # <font color=green> Case Study: X-ray Binary Vela X-1  </font>
# ***
# ## Introduction
# This thread serves as a comprehensive, step-by-step guide illustrating a mini science project leveraging XMM-Newton data. The focal point is the retrieval and processing of data associated with the high-mass X-ray binary Vela X-1, which is composed of a neutron star. Subsequently, the derived spectrum can undergo in depth analysis using pyXspec in accordance with the user's wishes, where if wanted they can apply various models to draw insightful conclusions from the observational data.
#
# Moreover, this thread exemplifies the practical utilization of the XMM-SAS Datalab for research purposes. This platform facilitates a streamlined experience, enabling users to promptly obtain data in their preferred format and conduct comprehensive analyses, all within a unified space. Importantly, this eliminates the need for additional package installations or the inconvenience of navigating between disparate platforms.
#
# On this thread we demonstrate applications of methods such as SAS start-up, reprocessing the ODF to generate concatenated EPIC event lists, extracting ligthcurves, checking for pile-up, and extracting a spectrum which can be used for scientific analysis.
#
# ## Background Information
#
# Vela X-1 is a prominent X-ray binary system located in the Vela constellation. Discovered in the early 1970s by the Uhuru X-ray satellite, however it has been observed by nearly all X-ray observatories even multiple times. This binary system features a pulsar—a rapidly rotating neutron star—as its compact object. The companion star is a massive B-type supergiant, and the system is characterized by the transfer of mass from the companion to the neutron star. As the material from the donor star accretes onto the neutron star's surface, it emits intense X-ray radiation, making Vela X-1 detectable in X-ray observations, while also providing a rich spectrum with various emission lines. The high rate of rotation of the neutron star, combined with the mass transfer process, results in the system's dynamic and variable behavior. Vela X-1's study has contributed valuable insights into the physics of accretion processes, neutron star characteristics, and the evolution of binary systems involving compact objects.
#
# The particular observation we chose is with ObsID of 0841890201. Total exposures are five with 3 EPIC, 0 OM, and 2 RGS. This is a very bright source, hence EPIC-pn exposure is in timing mode, and when processing adjustments such as pile-up correction will be necessary.
#
#
# ## Suggested Further Reading
# * https://doi.org/10.1051/0004-6361/202040272
# * https://heasarc.gsfc.nasa.gov/xanadu/xspec/python/html/index.html
# * https://ui.adsabs.harvard.edu/link_gateway/2023A&A...674A.147D/doi:10.48550/arXiv.2303.09631
# * https://ui.adsabs.harvard.edu/link_gateway/2023ApJ...950..170R/doi:10.48550/arXiv.2302.10953
# * https://ui.adsabs.harvard.edu/abs/2022A%26A...660A..19D/abstract
#
# ## Further Credits
# Special thanks and recognition to [Camille Diez](https://www.camillediez.com/) for sharing her research method, knowledge, and help.
#
# ***

# %% [markdown]
# Import the following libraries listed below:

# %%
from pysas.wrapper import Wrapper as w
import os.path
from os import path
import subprocess
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table
from matplotlib.colors import LogNorm
from matplotlib.ticker import ScalarFormatter  # For formatting axis labels
from xspec import *
import re
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = 'notebook'
import plotly.offline as pyo
pyo.init_notebook_mode(connected=True)
from tools.js9helper import *
from tools.plotLC import *
import shutil
from IPython.display import display, Image
from tools.xspecplot import *
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# * ### SAS start-up

# %% [markdown]
# Use the 'expanduser' function from the 'os.path' module to get the home directory of the current user. The variable 'home' now will contain the path to the home directory of the current user:

# %%
home = os.path.expanduser('~')

# %% [markdown]
# Create the working dircetory where all the files produced along the process can be stroed and accessed easily below. Make sure to save your files inside the `my_workspace` folder for permanent storage, as everything stored outside of this folder will be erased every time the Datalab is closed.

# %%
wdir=f'{home}/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan'

#Check if the working directory exists, and create it if it doesn't
if not os.path.exists(wdir):
    os.makedirs(wdir)

#Change to working directory
os.chdir(wdir)

print(f"Current working directory: {os.getcwd()}")

# %% [markdown]
# Define the path to the CCF files provided as a data volume by Datalabs. Hence the user des not need to download any CCF files nor worry about updates. For more information on how to add them in your Datalabs data volume, please refer to the general guidelines on the ESA Datalabs Help section.

# %%
os.environ['SAS_CCFPATH'] = f'{home}/data/user/pub'

# %% [markdown]
# Before starting, it is a good practice to sun `sasver` to check which SAS variables are defined.

# %%
inargs = []
t = w('sasver', inargs)
t.run()
# Out:
#     XMM-Newton SAS - release and build information
#
#     SAS release: xmmsas_20230412_1735-21.0.0
#     Compiled on: Sun Apr 16 21:03:02 CEST 2023
#     Compiled by: sasbuild@sasbld01n.iuser.lan
#     Platform   : Ubuntu20.04
#
#     SAS-related environment variables set:
#
#
# SAS_DIR        = /usr/local/SAS/xmmsas_20230412_1735
# SAS_PATH       = /usr/local/SAS/xmmsas_20230412_1735
# SAS_CCFPATH    = /home/egulbaha/data/user/pub

# %% [markdown]
# Next, we execute the command `startsas`. The task downloads the ODFs of the odfid the user defines in the working directory defined earlier. Please refer to the [XMM-Newton Science Archive](https://www.cosmos.esa.int/web/xmm-newton/xsa) to search through the catalogue for different observation IDs. We will be working with ODF 0841890201.

# %%
t = w('startsas',['odfid=0841890201'])
t.run()
# Out:
# startsas - WARNING - Executing /usr/local/SAS/xmmsas_20230412_1735/lib/python/pysas/startsas/startsas.py {'odfid': '0841890201', 'workdir': 'pwd', 'sasfiles': 'no', 'sas_ccf': '', 'sas_odf': '', 'level': 'ODF', 'cifbuild_opts': '', 'odfingest_opts': ''}
# WARNING:startsas:Executing /usr/local/SAS/xmmsas_20230412_1735/lib/python/pysas/startsas/startsas.py {'odfid': '0841890201', 'workdir': 'pwd', 'sasfiles': 'no', 'sas_ccf': '', 'sas_odf': '', 'level': 'ODF', 'cifbuild_opts': '', 'odfingest_opts': ''}
# INFO:startsas:LHEASOFT = /usr/local/heasoft-6.30.1/x86_64-pc-linux-gnu-libc2.31
# INFO:startsas:SAS_DIR = /usr/local/SAS/xmmsas_20230412_1735
# INFO:startsas:SAS_CCFPATH = /home/egulbaha/data/user/pub
# INFO:startsas:startsas was initiated from /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan
# INFO:startsas:Will download ODF with level ODF
# INFO:startsas:Requesting odfid  = 0841890201 to XMM-Newton Science Archive
#
# INFO:startsas:Downloading 0841890201, level ODF
# Requesting odfid  = 0841890201 to XMM-Newton Science Archive
#
#
# Downloading 0841890201, level ODF. Please wait ...
#
# Downloading URL http://nxsa.esac.esa.int/nxsa-sl/servlet/data-action-aio?obsno=0841890201&level=ODF to 0841890201.tar.gz ... [Done]
# INFO:startsas:0841890201.tar.gz downloaded.
# INFO:startsas:Creating directory 0841890201 ...
# INFO:startsas:Unpacking 0841890201.tar.gz ...
# Creating directory 0841890201 ...
#
# Unpacking 0841890201.tar.gz ...
# INFO:startsas:0841890201.tar.gz extracted successfully!
# INFO:startsas:0841890201.tar.gz removed
# INFO:startsas:Unpacking 3553_0841890201.TAR ...
# Unpacking 3553_0841890201.TAR ...
# INFO:startsas:3553_0841890201.TAR removed
# INFO:startsas:File MANIFEST.704820 exists
# INFO:startsas:Setting SAS_ODF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/0841890201
# INFO:startsas:Running cifbuild...
# Setting SAS_ODF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/0841890201
#
# Running cifbuild...
# cifbuild:- Executing (routine): cifbuild calindexset=ccf.cif ccfpath=. withccfpath=no usecanonicalname=no recurse=no fileglob=*.ccf|*.CCF fullpath=no observationdate=now withobservationdate=no analysisdate=now category=XMMCCF ignorecategory=no masterindex=no masterindexset=ccf.mif withmasterindexset=no append=no  -w 1 -V 4
# cifbuild:- cifbuild (cifbuild-4.10.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T09:58:10.000
# cifbuild:- Will ask the analysis date to the OAL.
# cifbuild:- Using the ODF 3553_0841890201 found in /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/0841890201
# cifbuild:- Observation date: 2019-05-03T21:14:00.000
# cifbuild:- Analysis date: 2025-01-07T09:58:10.000
# INFO:startsas:CIF file ccf.cif created
# INFO:startsas:Setting SAS_CCF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif
# INFO:startsas:Running odfingest...
# cifbuild:- cifbuild (cifbuild-4.10.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T10:01:07.000
#
# Setting SAS_CCF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif
#
# Running odfingest...
# odfingest:- Executing (routine): odfingest odfdir=. withodfdir=no outdir=. summaryfile=0000_0000000000_SCX000SUM.SAS usecanonicalname=yes writepath=yes findinstrumentmodes=yes usehousekeeping=yes oalcheck=no  -w 1 -V 4
# odfingest:- odfingest (odfingest-3.33.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T10:01:07.000
# odfingest:- Looking for ODF constituents in /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/0841890201/
# odfingest:- Identified the following ODF
# Revolution:  3553
# Observation: 0841890201
# Proposal:    0841890201
# odfingest:- Dataset Time Range: 3553_0841890201_M1S00100AUX.FIT : 2019-05-03T22:15:45.000 - 2019-05-05T05:02:29.000
# odfingest:- Dataset Time Range: 3553_0841890201_M1S00110IME.FIT : 2019-05-03T22:15:45.000 - 2019-05-05T05:02:29.000
# odfingest:- Dataset Time Range: 3553_0841890201_M1S00120IME.FIT : 2019-05-03T22:15:45.000 - 2019-05-05T05:02:29.000
# odfingest:- Dataset Time Range: 3553_0841890201_M1S00140IME.FIT : 2019-05-03T22:15:45.000 - 2019-05-05T05:02:29.000
# odfingest:- Dataset Time Range: 3553_0841890201_M1S00150IME.FIT : 2019-05-03T22:15:45.000 - 2019-05-05T05:02:29.000
# odfingest:- Dataset Time Range: 3553_0841890201_M1S00170IME.FIT : 2019-05-03T22:15:45.000 - 2019-05-05T05:02:29.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_M1S40010DII.FIT : 2019-05-03T21:31:47.000 - 2019-05-03T21:31:48.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_M1S40110DII.FIT : 2019-05-03T21:40:24.000 - 2019-05-03T21:40:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_M1S40210DII.FIT : 2019-05-03T21:49:02.000 - 2019-05-03T21:49:03.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_M1S40310DII.FIT : 2019-05-03T21:57:41.000 - 2019-05-03T21:57:42.000
# odfingest:- Dataset Time Range: 3553_0841890201_M2S00200AUX.FIT : 2019-05-03T21:32:23.000 - 2019-05-05T05:00:01.000
# odfingest:- Dataset Time Range: 3553_0841890201_M2S00200CCX.FIT : 2019-05-03T21:32:23.000 - 2019-05-05T05:00:01.000
# odfingest:- Dataset Time Range: 3553_0841890201_M2S00210TIE.FIT : 2019-05-03T21:32:23.000 - 2019-05-05T05:00:01.000
# odfingest:- Dataset Time Range: 3553_0841890201_M2S00220IME.FIT : 2019-05-03T21:32:23.000 - 2019-05-05T05:00:01.000
# odfingest:- Dataset Time Range: 3553_0841890201_M2S00230IME.FIT : 2019-05-03T21:32:23.000 - 2019-05-05T05:00:01.000
# odfingest:- Dataset Time Range: 3553_0841890201_M2S00240IME.FIT : 2019-05-03T21:32:23.000 - 2019-05-05T05:00:01.000
# odfingest:- Dataset Time Range: 3553_0841890201_M2S00250IME.FIT : 2019-05-03T21:32:23.000 - 2019-05-05T05:00:01.000
# odfingest:- Dataset Time Range: 3553_0841890201_M2S00260IME.FIT : 2019-05-03T21:32:23.000 - 2019-05-05T05:00:01.000
# odfingest:- Dataset Time Range: 3553_0841890201_M2S00270IME.FIT : 2019-05-03T21:32:23.000 - 2019-05-05T05:00:01.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02000E6I.FIT : 2019-05-03T21:53:06.000 - 2019-05-03T21:56:18.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02000WDX.FIT : 2019-05-03T21:53:06.000 - 2019-05-03T21:56:18.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02001E6I.FIT : 2019-05-03T21:53:06.000 - 2019-05-03T21:56:18.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02100E4I.FIT : 2019-05-03T22:19:24.000 - 2019-05-04T01:18:09.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02100WDX.FIT : 2019-05-03T22:19:24.000 - 2019-05-04T01:18:09.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02200E4I.FIT : 2019-05-04T01:41:45.000 - 2019-05-04T04:40:22.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02200WDX.FIT : 2019-05-04T01:41:45.000 - 2019-05-04T04:40:22.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02300E4I.FIT : 2019-05-04T05:04:07.000 - 2019-05-04T08:02:52.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02300WDX.FIT : 2019-05-04T05:04:07.000 - 2019-05-04T08:02:52.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02400E4I.FIT : 2019-05-04T08:26:28.000 - 2019-05-04T11:28:04.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02400WDX.FIT : 2019-05-04T08:26:28.000 - 2019-05-04T11:28:04.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02500E4I.FIT : 2019-05-04T11:51:12.000 - 2019-05-04T14:52:37.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02500WDX.FIT : 2019-05-04T11:51:12.000 - 2019-05-04T14:52:37.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02600E6I.FIT : 2019-05-04T15:15:17.000 - 2019-05-04T15:18:15.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02600WDX.FIT : 2019-05-04T15:15:17.000 - 2019-05-04T15:18:15.000
# odfingest:- Dataset Time Range: 3553_0841890201_OMS02601E6I.FIT : 2019-05-04T15:15:17.000 - 2019-05-04T15:18:15.000
# odfingest:- Dataset Time Range: 3553_0841890201_PNS00300AUX.FIT : 2019-05-03T22:09:45.000 - 2019-05-05T05:04:28.000
# odfingest:- Dataset Time Range: 3553_0841890201_PNS00300CCX.FIT : 2019-05-03T22:09:45.000 - 2019-05-05T05:04:28.000
# odfingest:- Dataset Time Range: 3553_0841890201_PNS00304TIE.FIT : 2019-05-03T22:09:45.000 - 2019-05-05T05:04:28.000
# odfingest:- Dataset Time Range: 3553_0841890201_R1S00400AUX.FIT : 2019-05-03T21:31:24.000 - 2019-05-05T05:08:17.000
# odfingest:- Dataset Time Range: 3553_0841890201_R1S00401SPE.FIT : 2019-05-03T21:31:24.000 - 2019-05-05T05:08:17.000
# odfingest:- Dataset Time Range: 3553_0841890201_R1S00402SPE.FIT : 2019-05-03T21:31:24.000 - 2019-05-05T05:08:17.000
# odfingest:- Dataset Time Range: 3553_0841890201_R1S00403SPE.FIT : 2019-05-03T21:31:24.000 - 2019-05-05T05:08:17.000
# odfingest:- Dataset Time Range: 3553_0841890201_R1S00404SPE.FIT : 2019-05-03T21:31:24.000 - 2019-05-05T05:08:17.000
# odfingest:- Dataset Time Range: 3553_0841890201_R1S00405SPE.FIT : 2019-05-03T21:31:24.000 - 2019-05-05T05:08:17.000
# odfingest:- Dataset Time Range: 3553_0841890201_R1S00406SPE.FIT : 2019-05-03T21:31:24.000 - 2019-05-05T05:08:17.000
# odfingest:- Dataset Time Range: 3553_0841890201_R1S00408SPE.FIT : 2019-05-03T21:31:24.000 - 2019-05-05T05:08:17.000
# odfingest:- Dataset Time Range: 3553_0841890201_R1S00409SPE.FIT : 2019-05-03T21:31:24.000 - 2019-05-05T05:08:17.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S90001DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S90102DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S90203DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S90304DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S90405DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S90506DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S90608DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S90709DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S90801DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S90902DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S91003DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S91104DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S91205DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S91306DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S91408DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S91509DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S91601DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S91702DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S91803DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S91904DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S92005DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S92106DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S92208DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S92309DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S92401DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S92502DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S92603DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S92704DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S92805DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S92906DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S93008DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S93109DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S93201DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S93302DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S93403DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S93504DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S93605DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S93706DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S93808DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S93909DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S94001DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S94102DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S94203DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S94304DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S94405DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S94506DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S94608DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S94709DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S94801DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S94902DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S95003DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S95104DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S95205DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S95306DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S95408DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S95509DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S95601DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S95702DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S95803DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S95904DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S96005DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S96106DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S96208DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S96309DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S96401DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S96502DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S96603DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S96704DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S96805DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S96906DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S97008DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S97109DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S97201DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S97302DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R1S97403DII.FIT : 2019-05-03T21:31:24.000 - 2019-05-03T21:31:25.000
# odfingest:- Dataset Time Range: 3553_0841890201_R2S00500AUX.FIT : 2019-05-03T21:31:32.000 - 2019-05-05T05:08:19.000
# odfingest:- Dataset Time Range: 3553_0841890201_R2S00501SPE.FIT : 2019-05-03T21:31:32.000 - 2019-05-05T05:08:19.000
# odfingest:- Dataset Time Range: 3553_0841890201_R2S00502SPE.FIT : 2019-05-03T21:31:32.000 - 2019-05-05T05:08:19.000
# odfingest:- Dataset Time Range: 3553_0841890201_R2S00503SPE.FIT : 2019-05-03T21:31:32.000 - 2019-05-05T05:08:19.000
# odfingest:- Dataset Time Range: 3553_0841890201_R2S00505SPE.FIT : 2019-05-03T21:31:32.000 - 2019-05-05T05:08:19.000
# odfingest:- Dataset Time Range: 3553_0841890201_R2S00506SPE.FIT : 2019-05-03T21:31:32.000 - 2019-05-05T05:08:19.000
# odfingest:- Dataset Time Range: 3553_0841890201_R2S00507SPE.FIT : 2019-05-03T21:31:32.000 - 2019-05-05T05:08:19.000
# odfingest:- Dataset Time Range: 3553_0841890201_R2S00508SPE.FIT : 2019-05-03T21:31:32.000 - 2019-05-05T05:08:19.000
# odfingest:- Dataset Time Range: 3553_0841890201_R2S00509SPE.FIT : 2019-05-03T21:31:32.000 - 2019-05-05T05:08:19.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S90001DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S90102DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S90203DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S90305DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S90406DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S90507DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S90608DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S90709DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S90801DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S90902DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S91003DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S91105DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S91206DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S91307DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S91408DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S91509DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S91601DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S91702DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S91803DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S91905DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S92006DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S92107DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S92208DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S92309DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Detected a data set with data mode 5 [Diagnostic]. This is know to contain the wrong DATE-END. I'm assigning to it an arbitrary duration of 1 second.
# odfingest:- Dataset Time Range: 3553_0841890201_R2S92401DII.FIT : 2019-05-03T21:31:32.000 - 2019-05-03T21:31:33.000
# odfingest:- Dataset Time Range: 3553_0841890201_PNU20104ODI.FIT : 2019-05-03T22:09:11.000 - 2019-05-03T22:09:37.000
# odfingest:- Observation Time Range: 2019-05-03T21:31:24.000 - 2019-05-05T05:08:19.000
# odfingest:- M1/S001 start = 2019-05-03T22:15:45.000 end = 2019-05-05T05:02:29.000
# odfingest:- M1/S001 start = 2019-05-03T22:15:45.000 end = 2019-05-05T05:02:29.000
# odfingest:- M1/S001 start = 2019-05-03T22:15:45.000 end = 2019-05-05T05:02:29.000
# odfingest:- M1/S001 start = 2019-05-03T22:15:45.000 end = 2019-05-05T05:02:29.000
# odfingest:- M1/S001 start = 2019-05-03T22:15:45.000 end = 2019-05-05T05:02:29.000
# odfingest:- M1/S001 start = 2019-05-03T22:15:45.000 end = 2019-05-05T05:02:29.000
# odfingest:- M1/S400 start = 2019-05-03T21:31:47.000 end = 2019-05-03T21:31:48.000
# odfingest:- M1/S401 start = 2019-05-03T21:40:24.000 end = 2019-05-03T21:40:25.000
# odfingest:- M1/S402 start = 2019-05-03T21:49:02.000 end = 2019-05-03T21:49:03.000
# odfingest:- M1/S403 start = 2019-05-03T21:57:41.000 end = 2019-05-03T21:57:42.000
# odfingest:- M2/S002 start = 2019-05-03T21:32:23.000 end = 2019-05-05T05:00:01.000
# odfingest:- M2/S002 start = 2019-05-03T21:32:23.000 end = 2019-05-05T05:00:01.000
# odfingest:- M2/S002 start = 2019-05-03T21:32:23.000 end = 2019-05-05T05:00:01.000
# odfingest:- M2/S002 start = 2019-05-03T21:32:23.000 end = 2019-05-05T05:00:01.000
# odfingest:- M2/S002 start = 2019-05-03T21:32:23.000 end = 2019-05-05T05:00:01.000
# odfingest:- M2/S002 start = 2019-05-03T21:32:23.000 end = 2019-05-05T05:00:01.000
# odfingest:- M2/S002 start = 2019-05-03T21:32:23.000 end = 2019-05-05T05:00:01.000
# odfingest:- M2/S002 start = 2019-05-03T21:32:23.000 end = 2019-05-05T05:00:01.000
# odfingest:- M2/S002 start = 2019-05-03T21:32:23.000 end = 2019-05-05T05:00:01.000
# odfingest:- R1/S004 start = 2019-05-03T21:31:24.000 end = 2019-05-05T05:08:17.000
# odfingest:- R1/S004 start = 2019-05-03T21:31:24.000 end = 2019-05-05T05:08:17.000
# odfingest:- R1/S004 start = 2019-05-03T21:31:24.000 end = 2019-05-05T05:08:17.000
# odfingest:- R1/S004 start = 2019-05-03T21:31:24.000 end = 2019-05-05T05:08:17.000
# odfingest:- R1/S004 start = 2019-05-03T21:31:24.000 end = 2019-05-05T05:08:17.000
# odfingest:- R1/S004 start = 2019-05-03T21:31:24.000 end = 2019-05-05T05:08:17.000
# odfingest:- R1/S004 start = 2019-05-03T21:31:24.000 end = 2019-05-05T05:08:17.000
# odfingest:- R1/S004 start = 2019-05-03T21:31:24.000 end = 2019-05-05T05:08:17.000
# odfingest:- R1/S004 start = 2019-05-03T21:31:24.000 end = 2019-05-05T05:08:17.000
# odfingest:- R1/S900 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S901 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S902 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S903 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S904 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S905 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S906 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S907 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S908 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S909 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S910 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S911 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S912 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S913 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S914 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S915 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S916 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S917 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S918 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S919 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S920 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S921 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S922 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S923 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S924 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S925 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S926 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S927 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S928 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S929 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S930 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S931 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S932 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S933 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S934 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S935 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S936 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S937 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S938 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S939 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S940 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S941 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S942 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S943 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S944 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S945 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S946 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S947 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S948 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S949 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S950 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S951 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S952 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S953 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S954 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S955 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S956 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S957 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S958 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S959 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S960 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S961 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S962 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S963 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S964 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S965 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S966 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S967 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S968 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S969 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S970 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S971 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S972 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S973 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S974 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R2/S005 start = 2019-05-03T21:31:32.000 end = 2019-05-05T05:08:19.000
# odfingest:- R2/S005 start = 2019-05-03T21:31:32.000 end = 2019-05-05T05:08:19.000
# odfingest:- R2/S005 start = 2019-05-03T21:31:32.000 end = 2019-05-05T05:08:19.000
# odfingest:- R2/S005 start = 2019-05-03T21:31:32.000 end = 2019-05-05T05:08:19.000
# odfingest:- R2/S005 start = 2019-05-03T21:31:32.000 end = 2019-05-05T05:08:19.000
# odfingest:- R2/S005 start = 2019-05-03T21:31:32.000 end = 2019-05-05T05:08:19.000
# odfingest:- R2/S005 start = 2019-05-03T21:31:32.000 end = 2019-05-05T05:08:19.000
# odfingest:- R2/S005 start = 2019-05-03T21:31:32.000 end = 2019-05-05T05:08:19.000
# odfingest:- R2/S005 start = 2019-05-03T21:31:32.000 end = 2019-05-05T05:08:19.000
# odfingest:- R2/S900 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# ...
# odfingest:- R1/S919 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S919 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S920 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S920 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S921 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S921 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S922 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S922 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S923 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S923 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S924 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S924 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S925 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S925 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S926 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S926 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S927 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S927 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S928 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S928 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S929 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S929 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S930 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S930 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S931 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S931 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S932 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S932 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S933 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S933 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S934 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S934 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S935 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S935 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S936 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S936 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S937 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S937 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S938 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S938 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S939 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S939 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S940 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S940 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S941 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S941 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S942 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S942 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S943 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S943 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S944 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S944 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S945 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S945 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S946 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S946 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S947 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S947 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S948 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S948 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S949 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S949 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S950 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S950 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S951 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S951 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S952 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S952 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S953 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S953 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S954 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S954 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S955 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S955 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S956 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S956 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S957 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S957 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S958 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S958 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S959 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S959 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S960 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S960 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S961 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S961 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S962 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S962 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S963 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S963 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S964 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S964 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S965 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S965 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S966 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S966 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S967 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S967 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S968 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S968 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S969 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S969 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S970 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S970 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S971 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S971 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S972 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S972 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S973 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S973 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S974 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R1/S974 start = 2019-05-03T21:31:24.000 end = 2019-05-03T21:31:25.000
# odfingest:- R2/S005 start = 2019-05-03T21:31:32.000 end = 2019-05-05T05:08:19.000
# odfingest:- R2/S005 start = 2019-05-03T21:31:32.000 end = 2019-05-05T05:08:19.000
# odfingest:- R2/S900 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S900 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S901 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S901 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S902 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S902 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S903 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S903 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S904 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S904 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S905 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S905 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S906 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S906 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S907 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S907 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S908 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S908 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S909 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S909 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S910 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S910 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S911 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S911 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S912 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S912 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S913 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S913 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S914 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S914 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S915 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S915 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S916 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S916 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S917 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S917 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S918 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S918 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S919 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S919 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S920 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S920 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S921 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S921 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S922 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S922 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S923 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S923 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S924 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- R2/S924 start = 2019-05-03T21:31:32.000 end = 2019-05-03T21:31:33.000
# odfingest:- PN/S003 start = 2019-05-03T22:09:45.000 end = 2019-05-05T05:04:28.000
# odfingest:- PN/S003 start = 2019-05-03T22:09:45.000 end = 2019-05-05T05:04:28.000
# odfingest:- Summary of the FILTER information for INSTEXP PN/S003 F1120 [ Thin1 ] Potentiometer val [ 112.801 ] F1118 [ FILTRA-THIN1 ] FD130 [ THIN1 ]
# odfingest:- PN/U201 start = 2019-05-03T22:09:11.000 end = 2019-05-03T22:09:37.000
# odfingest:- PN/U201 start = 2019-05-03T22:09:11.000 end = 2019-05-03T22:09:37.000
# odfingest:- OM/S020 start = 2019-05-03T21:54:26.000 end = 2019-05-03T21:54:45.000
# odfingest:- OM/S020 start = 2019-05-03T21:54:26.000 end = 2019-05-03T21:54:45.000
# odfingest:- OM/S021 start = 2019-05-03T22:20:38.000 end = 2019-05-03T23:27:18.000
# odfingest:- OM/S021 start = 2019-05-03T22:20:38.000 end = 2019-05-03T23:27:18.000
# odfingest:- OM/S022 start = 2019-05-04T01:43:04.000 end = 2019-05-04T02:49:42.000
# odfingest:- OM/S022 start = 2019-05-04T01:43:04.000 end = 2019-05-04T02:49:42.000
# odfingest:- OM/S023 start = 2019-05-04T05:05:26.000 end = 2019-05-04T06:12:07.000
# odfingest:- OM/S023 start = 2019-05-04T05:05:26.000 end = 2019-05-04T06:12:07.000
# odfingest:- OM/S024 start = 2019-05-04T08:27:44.000 end = 2019-05-04T09:34:26.000
# odfingest:- OM/S024 start = 2019-05-04T08:27:44.000 end = 2019-05-04T09:34:26.000
# odfingest:- OM/S025 start = 2019-05-04T11:52:25.000 end = 2019-05-04T12:59:05.000
# odfingest:- OM/S025 start = 2019-05-04T11:52:25.000 end = 2019-05-04T12:59:05.000
# INFO:startsas:odfingest successfully completed
# INFO:startsas:SAS summary file 3553_0841890201_SCX00000SUM.SAS created
# INFO:startsas:Setting SAS_ODF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS
# odfingest:- OM/S026 start = 2019-05-04T15:16:26.000 end = 2019-05-04T15:16:45.000
# odfingest:- OM/S026 start = 2019-05-04T15:16:26.000 end = 2019-05-04T15:16:45.000
# odfingest:- odfingest (odfingest-3.33.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T10:01:53.000
#
# Setting SAS_ODF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS
# INFO:startsas:Summary file PATH keyword matches /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/0841890201
# Warning: Summary file PATH keyword matches /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/0841890201
#
#
#
#         SAS_CCF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif
#         SAS_ODF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS

# %% [markdown]
# * ### Running `epproc`

# %%
inargs = [f'sas_ccf={wdir}/ccf.cif', f'sas_odf={wdir}/3553_0841890201_SCX00000SUM.SAS', f'workdir={wdir}']

w('startsas', inargs).run()
# Out:
# startsas - WARNING - Executing /usr/local/SAS/xmmsas_20230412_1735/lib/python/pysas/startsas/startsas.py {'odfid': '', 'workdir': '/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan', 'sasfiles': 'yes', 'sas_ccf': '/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif', 'sas_odf': '/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS', 'level': 'ODF', 'cifbuild_opts': '', 'odfingest_opts': ''}
# WARNING:startsas:Executing /usr/local/SAS/xmmsas_20230412_1735/lib/python/pysas/startsas/startsas.py {'odfid': '', 'workdir': '/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan', 'sasfiles': 'yes', 'sas_ccf': '/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif', 'sas_odf': '/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS', 'level': 'ODF', 'cifbuild_opts': '', 'odfingest_opts': ''}
# INFO:startsas:LHEASOFT = /usr/local/heasoft-6.30.1/x86_64-pc-linux-gnu-libc2.31
# INFO:startsas:SAS_DIR = /usr/local/SAS/xmmsas_20230412_1735
# INFO:startsas:SAS_CCFPATH = /home/egulbaha/data/user/pub
# INFO:startsas:startsas was initiated from /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan
# INFO:startsas:Work directory = /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan
# INFO:startsas:Changed directory to /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan
# INFO:startsas:Will download ODF with level ODF
# INFO:startsas:/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif is present
# INFO:startsas:/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS is present
# INFO:startsas:SAS_CCF = /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif
# INFO:startsas:SAS_ODF = /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS
#         Starting SAS session
#
#         Working directory = /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan
#
#
# SAS_CCF = /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif
# SAS_ODF = /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS

# %% [markdown]
# We will now apply `epproc` for this observation that has been taken in timing mode. Timing mode can be used for very bright sources (such as this observation of Vela X-1), which require a shorter readout time. In timing mode the arrival times of individual X-ray photons are recorded with high precision. Rather than focusing on spatial information, this mode emphasizes the temporal aspects of X-ray events, making it ideal for studying time-dependent phenomena. Timing mode can allow us to extract detailed information about periodicities, rotational periods, and other temporal characteristics, providing insights into the dynamic behavior of Vela X-1. The default intrinsic timing mode calibration settings when running the `epproc` task are shown below:
# ```
# TIMING: withrdpha=“Y”, withxrlcorrection=“Y”, runepreject=“Y”, runepfast=“N”
# ```
# One can change the default calibration settings by adding `withdefaultcal=“N”` as argument of the `epproc` task and set the aforementioned calibration parameters to their own preference. If further information is needed please refer to the thread *How to Reprocess ODFS to Generate Calibrated and Concatenated EPIC Event Lists* and to the Appendix of [Diez et al. (2023)](https://arxiv.org/pdf/2303.09631.pdf) for issues with default calibration settings when in timing mode. For this exercise, we apply the same calibration corrections as in [Diez et al. (2023)](https://arxiv.org/pdf/2303.09631.pdf).

# %%
# SAS Command
cmd    = 'epproc'  # SAS task to be executed

# Arguments of SAS Command, leave empty if you want to run with default calibration settings for timing mode
inargs = ['withdefaultcal=no', 'withrdpha=no', 'runepreject=yes', 'withxrlcorrection=yes', 'runepfast=yes']        #remove arguments for default cal
# comma separated arguments for SAS task

print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    SAS command to be executed: epproc, with arguments;
# ['withdefaultcal=no',
#  'withrdpha=no',
#  'runepreject=yes',
#  'withxrlcorrection=yes',
#  'runepfast=yes']

# %%
print("Running epproc ..... \n")

# Check if epproc has already run. If it has, do not run again 
exists = 0
pnevt_list = []
for root, dirs, files in os.walk("."):
    for filename in files:
        if (filename.find('EPN') != -1) and filename.endswith('TimingEvts.ds'):
            pnevt_list.append(filename)
            exists = 1
if exists:
    print(" > " + str(len(pnevt_list)) + " EPIC-pn event list found. Not running epproc again.\n")
    for x in pnevt_list:
        print("    " + x + "\n")
    print("..... OK")
else:
    w(cmd,inargs).run()      # <<<<< Execute SAS task
    exists = 0
    pnevt_list = []
    for root, dirs, files in os.walk("."):
        for filename in files:
            if (filename.find('EPN') != -1) and filename.endswith('TimingEvts.ds'):
                pnevt_list.append(filename)
                exists = 1
    if exists:
        print(" > " + str(len(pnevt_list)) + " EPIC-pn event list found after running epproc.\n")
        for x in pnevt_list:
            print("    " + x + "\n")
        print("..... OK")
    else:
        print("Something has gone wrong with epproc. I cant find any event list files after running. \n")
# Out:
# Running epproc .....
#
#  > 1 EPIC-pn event list found. Not running epproc again.
#
#     3553_0841890201_EPN_S003_TimingEvts.ds
#
# ..... OK

# %% [markdown]
# * ### Do I need to apply filtering for flaring particle background?

# %% [markdown]
# You do not always need to apply filtering for flaring particle background. In this scenario the source brightness is high enough to not require any filtering, because the flux of the object would be in every case larger than the possible flaring particle background. However, let us demonstrate this is indeed the case for demonstration purposes by inspecting the source and flaring particle background lightcurves.
#
# We define our event file produced n the previous step:

# %%
eventfile = wdir+'/3553_0841890201_EPN_S003_TimingEvts.ds'

# %%
# Define a SAS filter expression to derive a background rate cut

pn_pattern   = 0        # pattern selection
pn_pi_min    = 10000.   # Low energy range eV
pn_pi_max    = 12000.   # High energy range eV
pn_threshold = 0.4      # cts/sec (only used here for display purposes)

out_LCFile   = wdir+'/PN_bkg_nrjthreshold.fits'  # Name of the output BKG lightcurve

# %% [markdown]
# The argument values can be altered depending on the user, these are only display numbers. After observing the produced light curve, the user can either come back and change values above and rerun the kernels or just copy the same kernels with the new values.

# %%
# SAS Command
cmd        = "evselect" # SAS task to be executed                  

# Arguments of SAS Command
expression = f'#XMMEA_EP&&(PI>={pn_pi_min}&&PI<={pn_pi_max})&&(PATTERN=={pn_pattern})'  # event filter expression
inargs     = [f'table={eventfile}','withrateset=Y',f'rateset={out_LCFile}','maketimecolumn=Y','timebinsize=100','makeratecolumn=Y',f'expression={expression}']

print("   Filter expression to use: "+expression+" \n")
print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    Filter expression to use: #XMMEA_EP&&(PI>=10000.0&&PI<=12000.0)&&(PATTERN==0)
#
#    SAS command to be executed: evselect, with arguments;
# ['table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_EPN_S003_TimingEvts.ds',
#  'withrateset=Y',
#  'rateset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_bkg_nrjthreshold.fits',
#  'maketimecolumn=Y',
#  'timebinsize=100',
#  'makeratecolumn=Y',
#  'expression=#XMMEA_EP&&(PI>=10000.0&&PI<=12000.0)&&(PATTERN==0)']

# %%
# %%capture
# Execute SAS task with parameters

w(cmd, inargs).run()

# %%
# Plot BKG lightcurve
name= ["flaring particle background"]
file_paths = [out_LCFile]

# Call the function to plot light curves
plotLC(file_paths, name, threshold = None)

# %%
pn_pi_min    = 150   
out_file = wdir + '/PN_sr_Rthreshold.fits'

# %%
# SAS Command
cmd        = "evselect" # SAS task to be executed                  

# Arguments of SAS Command
expression = f'#XMMEA_EP&&(PI>={pn_pi_min})'  # event filter expression
inargs     = [f'table={eventfile}','withrateset=Y',f'rateset={out_file}','maketimecolumn=Y','timebinsize=283.44','makeratecolumn=Y',f'expression={expression}']

print("   Filter expression to use: "+expression+" \n")
print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    Filter expression to use: #XMMEA_EP&&(PI>=150)
#
#    SAS command to be executed: evselect, with arguments;
# ['table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_EPN_S003_TimingEvts.ds',
#  'withrateset=Y',
#  'rateset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_sr_Rthreshold.fits',
#  'maketimecolumn=Y',
#  'timebinsize=283.44',
#  'makeratecolumn=Y',
#  'expression=#XMMEA_EP&&(PI>=150)']

# %%
# %%capture
# Execute SAS task with parameters

w(cmd, inargs).run()

# %%
name= [" "]
file_paths = [out_file]

# Call the function to plot light curves
plotLC(file_paths, name, threshold = None)

# %% [markdown]
# * ### Barycentric correction
#
# Here we apply a barycentric correction, necessary
# for high resolved timing analysis.

# %% [markdown]
# After inspecting the light curve, the user can choose to remove the threshold value altogether if they see no need for it. This is particularly applicable in scenarios where the source is bright enough, rendering particle background filtering unnecessary. Hence we can run `evselect` in the following conditions:

# %%
pn_pi_min    = 150   
out_file = wdir + '/PN_clean_evt.fits'

# %%
# SAS Command
cmd        = "evselect" # SAS task to be executed                  

# Arguments of SAS Command
expression = f'#XMMEA_EP&&(PI>={pn_pi_min})'  # event filter expression
inargs     = [f'table={eventfile}','withfilteredset=Y',f'filteredset={out_file}','destruct=Y','keepfilteroutput=T',f'expression={expression}']

print("   Filter expression to use: "+expression+" \n")
print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    Filter expression to use: #XMMEA_EP&&(PI>=150)
#
#    SAS command to be executed: evselect, with arguments;
# ['table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_EPN_S003_TimingEvts.ds',
#  'withfilteredset=Y',
#  'filteredset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits',
#  'destruct=Y',
#  'keepfilteroutput=T',
#  'expression=#XMMEA_EP&&(PI>=150)']

# %%
# %%capture
# Execute SAS task with parameters

w(cmd, inargs).run()

# %% [markdown]
# Next we shall run the task `barycen`. The `barycen` task is designed to convert times from the local satellite frame to Barycentric Dynamical Time (TDB) using a specified table in a dataset containing times in XMM MET (Mission Elapsed Time) format. The task checks if barycentric conversion has been performed, exits if true, and proceeds to correct time tags in the specified column. Additionally, it converts interval start and stop times to TDB if a Good Time Interval extension exists and corrects time tags in EXPOSU tables if the relevant parameter is enabled. The task updates TIMEREF, TSTART, TSTOP, and TELAPSE attributes where necessary.

# %%
# Use the 'copy' function from the 'shutil' module to copy the file 'PN_clean_evt.fits'
# to a new file named 'PN_clean_evt_nobarycen_cor.fits'.
shutil.copy('PN_clean_evt.fits', 'PN_clean_evt_nobarycen_cor.fits')
# Out:
# 'PN_clean_evt_nobarycen_cor.fits'

# %%
table = wdir + "/PN_clean_evt.fits"

# %%
! /usr/local/SAS/xmmsas_20230412_1735/bin/barycen table='PN_clean_evt.fits:EVENTS' withtable=true
# Out:
# barycen:- Executing (routine): barycen withtable=yes table=PN_clean_evt.fits:EVENTS timecolumn=TIME withsrccoordinates=no srcra=0 srcdec=0 processgtis=yes processexposutables=yes time=0 ephemeris=DE200  -w 1 -V 4
# barycen:- barycen (barycen-1.22.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T10:26:35.000
# barycen:- Correcting Table... EXPOSU04
# barycen:- barycen (barycen-1.22.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T10:27:34.000

# %%
# SAS Command
cmd        = "/usr/local/SAS/xmmsas_20230412_1735/bin/barycen" # SAS task to be executed                  

# Arguments of SAS Command
inargs     = ['withtable=true', f'table={table}:EVENTS']

print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    SAS command to be executed: /usr/local/SAS/xmmsas_20230412_1735/bin/barycen, with arguments;
# ['withtable=true',
#  'table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data18Dec/PN_clean_evt.fits:EVENTS']

# %%
#|%%capture
# Execute SAS task with parameters

w(cmd, inargs).run()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[39], line 4
#       1 #|%%capture
#       2 # Execute SAS task with parameters
# ----> 4 w(cmd, inargs).run()
#
# File /usr/local/SAS/xmmsas_20230412_1735/lib/python/pysas/wrapper.py:47, in Wrapper.run(self)
#      45 def run(self):
#      46     t = MyTask(self.taskname, self.inargs,self.logFile)
# ---> 47     t.readparfile()
#      48     t.processargs()
#      49     t.runtask()
#
# File /usr/local/SAS/xmmsas_20230412_1735/lib/python/pysas/sastask.py:192, in MyTask.readparfile(self)
#     191 def readparfile(self):
# --> 192     t = paramXmlInfoReader(self.taskname)
#     193     t.xmlParser()
#     194     self.allparams = t.allparams
#
# File /usr/local/SAS/xmmsas_20230412_1735/lib/python/pysas/param.py:87, in paramXmlInfoReader.__init__(self, taskname)
#      84         break
#      86 if self.xmlFile == '':
# ---> 87     raise Exception(f'Does not exist any file named {parfile}. Wrong syntax?')
#
# Exception: Does not exist any file named /usr/local/SAS/xmmsas_20230412_1735/bin/barycen.par. Wrong syntax?

# %% [markdown]
# Now we have created filtered PN event list files with and without barycen. This barycentric correction will be necessary
# for high resolved timing analysis later on.

# %% [markdown]
# * ### Extracting the average light curve

# %% [markdown]
# Let us produce an image from our event file.

# %%
# Define some parameters to produce the image and the name of the output file

xbin=1     # xbin size
ybin=1    # ybin size
xcoord='RAWX'  # coordinate system
ycoord='RAWY'  # coordinate system

out_IMFile   = wdir+'/PNimage.fits'  # Name of the output Image file

# %%
# SAS Command
cmd        = "evselect" # SAS task to be executed                  

# Arguments of SAS Command
inargs     = [f'table={table}','imagebinning=binSize',f'imageset={out_IMFile}','withimageset=yes',f'xcolumn={xcoord}',f'ycolumn={ycoord}',f'ximagebinsize={xbin}',f'yimagebinsize={ybin}']

print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    SAS command to be executed: evselect, with arguments;
# ['table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits',
#  'imagebinning=binSize',
#  'imageset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PNimage.fits',
#  'withimageset=yes',
#  'xcolumn=RAWX',
#  'ycolumn=RAWY',
#  'ximagebinsize=1',
#  'yimagebinsize=1']

# %%
# %%capture
w(cmd, inargs).run()

# %% [markdown]
# In the image file the RAWY column is time, as the image produced was in timing mode. The source should be visible as a long bright line. Now we need to define the RARX1 and RAWX2 coordinate range for the strip of bright line which is the source, for this we can use js9 to get the coordination of the pixels.

# %% [markdown]
# Below we load the image produced in js9 using a custom function, so we can determine our RAWX1 and RAWX2 coordinates.

# %%
my_js9 = jpyjs9.JS9(width=600, height=700)
# Out:
# HTML(value="<iframe src='/datalabs/393fcf13918f01c7/js9/JS9-085e' width=600 height=700></iframe>")

# %%
visualise(my_js9, out_IMFile)

# %% [markdown]
# The values chosen in this case are taken from the paper of [Diez et al. (2023)](https://arxiv.org/pdf/2303.09631.pdf), where they study the same observation. However, the user can feel free to play around and experiment with their own values.

# %%
rawX1src = 32 #RAWX1 of the source rectangle region (in pixels)
rawX2src = 44 #RAWX2 of the source rectangle region (in pixels)

# %%
# Extract the source region lightcurve

# Define some parameters for filtering the event file and define the lightcurve binning

q_flag       = "#XMMEA_EP" # Quality flag for EPIC pn
n_pattern    = 4           # Pattern selection
pn_pi_min    = 500.        # Low energy range eV
pn_pi_max    = 10000.      # High energy range eV
lc_bin       = 283         # Lightcurve bin in secs

# Define the output ligthcurve file name

in_LCSRCFile = wdir+'/PN_source_lightcurve_raw_bin283sec.lc'   # Name of the output source lightcurve

# %%
# SAS Command
cmd        = "evselect" # SAS task to be executed                  

# Arguments of SAS Command
expression = f'{q_flag}&&(PATTERN<={n_pattern})&&(RAWX in [{rawX1src}:{rawX2src}])&&(PI in [{pn_pi_min}:{pn_pi_max}])'  # event filter expression
inargs     = [f'table={table}','energycolumn=PI','withrateset=yes',f'rateset={in_LCSRCFile}',
              f'timebinsize={lc_bin}','maketimecolumn=yes','makeratecolumn=yes',f'expression={expression}']

print("   Filter expression to use: "+expression+" \n")
print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    Filter expression to use: #XMMEA_EP&&(PATTERN<=4)&&(RAWX in [32:44])&&(PI in [500.0:10000.0])
#
#    SAS command to be executed: evselect, with arguments;
# ['table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits',
#  'energycolumn=PI',
#  'withrateset=yes',
#  'rateset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_bin283sec.lc',
#  'timebinsize=283',
#  'maketimecolumn=yes',
#  'makeratecolumn=yes',
#  'expression=#XMMEA_EP&&(PATTERN<=4)&&(RAWX in [32:44])&&(PI in [500.0:10000.0])']

# %%
# %%capture
w(cmd, inargs).run()

# %% [markdown]
# After extration we can plot the lightcurve of the selected source region:

# %%
name= ["Source with 283 bin in sec"]
file_paths = [in_LCSRCFile]
plotVelaX1LC(file_paths, name, threshold=None, figname="src_lightcurve.png")

# %% [markdown]
# Next moving onto extracting the lightcurve of the background region, where again pixel coordinate values have been taken from [Diez et al. (2023)](https://arxiv.org/pdf/2303.09631.pdf):

# %%
rawX1bkg = 3 #RAWX1 of the bkg rectangle region (in pixels)
rawX2bkg = 5 #RAWX2 of the bkg rectangle region (in pixels)

# %%
# Extract the background region lightcurve

# Define some parameters for filtering the event file and define the lightcurve binning

q_flag       = "#XMMEA_EP" # Quality flag for EPIC pn
n_pattern    = 4           # Pattern selection
pn_pi_min    = 500.        # Low energy range eV
pn_pi_max    = 10000.      # High energy range eV
lc_bin       = 283         # Lightcurve bin in secs

# Define the output ligthcurve file name

in_LCBKGFile = wdir+'/PN_lightcurve_background_raw_bin283sec.lc'   # Name of the output source lightcurve

# %%
# SAS Command
cmd        = "evselect" # SAS task to be executed                  

# Arguments of SAS Command
expression = f'{q_flag}&&(PATTERN<={n_pattern})&&(RAWX in [{rawX1bkg}:{rawX2bkg}])&&(PI in [{pn_pi_min}:{pn_pi_max}])'  # event filter expression
inargs     = [f'table={table}','energycolumn=PI','withrateset=yes',f'rateset={in_LCBKGFile}',
              f'timebinsize={lc_bin}','maketimecolumn=yes','makeratecolumn=yes',f'expression={expression}']

print("   Filter expression to use: "+expression+" \n")
print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    Filter expression to use: #XMMEA_EP&&(PATTERN<=4)&&(RAWX in [3:5])&&(PI in [500.0:10000.0])
#
#    SAS command to be executed: evselect, with arguments;
# ['table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits',
#  'energycolumn=PI',
#  'withrateset=yes',
#  'rateset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_bin283sec.lc',
#  'timebinsize=283',
#  'maketimecolumn=yes',
#  'makeratecolumn=yes',
#  'expression=#XMMEA_EP&&(PATTERN<=4)&&(RAWX in [3:5])&&(PI in [500.0:10000.0])']

# %%
# %%capture
w(cmd, inargs).run()

# %%
name= ["Background with 283 bins in sec"]
file_paths = [in_LCBKGFile]
plotVelaX1LC(file_paths, name, threshold=None, figname="bkg_lightcurve.png")

# %% [markdown]
# For background extraction we can run the command `epiclccorr` to perform correction of the lightcurve. Hence the command requires as input both light curves (which are used to establish the binning of the final corrected background subtracted light curve) and the event file.

# %%
# Define the output corrected ligthcurve file name

in_LCFile = wdir+'/PN_lccorr_bin283sec.lc'   # Name of the output corrected lightcurve

# %%
# Correct the light curve with the SAS task epiclccorr

# SAS Command
cmd        = "epiclccorr" # SAS task to be executed                  

# Arguments of SAS Command
inargs     = [f'eventlist={table}',f'srctslist={in_LCSRCFile}',f'outset={in_LCFile}',
              f'bkgtslist={in_LCBKGFile}','withbkgset=yes','applyabsolutecorrections=yes']

print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    SAS command to be executed: epiclccorr, with arguments;
# ['eventlist=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits',
#  'srctslist=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_bin283sec.lc',
#  'outset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_bin283sec.lc',
#  'bkgtslist=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_bin283sec.lc',
#  'withbkgset=yes',
#  'applyabsolutecorrections=yes']

# %%
# %%capture
w(cmd, inargs).run()
# Out:
# Executing:
# epiclccorr srctslist='/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_bin283sec.lc' eventlist='/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' outset='/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_bin283sec.lc' withbkgset='yes' bkgtslist='/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_bin283sec.lc' applyabsolutecorrections='yes' withdetbins='no' detxbins='5' detybins='5' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' allcamera='no'
# epiclccorr:- Executing (routine): epiclccorr srctslist=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_bin283sec.lc eventlist=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits outset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_bin283sec.lc bkgtslist=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_bin283sec.lc withbkgset=yes detxbins=5 detybins=5 withdetbins=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no applyabsolutecorrections=yes allcamera=no  -w 1 -V 4
# epiclccorr:- epiclccorr (epiclccorr-1.23.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T10:30:14.000
# epiclccorr:- selected 15479444 rows from the source input table.
# epiclccorr:- Closing event file dataset
# epiclccorr:- Extraction region lies in CCD number 4
# epiclccorr:- Calculating the relative corrections for each CCD...
# epiclccorr:- STDGTI04 extension found
# epiclccorr:- Processing GTI extension: STDGTI04 corresponding to CCD 4
# epiclccorr:- Doing GTI Correction...
# epiclccorr:- GTI Extension[STDGTI04]
# epiclccorr:- Done.
# epiclccorr:- Doing Exposure and Dead Time Correction: /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EXPOSU04
# ** epiclccorr: warning (PNTimingRand), Randomization for PN Timing or Burst not implemented
# epiclccorr:- closing data set /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits
# epiclccorr:- Exposure Correction Done.
# epiclccorr:- Relative Corrections Done.
# epiclccorr:- Calculating spectrum...
# epiclccorr:- Executing (invoked): evselect table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='( CCDNR in [4] && gti(/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [32:44] && PI in [500:) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum_PN_source_lightcurve_raw_bin283sec.lc spectralbinsize=50 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# epiclccorr:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T10:31:15.000
# epiclccorr::evselect:- Executing (routine): evselect table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='( CCDNR in [4] && gti(/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [32:44] && PI in [500:) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum_PN_source_lightcurve_raw_bin283sec.lc spectralbinsize=50 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# epiclccorr::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T10:31:15.000
# epiclccorr::evselect:- selected 15479444 rows from the input table.
# ** epiclccorr::evselect: warning (NonStandardSpectrum), The standard PI channel range for PN is 0-20479. Detector matrices can not be created for this spectrum and spectral fitting will not be possible.
# epiclccorr::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T10:31:38.000
# epiclccorr:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T10:31:38.000
# epiclccorr:- Done.
# epiclccorr:- Calculating arfgen...
# epiclccorr:- Executing (invoked): arfgen spectrumset=spectrum_PN_source_lightcurve_raw_bin283sec.lc rmfset=response.ds withrmfset=no arfset=src_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T10:31:38.000
# epiclccorr::arfgen:- Executing (routine): arfgen spectrumset=spectrum_PN_source_lightcurve_raw_bin283sec.lc rmfset=response.ds withrmfset=no arfset=src_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T10:31:38.000
# epiclccorr::arfgen:- Opening spectrumset spectrum_PN_source_lightcurve_raw_bin283sec.lc...
# epiclccorr::arfgen:- Closing spectrumset spectrum_PN_source_lightcurve_raw_bin283sec.lc.
# epiclccorr::arfgen:- Computing source position from region extent..
# epiclccorr::arfgen:- Using a source position in DET coordinates of x=45.5 y=-195.132
# epiclccorr::arfgen:-  The source position in focal plane coords is  theta=68.3147 phi=3.57833
# epiclccorr::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# epiclccorr::arfgen:- detector map binning will be: xbins: 55 ybins: 55
# epiclccorr::arfgen:- Constructing a flat detector map with  xmin=-8229 xmax=8320 xbins=55 ymin=-1080 ymax=15469 ybins=55
# epiclccorr::arfgen:- PSF type: 3 [ELLBETA] will be used
# epiclccorr::arfgen:- Opening arfset src_ancillary.ds...
# Making file temp_badcol.ds
# epiclccorr::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# epiclccorr::arfgen:- Writing energy data into dataset ..
# epiclccorr::arfgen:- Calculating Area curve ...
# epiclccorr::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# epiclccorr::arfgen:- Bad pixel & chip gap fraction: ~0.215234075 %
# epiclccorr::arfgen:- Writing area data into dataset ..
# epiclccorr::arfgen:- Closing arfset src_ancillary.ds.
# epiclccorr::arfgen:- Opening spectrumset spectrum_PN_source_lightcurve_raw_bin283sec.lc...
# epiclccorr::arfgen:- Opened spectrumset spectrum_PN_source_lightcurve_raw_bin283sec.lc...
# epiclccorr::arfgen:- Opened table spectrum_PN_source_lightcurve_raw_bin283sec.lc...
# epiclccorr::arfgen:- current backscale value is: 1
# epiclccorr::arfgen:- deleted attspectrum_PN_source_lightcurve_raw_bin283sec.lc...
# epiclccorr::arfgen:- Backscale value is: 17662465
# epiclccorr::arfgen:- added attspectrum_PN_source_lightcurve_raw_bin283sec.lc...
# epiclccorr::arfgen:- closed specspectrum_PN_source_lightcurve_raw_bin283sec.lc...
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T10:32:14.000
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T10:32:14.000
# epiclccorr:- Done.
# epiclccorr:- Reading Spectrum... spectrum_PN_source_lightcurve_raw_bin283sec.lc
# epiclccorr:- Reading ancillary file... spectrum_PN_source_lightcurve_raw_bin283sec.lc
# epiclccorr:- Done.
# epiclccorr:- Calculating arfgen...
# epiclccorr:- Executing (invoked): arfgen spectrumset=spectrum_PN_source_lightcurve_raw_bin283sec.lc rmfset=response.ds withrmfset=no arfset=on_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=yes detxbins=1 detybins=1 withdetbins=no psfenergy=2 filterdss=no filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=tel sourcex=0 sourcey=0 withsourcepos=yes extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T10:32:14.000
# epiclccorr::arfgen:- Executing (routine): arfgen spectrumset=spectrum_PN_source_lightcurve_raw_bin283sec.lc rmfset=response.ds withrmfset=no arfset=on_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=yes detxbins=1 detybins=1 withdetbins=no psfenergy=2 filterdss=no filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=tel sourcex=0 sourcey=0 withsourcepos=yes extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T10:32:14.000
# epiclccorr::arfgen:- Opening spectrumset spectrum_PN_source_lightcurve_raw_bin283sec.lc...
# epiclccorr::arfgen:- Closing spectrumset spectrum_PN_source_lightcurve_raw_bin283sec.lc.
# epiclccorr::arfgen:- Using a source position in TEL coordinates of x=0 y=0
# epiclccorr::arfgen:- This corresponds to a position in DET coordinates of DETX=1283.63 DETY=382.834
# epiclccorr::arfgen:-  The source position in focal plane coords is  theta=0 phi=0
# epiclccorr::arfgen:- Taking detector map bounds from the parameters detxoffset and detyoffset ...
# epiclccorr::arfgen:- detector map binning will be: xbins: 8 ybins: 8
# epiclccorr::arfgen:- Constructing a flat detector map with  xmin=83.63452736 xmax=2483.634527 xbins=8 ymin=-817.1664529 ymax=1582.833547 ybins=8
# epiclccorr::arfgen:- Opening arfset on_ancillary.ds...
# epiclccorr::arfgen:- Writing energy data into dataset ..
# epiclccorr::arfgen:- Calculating Area curve ...
# epiclccorr::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# epiclccorr::arfgen:- Bad pixel & chip gap fraction: ~0 %
# epiclccorr::arfgen:- Writing area data into dataset ..
# epiclccorr::arfgen:- Closing arfset on_ancillary.ds.
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T10:32:21.000
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T10:32:21.000
# epiclccorr:- Done.
# epiclccorr:- Reading ancillary file... spectrum_PN_source_lightcurve_raw_bin283sec.lc
# epiclccorr:- Done.
# epiclccorr:- Weighted Mean 1.155357457511373642
# epiclccorr:- selected 30717 rows from the source input table.
# epiclccorr:- Closing event file dataset
# epiclccorr:- Extraction region lies in CCD number 4
# epiclccorr:- Calculating the relative corrections for each CCD...
# epiclccorr:- STDGTI04 extension found
# epiclccorr:- Processing GTI extension: STDGTI04 corresponding to CCD 4
# epiclccorr:- Doing GTI Correction...
# epiclccorr:- GTI Extension[STDGTI04]
# epiclccorr:- Done.
# epiclccorr:- Doing Exposure and Dead Time Correction: /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EXPOSU04
# epiclccorr:- closing data set /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits
# epiclccorr:- Exposure Correction Done.
# epiclccorr:- Relative Corrections Done.
# epiclccorr:- Calculating spectrum...
# epiclccorr:- Executing (invoked): evselect table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='( CCDNR in [4] && gti(/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [3:5] && PI in [500:) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum_PN_lightcurve_background_raw_bin283sec.lc spectralbinsize=50 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# epiclccorr:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T10:33:20.000
# epiclccorr::evselect:- Executing (routine): evselect table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='( CCDNR in [4] && gti(/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [3:5] && PI in [500:) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum_PN_lightcurve_background_raw_bin283sec.lc spectralbinsize=50 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# epiclccorr::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T10:33:20.000
# epiclccorr::evselect:- selected 30717 rows from the input table.
# ** epiclccorr::evselect: warning (NonStandardSpectrum), The standard PI channel range for PN is 0-20479. Detector matrices can not be created for this spectrum and spectral fitting will not be possible.
# epiclccorr::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T10:33:36.000
# epiclccorr:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T10:33:36.000
# epiclccorr:- Done.
# epiclccorr:- Calculating arfgen...
# epiclccorr:- Executing (invoked): arfgen spectrumset=spectrum_PN_lightcurve_background_raw_bin283sec.lc rmfset=response.ds withrmfset=no arfset=bkg_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=yes modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T10:33:36.000
# epiclccorr::arfgen:- Executing (routine): arfgen spectrumset=spectrum_PN_lightcurve_background_raw_bin283sec.lc rmfset=response.ds withrmfset=no arfset=bkg_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=yes modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T10:33:36.000
# epiclccorr::arfgen:- Opening spectrumset spectrum_PN_lightcurve_background_raw_bin283sec.lc...
# epiclccorr::arfgen:- Closing spectrumset spectrum_PN_lightcurve_background_raw_bin283sec.lc.
# epiclccorr::arfgen:- Computing source position from region extent..
# epiclccorr::arfgen:- Using a source position in DET coordinates of x=2852 y=-195.132
# epiclccorr::arfgen:-  The source position in focal plane coords is  theta=83.5677 phi=5.93011
# epiclccorr::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# epiclccorr::arfgen:- detector map binning will be: xbins: 55 ybins: 55
# epiclccorr::arfgen:- Constructing a flat detector map with  xmin=-5406 xmax=11110 xbins=55 ymin=-1064 ymax=15453 ybins=55
# epiclccorr::arfgen:- Opening arfset bkg_ancillary.ds...
# Making file temp_badcol.ds
# epiclccorr::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# epiclccorr::arfgen:- Writing energy data into dataset ..
# epiclccorr::arfgen:- Calculating Area curve ...
# epiclccorr::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# epiclccorr::arfgen:- Bad pixel & chip gap fraction: ~0.5690072639 %
# epiclccorr::arfgen:- Writing area data into dataset ..
# epiclccorr::arfgen:- Closing arfset bkg_ancillary.ds.
# epiclccorr::arfgen:- Opening spectrumset spectrum_PN_lightcurve_background_raw_bin283sec.lc...
# epiclccorr::arfgen:- Opened spectrumset spectrum_PN_lightcurve_background_raw_bin283sec.lc...
# epiclccorr::arfgen:- Opened table spectrum_PN_lightcurve_background_raw_bin283sec.lc...
# epiclccorr::arfgen:- current backscale value is: 1
# epiclccorr::arfgen:- deleted attspectrum_PN_lightcurve_background_raw_bin283sec.lc...
# epiclccorr::arfgen:- Backscale value is: 3942240
# epiclccorr::arfgen:- added attspectrum_PN_lightcurve_background_raw_bin283sec.lc...
# epiclccorr::arfgen:- closed specspectrum_PN_lightcurve_background_raw_bin283sec.lc...
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T10:33:38.000
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T10:33:38.000
# epiclccorr:- Done.
# epiclccorr:- Reading Spectrum... spectrum_PN_lightcurve_background_raw_bin283sec.lc
# epiclccorr:- Substracting background...
# epiclccorr:- Checking Source and Background Binning
# epiclccorr:- Source Start Time: 673308775.717167
# epiclccorr:- Background Start Time: 673308775.717167
# epiclccorr:- Source Stop Time: 673420277.717167
# epiclccorr:- Background Stop Time: 673420277.717167
# epiclccorr:- Source BACKSCALE: 17662465
# epiclccorr:- Background BACKSCALE: 3942240
# epiclccorr:- Done.
# epiclccorr:- Applying Absolute Correction...
# epiclccorr:- Done.
# epiclccorr:- Creating SRC_GTIS GTIs...
# epiclccorr:- Done.
# epiclccorr:- Creating BKG_GTIS GTIs...
# epiclccorr:- Done.
# epiclccorr:- Removing GTI information from DSS...
# epiclccorr:- Done
# epiclccorr:- Extracting PI information from DSS...
# epiclccorr:- Done
# epiclccorr:- LightCurve Destructor
# epiclccorr:- Done
# epiclccorr:- LightCurve Destructor
# epiclccorr:- Done
# epiclccorr:- epiclccorr (epiclccorr-1.23.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T10:33:38.000
# ** epiclccorr: warning (SummaryOfWarnings),
#    warning PNTimingRand silently occurred 1 times

# %% [markdown]
# Let us visualize all the lightcurves produced using matplotlib lightcurve plotting function define by us through the plotLC python file, where we can bin some of the data for a cleaner look:

# %%
# Inspect the light curves
fileNames = [in_LCFile, in_LCSRCFile]
names = ['Corrected', 'Source']

plotVelaX1LC(fileNames, names, threshold=None, figname="combined_lightcurvenothreshold.png")

# %% [markdown]
# * ### Checking for Pile-Up
#
# "Pile-up" happens when the detector registers multiple X-ray photons within a single readout frame as a single event. This occurs when the X-ray flux is so high that the detector cannot distinguish individual photons, and their signals overlap or pile up.
#
# In XMM-Newton, each incoming X-ray photon is converted into an electronic signal. However, if multiple photons arrive at the detector in rapid succession, their signals may overlap, leading to an inaccurate representation of the detected X-ray events. This phenomenon can distort the measured X-ray spectra and impact the accuracy of scientific observations.
#
# This step is usually advised to be applied before extracting the light curves as done on the previous step, however as the source we look at is immensely bright, the pile-up effect will not have an significant impact on the output light curve. However, we apply it here as before the extraction of the spectrum it is important, otherwise it could lead to false output with the spectrum having higher flux at high energies.

# %%
# Define some parameters for filtering the event file
rawX1src = 32
rawX2src = 44
pn_pi_min    = 550.        # Low energy range eV
pn_pi_max    = 10000.      # High energy range eV

# Define the output file name

filtered_output = wdir+'/PN_filtered_'+str(rawX1src)+'-'+str(rawX2src)+'.evt'

# %%
# SAS Command
cmd        = "evselect" # SAS task to be executed                  

# Arguments of SAS Command
expression = f'(RAWX in [{rawX1src}:{rawX2src}])&&(PI in [{pn_pi_min}:{pn_pi_max}])'  # event filter expression
inargs     = [f'table={table}','withfilteredset=yes',f'filteredset={filtered_output}',
              'keepfilteroutput=yes',f'expression={expression}']

print("   Filter expression to use: "+expression+" \n")
print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    Filter expression to use: (RAWX in [32:44])&&(PI in [550.0:10000.0])
#
#    SAS command to be executed: evselect, with arguments;
# ['table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits',
#  'withfilteredset=yes',
#  'filteredset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_filtered_32-44.evt',
#  'keepfilteroutput=yes',
#  'expression=(RAWX in [32:44])&&(PI in [550.0:10000.0])']

# %%
# %%capture
w(cmd, inargs).run()
# Out:
# Executing:
# evselect table='/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' keepfilteroutput='yes' withfilteredset='yes' filteredset='/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_filtered_32-44.evt' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='(RAWX in [32:44])&&(PI in [550.0:10000.0])' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PHA' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='no' spectrumset='spectrum.fits' spectralbinsize='5' withspecranges='no' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits filteredset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_filtered_32-44.evt withfilteredset=yes keepfilteroutput=yes flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(RAWX in [32:44])&&(PI in [550.0:10000.0])' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PHA zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T11:14:45.000
# evselect:- selected 15052134 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T11:15:03.000

# %% [markdown]
# We can use the SAS command `epatplot` to plot EPIC pn and MOS event pattern statistics, which should help us see if pile-up has occured. For further in depth information the user is advised to look at the thread *How to Evaluate and test Pile-Up in an EPIC Source*.

# %%
# %%capture
w('epatplot',[f'set={filtered_output}', 'device= /PNG']).run()
# Out:
# Executing:
# epatplot set='/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_filtered_32-44.evt' modifyinset='yes' sigma='3' withflag='yes' xaxisadu='no' device=' /PNG' outdir='./' useplotfile='no' plotfile='events_pat.ps' withqdp='no' withdetxy='no' withsrcxy='yes' withoutputmask='no' outmaskname='flag0_map_##.dat' withbackgroundset='no' backgroundset='bkg_events.fits' backscal='1.0' withusermode='no' usermode='0' withuserrawy='no' userrawy='190' ccdlimits='1 64 1 200 1 12' plotxrange='0.0 0.0' plotyrange='0.0 0.0' pileupnumberenergyrange='500 2000'
# epatplot:- Executing (routine): epatplot set=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_filtered_32-44.evt modifyinset=yes sigma=3 withflag=yes xaxisadu=no device=' /PNG' outdir=./ plotfile=events_pat.ps useplotfile=no withqdp=no withdetxy=no withsrcxy=yes outmaskname=flag0_map_##.dat withoutputmask=no backgroundset=bkg_events.fits withbackgroundset=no backscal=1 usermode=0 withusermode=no userrawy=190 withuserrawy=no ccdlimits='1 64 1 200 1 12' plotxrange='0 0' plotyrange='0 0' pileupnumberenergyrange='500 2000'  -w 1 -V 4
# epatplot:- epatplot (epatplot-1.22)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-07T11:15:08.000
# epatplot:-  epatplot 1.22 is running...
# ** epatplot: warning (noDETX), No DETX column in input data set
# ** epatplot: warning (noDETY), No DETY column in input data set
# epatplot:-
# epatplot:-        s       d       t       q
# epatplot:-   0.7946  0.1947  0.0049  0.0057
# epatplot:-
# epatplot:- 0.5-2.0 keV observed-to-model fractions:
# epatplot:- s: 0.973 +/- 0.002   d: 1.250 +/- 0.004
# epatplot:-
# epatplot:-  PostScript output written to file PN_filtered_32-44_pat.ps
# epatplot:- epatplot (epatplot-1.22)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-07T11:15:18.000

# %% [markdown]
# We can display the image produced:

# %%
png_path = wdir+'/pgplot.png'
display(Image(filename=png_path))

# %% [markdown]
# As we can see the double events are higher than theory line and single ones are lower for our observation, thereby indicating the need for applying a pile-up correction, which we apply below:

# %%
# Define some parameters for filtering the event file 
rawX3src = 36
rawX4src = 40
pn_pi_min    = 550.        # Low energy range eV
pn_pi_max    = 10000.      # High energy range eV

# Define the output file name

filtered_output = wdir+'/PN_filtered_annulus_'+str(rawX1src)+'-'+str(rawX3src)+'_'+str(rawX4src)+'-'+str(rawX2src)+'.evt'   # Name of the output

# %%
# SAS Command
cmd        = "evselect" # SAS task to be executed                  

# Arguments of SAS Command
expression = f'(RAWX in [{rawX1src}:{rawX3src}] || RAWX in [{rawX4src}:{rawX2src}])&&(PI in [{pn_pi_min}:{pn_pi_max}])'  # event filter expression
inargs     = [f'table={table}','withfilteredset=yes',f'filteredset={filtered_output}',
              'keepfilteroutput=yes',f'expression={expression}']

print("   Filter expression to use: "+expression+" \n")
print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    Filter expression to use: (RAWX in [32:36] || RAWX in [40:44])&&(PI in [550.0:10000.0])
#
#    SAS command to be executed: evselect, with arguments;
# ['table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits',
#  'withfilteredset=yes',
#  'filteredset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_filtered_annulus_32-36_40-44.evt',
#  'keepfilteroutput=yes',
#  'expression=(RAWX in [32:36] || RAWX in [40:44])&&(PI in [550.0:10000.0])']

# %%
# %%capture
w(cmd, inargs).run()

# %%
# %%capture
w('epatplot',[f'set={filtered_output}', 'device= /PNG']).run()

# %%
png_path = f'{home}/my_workspace/xmm_sas_datalabs/data/VelaX1/pgplot.png'
display(Image(filename=png_path))

# %% [markdown]
# Now we can see that after the correction the theory and observation match and we have accounted for pile-up, therefore we can move onto extracting the spectrum of the source safely.

# %% [markdown]
# * ### Spectrum Extraction
#
# #### Time Averaged Spectrum

# %% [markdown]
# No we can produce a spectrum for the source region, by avoiding pile-up regions:

# %%
rawX1src= 32
rawX2src = 44

# %%
#core of the psf coordinates:
rawX3src = 36
rawX4src = 40
spectrumset= wdir+ '/PN_source_spectrum_raw_'+str(rawX1src)+'-'+str(rawX3src)+'_'+str(rawX4src)+'-'+str(rawX2src)+'.fits'

# %%
# SAS Command
cmd        = "evselect" # SAS task to be executed                  

# Arguments of SAS Command
expression = f'(FLAG==0) && (PATTERN<=4) && (RAWX in [{rawX1src}:{rawX3src}] || RAWX in [{rawX4src}:{rawX2src}])'  # event filter expression
inargs     = [f'table={table}','withspectrumset=yes',f'spectrumset={spectrumset}',
              'energycolumn=PI', 'spectralbinsize=5', 'withspecranges=yes', 'specchannelmin=0', 'specchannelmax=20479',f'expression={expression}']

print("   Filter expression to use: "+expression+" \n")
print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    Filter expression to use: (FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44])
#
#    SAS command to be executed: evselect, with arguments;
# ['table=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits',
#  'withspectrumset=yes',
#  'spectrumset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_32-36_40-44.fits',
#  'energycolumn=PI',
#  'spectralbinsize=5',
#  'withspecranges=yes',
#  'specchannelmin=0',
#  'specchannelmax=20479',
#  'expression=(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44])']

# %%
# %%capture
w(cmd, inargs).run()

# %%
# SAS Command
cmd        = "backscale" # SAS task to be executed                  

# Arguments of SAS Command
inargs     = [f'spectrumset={spectrumset}',f'badpixlocation={table}']

print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    SAS command to be executed: backscale, with arguments;
# ['spectrumset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_32-36_40-44.fits',
#  'badpixlocation=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits']

# %%
# %%capture
w(cmd, inargs).run()

# %%
# Define some parameters for rmfgen

# Define the output redistribution matrix file name

in_RESPFile = wdir+'/PN_'+str(rawX1src)+'-'+str(rawX3src)+'_'+str(rawX4src)+'-'+str(rawX2src)+'.rmf'   # Name of the output redistribution

# %%
# SAS Command
cmd        = "rmfgen" # SAS task to be executed                  

# Arguments of SAS Command
inargs     = [f'spectrumset={spectrumset}',f'rmfset={in_RESPFile}']

print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    SAS command to be executed: rmfgen, with arguments;
# ['spectrumset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_32-36_40-44.fits',
#  'rmfset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_32-36_40-44.rmf']

# %%
# %%capture
w(cmd, inargs).run()

# %%
# Define some parameters for arfgen

# Define the output ancillary file name

in_ARFFile = wdir+'/PN_'+str(rawX1src)+'-'+str(rawX3src)+'_'+str(rawX4src)+'-'+str(rawX2src)+'.arf'   # Name of the output ancillary

# %%
# SAS Command
cmd        = "arfgen" # SAS task to be executed                  

print("   Checking for Response File ..... \n")
# Check if RESP file is available.
if os.path.isfile(in_RESPFile):
    print ("File "+in_RESPFile+" exists. \n")
else:
    print ("File "+in_RESPFile+" does not exist, please check. \n")

# Arguments of SAS Command
inargs     = [f'spectrumset={spectrumset}',f'arfset={in_ARFFile}',
              'withrmfset=yes',f'rmfset={in_RESPFile}',f'badpixlocation={table}','detmaptype=psf', 'applyabsfluxcorr=yes']

print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    Checking for Response File .....
#
# File /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_32-36_40-44.rmf exists.
#
#    SAS command to be executed: arfgen, with arguments;
# ['spectrumset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_32-36_40-44.fits',
#  'arfset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_32-36_40-44.arf',
#  'withrmfset=yes',
#  'rmfset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_32-36_40-44.rmf',
#  'badpixlocation=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits',
#  'detmaptype=psf',
#  'applyabsfluxcorr=yes']

# %%
# %%capture
w(cmd, inargs).run()

# %%
# Define some parameters for specgruop

in_GRPFile = wdir+'/PN_spectrum_grp_'+str(rawX1src)+'-'+str(rawX3src)+'_'+str(rawX4src)+'-'+str(rawX2src)+'.fits'   # Name of the output specgruop

# %%
# SAS Command
cmd        = "specgroup" # SAS task to be executed                  

# Arguments of SAS Command
inargs     = [f'spectrumset={spectrumset}','mincounts=25','oversample=3',
              f'rmfset={in_RESPFile}',f'arfset={in_ARFFile}',
              f'groupedset={in_GRPFile}']

print("   SAS command to be executed: "+cmd+", with arguments; \n")
inargs
# Out:
#    SAS command to be executed: specgroup, with arguments;
# ['spectrumset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_32-36_40-44.fits',
#  'mincounts=25',
#  'oversample=3',
#  'rmfset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_32-36_40-44.rmf',
#  'arfset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_32-36_40-44.arf',
#  'groupedset=/home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_32-36_40-44.fits']

# %%
# %%capture
w(cmd, inargs).run()

# %% [markdown]
# Now that we have acquired the final spectrum, we can load the file using pyXspec:

# %%
# Before you start, clear all data and models

AllModels.clear()  # Clear all models
AllData.clear()    # Clear all data

# %%
# Load the group spectral file

# The group file already contains in the header the names of all the necessary files needed by xspec
# (source and background spectra, response and ancillery files)

data1 = Spectrum(in_GRPFile)  # load spectra groupped file

AllData.show()                # inspect loaded data
# Out:
# 1 spectrum  in use
#
# Spectral Data File: /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_32-36_40-44.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  4.907e+01 +/- 2.119e-02
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-238
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.093e+05 sec
#  Using fit statistic: chi
#  Using Response (RMF) File            /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_32-36_40-44.rmf for Source 1
#  Using Auxiliary Response (ARF) File  /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_32-36_40-44.arf
#
#
# 2 spectra  in use
#
# Spectral Data File: /home/egulbaha/my_workspace/xmm_sas_datalabs/data/camillespectra/nondefault/PN_spectrum_grp_32-36_40-44.fits  Spectrum 2
# Net count rate (cts/s) for Spectrum:2  4.907e+01 +/- 2.119e-02
#  Assigned to Data Group 1 and Plot Group 2
#   Noticed Channels:  1-238
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.093e+05 sec
#  Using fit statistic: chi
#  Using Response (RMF) File            /home/egulbaha/my_workspace/xmm_sas_datalabs/data/camillespectra/nondefault/PN_32-36_40-44.rmf for Source 1
#  Using Auxiliary Response (ARF) File  /home/egulbaha/my_workspace/xmm_sas_datalabs/data/camillespectra/nondefault/PN_32-36_40-44.arf
#
#
# 2 files 2 spectra
# Spectrum 1  Spectral Data File: /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_32-36_40-44.fits
# Net count rate (cts/s) for Spectrum:1  4.907e+01 +/- 2.119e-02
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-238
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.093e+05 sec
#  Using fit statistic: chi
#  Using Response (RMF) File            /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_32-36_40-44.rmf for Source 1
#  Using Auxiliary Response (ARF) File  /home/egulbaha/my_workspace/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_32-36_40-44.arf
#
# Spectrum 2  Spectral Data File: /home/egulbaha/my_workspace/xmm_sas_datalabs/data/camillespectra/nondefault/PN_spectrum_grp_32-36_40-44.fits
# Net count rate (cts/s) for Spectrum:2  4.907e+01 +/- 2.119e-02
#  Assigned to Data Group 1 and Plot Group 2
#   Noticed Channels:  1-238
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.093e+05 sec
#  Using fit statistic: chi
#  Using Response (RMF) File            /home/egulbaha/my_workspace/xmm_sas_datalabs/data/camillespectra/nondefault/PN_32-36_40-44.rmf for Source 1
#  Using Auxiliary Response (ARF) File  /home/egulbaha/my_workspace/xmm_sas_datalabs/data/camillespectra/nondefault/PN_32-36_40-44.arf

# %%
# Set the plot device to /null to suppress graphical output

Plot.device = "/null"

# %%
# First inspection of the spectrum

Plot.xAxis = "keV"        # set X axis to energy units
Plot.xLog  = True         # log scale
Plot.yLog  = True         # log scale
Plot("data")   # plot source and background spectra

# %%
# Extract data from the XSPEC plot
energies = Plot.x(1)    # X-axis values
edeltas = Plot.xErr(1)  # X-axis error values
rates = Plot.y(1)       # Y-axis values
errors = Plot.yErr(1)   # Y-axis error values
labels = Plot.labels()

# %%
# Customize the plot appearance
plt.xscale('log')
plt.yscale('log')
plt.xlabel(labels[0])
plt.ylabel(labels[1])
plt.title('Averaged Spectrum Vela X-1: Datalabs')
plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
plt.tick_params(axis='both', which='major', labelsize=13, length=10, width=1)
plt.tick_params(axis='both', which='minor', length=5, width=1)
plt.xticks([0.5, 1, 2, 5, 10], labels=[0.5, 1, 2, 5, 10])

# Plot your spectrum with error bars
plt.errorbar(energies,rates,xerr=edeltas,yerr=errors,fmt='.')

plt.savefig(wdir+"/averaged-spec-datalabs.png", dpi=300)

# %% [markdown]
# Above we have visualised an average spectrum, and to fit model the user needs to look at time resolved spectroscopy. In this thread we will not go into the specifics of model fitting for the spectrum.
#
# #### Spectra for three distinct observation phases (see Fig. 3 from [Diez et al. (2023)](https://arxiv.org/pdf/2303.09631.pdf))
#
# The phases are characterised by their hardness ratio as observed in [Diez et al. (2022)](https://ui.adsabs.harvard.edu/abs/2022A%26A...660A..19D/abstract):
#
# * Stable hardness ratio at: $ 0.37 \lesssim Orbital Phase \lesssim 0.44 $
# * Phase 2: $ 0.44 \lesssim Orbital Phase \lesssim 0.46 $
# * Rise in the hardness ratio at: $ 0.46 \lesssim Orbital Phase \lesssim 0.51 $
#
# Instead of running the detailed spectrum extraction steps showcased above, we have put the same tasks in a Python script with a loop to run it for our selected time ranges. The file is called spectrum-extractor.py and we simply run it to get the spectra for the three distinct phases of interest.

# %%
# !python3 /media/user/Vela-work/XMM-SAS-Datalabs-Paper/scripts/spectrum-extractor.py
# Out:
# [673310879.9999998, 673367039.9999999, 673382591.9999999, 673418879.9999998]
# startsas - WARNING - Executing /usr/local/SAS/xmmsas_20230412_1735/lib/python/pysas/startsas/startsas.py {'odfid': '', 'workdir': '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan', 'sasfiles': 'yes', 'sas_ccf': '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif', 'sas_odf': '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS', 'level': 'ODF', 'cifbuild_opts': '', 'odfingest_opts': ''}
#
#
#         Starting SAS session
#
#         Working directory = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan
#
#
# SAS_CCF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif
# SAS_ODF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS
# Warning: No need to include withspecranges. Assumed withspecranges=yes
# Executing:
# evselect table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44]) && (TIME >= 673310879.9999998) && (TIME <= 673367039.9999999)' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits' spectralbinsize='5' withspecranges='yes' specchannelmin='0' specchannelmax='20479' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44]) && (TIME >= 673310879.9999998) && (TIME <= 673367039.9999999)' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits spectralbinsize=5 specchannelmin=0 specchannelmax=20479 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:18:05.000
# evselect:- selected 3321131 rows from the input table.
# ** evselect: warning (DifferentAttributeValues), Attribute `TIMESYS' has different value in `/tmp/fileaiiBbi:STDGTI04' (TDB) and `/tmp/fileQml4Kg:GTI00003' (TT) - please make sure it makes sense to merge the GTI tables
# ** evselect: warning (ExpBadDssGlobal), A filtering expression has been specified which may not allow for calculation of a uniform exposure for all events.  Please ensure that all TIME related filters are applied uniformly.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:18:19.000
# ** evselect: warning (SummaryOfWarnings),
#    warning DifferentAttributeValues silently occurred 3 times
# Executing:
# backscale spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits' badpixlocation='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:18:19.000
# backscale:- Executing (routine): arfgen spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:18:19.000
# backscale::arfgen:- Opening spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits...
# backscale::arfgen:- Closing spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# backscale::arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-8545 xmax=8635 xbins=1 ymin=-1065 ymax=15454 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# ** backscale::arfgen: warning (zeroSumDetmap), The filtered detector map has a zero normalisation - returning zero area. Try using a flat detector map and/or more bins
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0.1429431873 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits...
# backscale::arfgen:- Opened spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits...
# backscale::arfgen:- Opened table /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits...
# backscale::arfgen:- Backscale value is: 13407164
# backscale::arfgen:- added att/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits...
# backscale::arfgen:- closed spec/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:18:49.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:18:49.000
# Executing:
# rmfgen rmfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.rmf' threshold='1e-06' withenergybins='no' energymin='0' energymax='15' nenergybins='30' spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits' format='var' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='yes' detxbins='160' detybins='160' correctforpileup='no' raweventfile='rawevents.ds' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withrmfset='no' psfenergy='2' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='no' modelquantumeff='no' modelfiltertrans='no' modelcontamination='no' modelee='yes' modelootcorr='no' eegridfactor='100' withbadpixcorr='no' badpixlocation='notSpecified' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset='' psfmodel='notSpecified' withbadpixres='no' badpixelresolution='2' applyxcaladjustment='no' acceptchanrange='no' applyabsfluxcorr='no'
# rmfgen:- Executing (routine): rmfgen rmfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.rmf threshold=1e-06 withenergybins=no energymin=0 energymax=15 nenergybins=30 spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits format=var detmaptype=psf detmaparray=detmapfile.ds: withdetbounds=no detxoffset=1200 detyoffset=1200 detxbins=160 detybins=160 withdetbins=yes raweventfile=rawevents.ds correctforpileup=no filterdss=yes withfilteredset=no filteredset=filteredpixellist.ds withrmfset=no psfenergy=2 withsourcepos=no sourcecoords=eqpos sourcex=0 sourcey=0 extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=no modelee=yes modelootcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no psfmodel=notSpecified badpixelresolution=2 withbadpixres=no applyxcaladjustment=no acceptchanrange=no applyabsfluxcorr=no  -w 1 -V 4
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:18:49.000
# Set to: notSpecified
# rmfgen:- Opening spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits...
# rmfgen:- Closing spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits.
# rmfgen:- Computing source position from region extent..
# rmfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# rmfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# rmfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# rmfgen:- detector map binning will be: xbins: 160 ybins: 160
# rmfgen:- Constructing a psf detector map with  xmin=-8545 xmax=8635 xbins=160 ymin=-1065 ymax=15454 ybins=160
# rmfgen:- PSF type: 5 [HIGH] will be used
# rmfgen:-  Creating RmfDataServer...
# rmfgen:-  EventGrades:4 FastTiming 37
# rmfgen:-  RmfDataServer created ok.
# rmfgen:- Opening data set ...
# rmfgen:- Opened data set.
# rmfgen:- Adding MATRIX table. There will be 2067 rows in table
# rmfgen:- Initialising table iterator ..
# rmfgen:- Populating table ..
# rmfgen:- Adding EBOUNDS extension ...
# rmfgen:-  Cleanup ...
# rmfgen:-  Closing data set ...
# rmfgen:-  Closed data set.
# rmfgen:-  Cleanup complete.
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:19:31.000
# Executing:
# arfgen spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits' withrmfset='yes' rmfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.rmf' arfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.arf' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='no' detxbins='5' detybins='5' psfenergy='2' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='yes' modelquantumeff='yes' modelfiltertrans='yes' modelcontamination='yes' modelee='yes' modelootcorr='yes' applyxcaladjustment='no' applyabsfluxcorr='yes' eegridfactor='100' withbadpixcorr='yes' badpixlocation='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' psfmodel='ELLBETA' withbadpixres='no' badpixelresolution='2' badpixmaptype='flat' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset=''
# arfgen:- Executing (routine): arfgen spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits rmfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.rmf withrmfset=yes arfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.arf detmaptype=psf detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=yes eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:19:31.000
# arfgen:- Opening spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits...
# arfgen:- Closing spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits.
# arfgen:- Computing source position from region extent..
# arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# arfgen:- detector map binning will be: xbins: 57 ybins: 55
# arfgen:- Constructing a psf detector map with  xmin=-8545 xmax=8635 xbins=57 ymin=-1065 ymax=15454 ybins=55
# arfgen:- PSF type: 3 [ELLBETA] will be used
# arfgen:- Opening arfset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.arf...
# Making file temp_badcol.ds
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- Writing energy data into dataset ..
# arfgen:- Calculating Area curve ...
# arfgen:- Calculating Area curve ...50.4999999 2067 15997.49947
# arfgen:- Bad pixel & chip gap fraction: ~0.4448886274 %
# arfgen:- Writing area data into dataset ..
# arfgen:- Closing arfset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.arf.
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:26:59.000
# Executing:
# specgroup spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits' overwrite='no' groupedset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673310879.9999998_32-36_40-44.fits' withbgdset='no' backgndset='' withCounts='yes' mincounts='25' withminSN='no' minSN='5' withratioabovebgnd='no' ratioabovebgnd='' withoversampling='yes' oversample='3' withtemplate='no' grouptemplate='grptemplate.ds' withranges='no' ranges='' withRegularBins='no' regbinstart='' regbinend='' regbinwid='' units='CHAN' withrmfset='yes' rmfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.rmf' witharfset='yes' arfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.arf' addfilenames='yes' hightolow='no' lastbin='addtogroup' setbad='CCF'
# specgroup:- Executing (routine): specgroup spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673310879.9999998_32-36_40-44.fits groupedset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673310879.9999998_32-36_40-44.fits overwrite=no backgndset='' withbgdset=no mincounts=25 withCounts=yes minSN=5 withminSN=no ratioabovebgnd=0 withratioabovebgnd=no oversample=3 withoversampling=yes grouptemplate=grptemplate.ds withtemplate=no ranges='' withranges=no regbinstart=0 regbinend=0 regbinwid=0 withRegularBins=no units=CHAN rmfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.rmf withrmfset=yes arfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.arf witharfset=yes addfilenames=yes hightolow=no lastbin=addtogroup setbad=CCF  -w 1 -V 4
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:26:59.000
# specgroup:- Prepared spectrum /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673310879.9999998_32-36_40-44.fits with 237 groups
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:27:00.000
# Warning: No need to include withspecranges. Assumed withspecranges=yes
# Executing:
# evselect table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44]) && (TIME >= 673367039.9999999) && (TIME <= 673382591.9999999)' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits' spectralbinsize='5' withspecranges='yes' specchannelmin='0' specchannelmax='20479' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44]) && (TIME >= 673367039.9999999) && (TIME <= 673382591.9999999)' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits spectralbinsize=5 specchannelmin=0 specchannelmax=20479 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:27:00.000
# evselect:- selected 725917 rows from the input table.
# ** evselect: warning (DifferentAttributeValues), Attribute `TIMESYS' has different value in `/tmp/file5yvco4:STDGTI04' (TDB) and `/tmp/fileddTRv7:GTI00003' (TT) - please make sure it makes sense to merge the GTI tables
# ** evselect: warning (ExpBadDssGlobal), A filtering expression has been specified which may not allow for calculation of a uniform exposure for all events.  Please ensure that all TIME related filters are applied uniformly.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:27:05.000
# ** evselect: warning (SummaryOfWarnings),
#    warning DifferentAttributeValues silently occurred 3 times
# Executing:
# backscale spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits' badpixlocation='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:27:06.000
# backscale:- Executing (routine): arfgen spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:27:06.000
# backscale::arfgen:- Opening spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits...
# backscale::arfgen:- Closing spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# backscale::arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-8545 xmax=8635 xbins=1 ymin=-1065 ymax=15454 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# ** backscale::arfgen: warning (zeroSumDetmap), The filtered detector map has a zero normalisation - returning zero area. Try using a flat detector map and/or more bins
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0.1429431873 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits...
# backscale::arfgen:- Opened spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits...
# backscale::arfgen:- Opened table /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits...
# backscale::arfgen:- Backscale value is: 13407164
# backscale::arfgen:- added att/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits...
# backscale::arfgen:- closed spec/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:27:35.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:27:35.000
# Executing:
# rmfgen rmfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.rmf' threshold='1e-06' withenergybins='no' energymin='0' energymax='15' nenergybins='30' spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits' format='var' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='yes' detxbins='160' detybins='160' correctforpileup='no' raweventfile='rawevents.ds' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withrmfset='no' psfenergy='2' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='no' modelquantumeff='no' modelfiltertrans='no' modelcontamination='no' modelee='yes' modelootcorr='no' eegridfactor='100' withbadpixcorr='no' badpixlocation='notSpecified' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset='' psfmodel='notSpecified' withbadpixres='no' badpixelresolution='2' applyxcaladjustment='no' acceptchanrange='no' applyabsfluxcorr='no'
# rmfgen:- Executing (routine): rmfgen rmfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.rmf threshold=1e-06 withenergybins=no energymin=0 energymax=15 nenergybins=30 spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits format=var detmaptype=psf detmaparray=detmapfile.ds: withdetbounds=no detxoffset=1200 detyoffset=1200 detxbins=160 detybins=160 withdetbins=yes raweventfile=rawevents.ds correctforpileup=no filterdss=yes withfilteredset=no filteredset=filteredpixellist.ds withrmfset=no psfenergy=2 withsourcepos=no sourcecoords=eqpos sourcex=0 sourcey=0 extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=no modelee=yes modelootcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no psfmodel=notSpecified badpixelresolution=2 withbadpixres=no applyxcaladjustment=no acceptchanrange=no applyabsfluxcorr=no  -w 1 -V 4
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:27:35.000
# Set to: notSpecified
# rmfgen:- Opening spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits...
# rmfgen:- Closing spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits.
# rmfgen:- Computing source position from region extent..
# rmfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# rmfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# rmfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# rmfgen:- detector map binning will be: xbins: 160 ybins: 160
# rmfgen:- Constructing a psf detector map with  xmin=-8545 xmax=8635 xbins=160 ymin=-1065 ymax=15454 ybins=160
# rmfgen:- PSF type: 5 [HIGH] will be used
# rmfgen:-  Creating RmfDataServer...
# rmfgen:-  EventGrades:4 FastTiming 37
# rmfgen:-  RmfDataServer created ok.
# rmfgen:- Opening data set ...
# rmfgen:- Opened data set.
# rmfgen:- Adding MATRIX table. There will be 2067 rows in table
# rmfgen:- Initialising table iterator ..
# rmfgen:- Populating table ..
# rmfgen:- Adding EBOUNDS extension ...
# rmfgen:-  Cleanup ...
# rmfgen:-  Closing data set ...
# rmfgen:-  Closed data set.
# rmfgen:-  Cleanup complete.
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:28:17.000
# Executing:
# arfgen spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits' withrmfset='yes' rmfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.rmf' arfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.arf' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='no' detxbins='5' detybins='5' psfenergy='2' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='yes' modelquantumeff='yes' modelfiltertrans='yes' modelcontamination='yes' modelee='yes' modelootcorr='yes' applyxcaladjustment='no' applyabsfluxcorr='yes' eegridfactor='100' withbadpixcorr='yes' badpixlocation='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' psfmodel='ELLBETA' withbadpixres='no' badpixelresolution='2' badpixmaptype='flat' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset=''
# arfgen:- Executing (routine): arfgen spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits rmfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.rmf withrmfset=yes arfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.arf detmaptype=psf detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=yes eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:28:17.000
# arfgen:- Opening spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits...
# arfgen:- Closing spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits.
# arfgen:- Computing source position from region extent..
# arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# arfgen:- detector map binning will be: xbins: 57 ybins: 55
# arfgen:- Constructing a psf detector map with  xmin=-8545 xmax=8635 xbins=57 ymin=-1065 ymax=15454 ybins=55
# arfgen:- PSF type: 3 [ELLBETA] will be used
# arfgen:- Opening arfset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.arf...
# Making file temp_badcol.ds
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- Writing energy data into dataset ..
# arfgen:- Calculating Area curve ...
# arfgen:- Calculating Area curve ...50.4999999 2067 15997.49947
# arfgen:- Bad pixel & chip gap fraction: ~0.4448886274 %
# arfgen:- Writing area data into dataset ..
# arfgen:- Closing arfset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.arf.
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:35:44.000
# Executing:
# specgroup spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits' overwrite='no' groupedset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673367039.9999999_32-36_40-44.fits' withbgdset='no' backgndset='' withCounts='yes' mincounts='25' withminSN='no' minSN='5' withratioabovebgnd='no' ratioabovebgnd='' withoversampling='yes' oversample='3' withtemplate='no' grouptemplate='grptemplate.ds' withranges='no' ranges='' withRegularBins='no' regbinstart='' regbinend='' regbinwid='' units='CHAN' withrmfset='yes' rmfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.rmf' witharfset='yes' arfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.arf' addfilenames='yes' hightolow='no' lastbin='addtogroup' setbad='CCF'
# specgroup:- Executing (routine): specgroup spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673367039.9999999_32-36_40-44.fits groupedset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673367039.9999999_32-36_40-44.fits overwrite=no backgndset='' withbgdset=no mincounts=25 withCounts=yes minSN=5 withminSN=no ratioabovebgnd=0 withratioabovebgnd=no oversample=3 withoversampling=yes grouptemplate=grptemplate.ds withtemplate=no ranges='' withranges=no regbinstart=0 regbinend=0 regbinwid=0 withRegularBins=no units=CHAN rmfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.rmf withrmfset=yes arfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.arf witharfset=yes addfilenames=yes hightolow=no lastbin=addtogroup setbad=CCF  -w 1 -V 4
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:35:44.000
# specgroup:- Prepared spectrum /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673367039.9999999_32-36_40-44.fits with 233 groups
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:35:44.000
# Warning: No need to include withspecranges. Assumed withspecranges=yes
# Executing:
# evselect table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44]) && (TIME >= 673382591.9999999) && (TIME <= 673418879.9999998)' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits' spectralbinsize='5' withspecranges='yes' specchannelmin='0' specchannelmax='20479' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44]) && (TIME >= 673382591.9999999) && (TIME <= 673418879.9999998)' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits spectralbinsize=5 specchannelmin=0 specchannelmax=20479 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:35:44.000
# evselect:- selected 1174892 rows from the input table.
# ** evselect: warning (DifferentAttributeValues), Attribute `TIMESYS' has different value in `/tmp/filek42yrm:STDGTI04' (TDB) and `/tmp/fileSwIMcj:GTI00003' (TT) - please make sure it makes sense to merge the GTI tables
# ** evselect: warning (ExpBadDssGlobal), A filtering expression has been specified which may not allow for calculation of a uniform exposure for all events.  Please ensure that all TIME related filters are applied uniformly.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:35:51.000
# ** evselect: warning (SummaryOfWarnings),
#    warning DifferentAttributeValues silently occurred 3 times
# Executing:
# backscale spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits' badpixlocation='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:35:51.000
# backscale:- Executing (routine): arfgen spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:35:51.000
# backscale::arfgen:- Opening spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits...
# backscale::arfgen:- Closing spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# backscale::arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-8545 xmax=8635 xbins=1 ymin=-1065 ymax=15454 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# ** backscale::arfgen: warning (zeroSumDetmap), The filtered detector map has a zero normalisation - returning zero area. Try using a flat detector map and/or more bins
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0.1429431873 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits...
# backscale::arfgen:- Opened spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits...
# backscale::arfgen:- Opened table /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits...
# backscale::arfgen:- Backscale value is: 13407164
# backscale::arfgen:- added att/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits...
# backscale::arfgen:- closed spec/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:36:20.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:36:20.000
# Executing:
# rmfgen rmfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.rmf' threshold='1e-06' withenergybins='no' energymin='0' energymax='15' nenergybins='30' spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits' format='var' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='yes' detxbins='160' detybins='160' correctforpileup='no' raweventfile='rawevents.ds' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withrmfset='no' psfenergy='2' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='no' modelquantumeff='no' modelfiltertrans='no' modelcontamination='no' modelee='yes' modelootcorr='no' eegridfactor='100' withbadpixcorr='no' badpixlocation='notSpecified' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset='' psfmodel='notSpecified' withbadpixres='no' badpixelresolution='2' applyxcaladjustment='no' acceptchanrange='no' applyabsfluxcorr='no'
# rmfgen:- Executing (routine): rmfgen rmfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.rmf threshold=1e-06 withenergybins=no energymin=0 energymax=15 nenergybins=30 spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits format=var detmaptype=psf detmaparray=detmapfile.ds: withdetbounds=no detxoffset=1200 detyoffset=1200 detxbins=160 detybins=160 withdetbins=yes raweventfile=rawevents.ds correctforpileup=no filterdss=yes withfilteredset=no filteredset=filteredpixellist.ds withrmfset=no psfenergy=2 withsourcepos=no sourcecoords=eqpos sourcex=0 sourcey=0 extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=no modelee=yes modelootcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no psfmodel=notSpecified badpixelresolution=2 withbadpixres=no applyxcaladjustment=no acceptchanrange=no applyabsfluxcorr=no  -w 1 -V 4
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:36:20.000
# Set to: notSpecified
# rmfgen:- Opening spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits...
# rmfgen:- Closing spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits.
# rmfgen:- Computing source position from region extent..
# rmfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# rmfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# rmfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# rmfgen:- detector map binning will be: xbins: 160 ybins: 160
# rmfgen:- Constructing a psf detector map with  xmin=-8545 xmax=8635 xbins=160 ymin=-1065 ymax=15454 ybins=160
# rmfgen:- PSF type: 5 [HIGH] will be used
# rmfgen:-  Creating RmfDataServer...
# rmfgen:-  EventGrades:4 FastTiming 37
# rmfgen:-  RmfDataServer created ok.
# rmfgen:- Opening data set ...
# rmfgen:- Opened data set.
# rmfgen:- Adding MATRIX table. There will be 2067 rows in table
# rmfgen:- Initialising table iterator ..
# rmfgen:- Populating table ..
# rmfgen:- Adding EBOUNDS extension ...
# rmfgen:-  Cleanup ...
# rmfgen:-  Closing data set ...
# rmfgen:-  Closed data set.
# rmfgen:-  Cleanup complete.
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:37:02.000
# Executing:
# arfgen spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits' withrmfset='yes' rmfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.rmf' arfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.arf' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='no' detxbins='5' detybins='5' psfenergy='2' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='yes' modelquantumeff='yes' modelfiltertrans='yes' modelcontamination='yes' modelee='yes' modelootcorr='yes' applyxcaladjustment='no' applyabsfluxcorr='yes' eegridfactor='100' withbadpixcorr='yes' badpixlocation='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' psfmodel='ELLBETA' withbadpixres='no' badpixelresolution='2' badpixmaptype='flat' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset=''
# arfgen:- Executing (routine): arfgen spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits rmfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.rmf withrmfset=yes arfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.arf detmaptype=psf detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=yes eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:37:02.000
# arfgen:- Opening spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits...
# arfgen:- Closing spectrumset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits.
# arfgen:- Computing source position from region extent..
# arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# arfgen:- detector map binning will be: xbins: 57 ybins: 55
# arfgen:- Constructing a psf detector map with  xmin=-8545 xmax=8635 xbins=57 ymin=-1065 ymax=15454 ybins=55
# arfgen:- PSF type: 3 [ELLBETA] will be used
# arfgen:- Opening arfset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.arf...
# Making file temp_badcol.ds
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- Writing energy data into dataset ..
# arfgen:- Calculating Area curve ...
# arfgen:- Calculating Area curve ...50.4999999 2067 15997.49947
# arfgen:- Bad pixel & chip gap fraction: ~0.4448886274 %
# arfgen:- Writing area data into dataset ..
# arfgen:- Closing arfset /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.arf.
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:44:27.000
# Executing:
# specgroup spectrumset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits' overwrite='no' groupedset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673382591.9999999_32-36_40-44.fits' withbgdset='no' backgndset='' withCounts='yes' mincounts='25' withminSN='no' minSN='5' withratioabovebgnd='no' ratioabovebgnd='' withoversampling='yes' oversample='3' withtemplate='no' grouptemplate='grptemplate.ds' withranges='no' ranges='' withRegularBins='no' regbinstart='' regbinend='' regbinwid='' units='CHAN' withrmfset='yes' rmfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.rmf' witharfset='yes' arfset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.arf' addfilenames='yes' hightolow='no' lastbin='addtogroup' setbad='CCF'
# specgroup:- Executing (routine): specgroup spectrumset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_spectrum_raw_673382591.9999999_32-36_40-44.fits groupedset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673382591.9999999_32-36_40-44.fits overwrite=no backgndset='' withbgdset=no mincounts=25 withCounts=yes minSN=5 withminSN=no ratioabovebgnd=0 withratioabovebgnd=no oversample=3 withoversampling=yes grouptemplate=grptemplate.ds withtemplate=no ranges='' withranges=no regbinstart=0 regbinend=0 regbinwid=0 withRegularBins=no units=CHAN rmfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.rmf withrmfset=yes arfset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.arf witharfset=yes addfilenames=yes hightolow=no lastbin=addtogroup setbad=CCF  -w 1 -V 4
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T07:44:27.000
# specgroup:- Prepared spectrum /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673382591.9999999_32-36_40-44.fits with 236 groups
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T07:44:27.000
# ['/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673310879.9999998_32-36_40-44.fits', '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673367039.9999999_32-36_40-44.fits', '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673382591.9999999_32-36_40-44.fits']

# %% [markdown]
# From the final list printed above we can see the names of the grouped spectrum files, we list them below:

# %%
phase1 = '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673310879.9999998_32-36_40-44.fits'
phase2 = '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673367039.9999999_32-36_40-44.fits'
phase3 = '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673382591.9999999_32-36_40-44.fits'

# %% [markdown]
# Now we can visualise them using pyxspec.

# %%
# Before you start, clear all data and models

AllModels.clear()  # Clear all models
AllData.clear()    # Clear all data

# %%
# Load the group spectral file

# The group file already contains in the header the names of all the necessary files needed by xspec
# (source and background spectra, response and ancillery files)

data1 = Spectrum(phase1)  # load spectra groupped file
data2 = Spectrum(phase2)
data3 = Spectrum(phase3)

AllData.show()                # inspect loaded data
# Out:
# 1 spectrum  in use
#
# Spectral Data File: /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673310879.9999998_32-36_40-44.fits  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  5.989e+01 +/- 3.299e-02
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-237
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 5.501e+04 sec
#  Using fit statistic: chi
#  Using Response (RMF) File            /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.rmf for Source 1
#  Using Auxiliary Response (ARF) File  /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.arf
#
#
# 2 spectra  in use
#
# Spectral Data File: /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673367039.9999999_32-36_40-44.fits  Spectrum 2
# Net count rate (cts/s) for Spectrum:2  4.693e+01 +/- 5.532e-02
#  Assigned to Data Group 1 and Plot Group 2
#   Noticed Channels:  1-233
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.533e+04 sec
#  Using fit statistic: chi
#  Using Response (RMF) File            /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.rmf for Source 1
#  Using Auxiliary Response (ARF) File  /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.arf
#
#
# 3 spectra  in use
#
# Spectral Data File: /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673382591.9999999_32-36_40-44.fits  Spectrum 3
# Net count rate (cts/s) for Spectrum:3  3.246e+01 +/- 3.014e-02
#  Assigned to Data Group 1 and Plot Group 3
#   Noticed Channels:  1-236
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 3.574e+04 sec
#  Using fit statistic: chi
#  Using Response (RMF) File            /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.rmf for Source 1
#  Using Auxiliary Response (ARF) File  /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.arf
#
#
# 3 files 3 spectra
# Spectrum 1  Spectral Data File: /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673310879.9999998_32-36_40-44.fits
# Net count rate (cts/s) for Spectrum:1  5.989e+01 +/- 3.299e-02
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-237
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 5.501e+04 sec
#  Using fit statistic: chi
#  Using Response (RMF) File            /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.rmf for Source 1
#  Using Auxiliary Response (ARF) File  /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673310879.9999998_32-36_40-44.arf
#
# Spectrum 2  Spectral Data File: /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673367039.9999999_32-36_40-44.fits
# Net count rate (cts/s) for Spectrum:2  4.693e+01 +/- 5.532e-02
#  Assigned to Data Group 1 and Plot Group 2
#   Noticed Channels:  1-233
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 1.533e+04 sec
#  Using fit statistic: chi
#  Using Response (RMF) File            /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.rmf for Source 1
#  Using Auxiliary Response (ARF) File  /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673367039.9999999_32-36_40-44.arf
#
# Spectrum 3  Spectral Data File: /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_spectrum_grp_673382591.9999999_32-36_40-44.fits
# Net count rate (cts/s) for Spectrum:3  3.246e+01 +/- 3.014e-02
#  Assigned to Data Group 1 and Plot Group 3
#   Noticed Channels:  1-236
#   Telescope: XMM Instrument: EPN  Channel Type: PI
#   Exposure Time: 3.574e+04 sec
#  Using fit statistic: chi
#  Using Response (RMF) File            /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.rmf for Source 1
#  Using Auxiliary Response (ARF) File  /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_673382591.9999999_32-36_40-44.arf

# %% [markdown]
# For swift visualisation, we can use the the custom made Python function available in the file xspecplot.py. It will require a list of the spectrum data given to xspec only, the rest can be changed if customisation is required by the user:
# ```
# xspecplot(data, xAxis="keV", xLog=True, yLog=True, figname="multiple-spectra.png")
# ```

# %%
xspecplot([data1, data2, data3], xAxis="keV", xLog=True, yLog=True)

# %% [markdown]
# * ### Energy-resolved light curves

# %% [markdown]
# At the spectra produced above, 4 energy bands of interest have been marked with the vertical red dashed line:
# * 0.5-3.0 keV
# * 3.0-6.0 keV
# * 6.0-8.0 keV
# * 8.0-10.0 keV
#
# We can extract light curves for the each band of interest for further analysis of variability in photon count rates. Instead of running all the tasks one by one as in the previous section named `Extracting Average Light Curve`, we have written a Python script to automatise the process and run it for our selected ranges. The script is present underthe name `energy-resolvedLC.py`, which we run below:

# %%
# !python3 /media/user/Vela-work/XMM-SAS-Datalabs-Paper/scripts/energy-resolvedLC.py
# Out:
# startsas - WARNING - Executing /usr/local/SAS/xmmsas_20230412_1735/lib/python/pysas/startsas/startsas.py {'odfid': '', 'workdir': '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan', 'sasfiles': 'yes', 'sas_ccf': '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif', 'sas_odf': '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS', 'level': 'ODF', 'cifbuild_opts': '', 'odfingest_opts': ''}
#
#
#         Starting SAS session
#
#         Working directory = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan
#
#
# SAS_CCF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif
# SAS_ODF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS
# Executing:
# evselect table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EP&&(PATTERN<=4)&&(RAWX in [32:36] || RAWX in [40:44])&&(PI in [500:3000])' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='no' spectrumset='spectrum.fits' spectralbinsize='5' withspecranges='no' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='yes' rateset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_500to3000eV_bin283sec.lc' timecolumn='TIME' timebinsize='283' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='yes' makeratecolumn='yes' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EP&&(PATTERN<=4)&&(RAWX in [32:36] || RAWX in [40:44])&&(PI in [500:3000])' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_500to3000eV_bin283sec.lc timecolumn=TIME timebinsize=283 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=yes makeratecolumn=yes withrateset=yes histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:32:47.000
# evselect:- selected 823765 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:32:53.000
# Executing:
# evselect table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EP&&(PATTERN<=4)&&(RAWX in [3:5])&&(PI in [500:3000])' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='no' spectrumset='spectrum.fits' spectralbinsize='5' withspecranges='no' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='yes' rateset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_500to3000eV_bin283sec.lc' timecolumn='TIME' timebinsize='283' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='yes' makeratecolumn='yes' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EP&&(PATTERN<=4)&&(RAWX in [3:5])&&(PI in [500:3000])' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_500to3000eV_bin283sec.lc timecolumn=TIME timebinsize=283 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=yes makeratecolumn=yes withrateset=yes histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:32:53.000
# evselect:- selected 5241 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:32:58.000
# Executing:
# epiclccorr srctslist='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_500to3000eV_bin283sec.lc' eventlist='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' outset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_500to3000eV_bin283sec.lc' withbkgset='yes' bkgtslist='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_500to3000eV_bin283sec.lc' applyabsolutecorrections='yes' withdetbins='no' detxbins='5' detybins='5' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' allcamera='no'
# epiclccorr:- Executing (routine): epiclccorr srctslist=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_500to3000eV_bin283sec.lc eventlist=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits outset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_500to3000eV_bin283sec.lc bkgtslist=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_500to3000eV_bin283sec.lc withbkgset=yes detxbins=5 detybins=5 withdetbins=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no applyabsolutecorrections=yes allcamera=no  -w 1 -V 4
# epiclccorr:- epiclccorr (epiclccorr-1.23.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:32:58.000
# epiclccorr:- selected 5416690 rows from the source input table.
# epiclccorr:- Closing event file dataset
# epiclccorr:- Extraction region lies in CCD number 4
# epiclccorr:- Calculating the relative corrections for each CCD...
# epiclccorr:- STDGTI04 extension found
# epiclccorr:- Processing GTI extension: STDGTI04 corresponding to CCD 4
# epiclccorr:- STDGTI04 extension found
# epiclccorr:- Processing GTI extension: STDGTI04 corresponding to CCD 4
# epiclccorr:- Doing GTI Correction...
# epiclccorr:- GTI Extension[STDGTI04]
# epiclccorr:- GTI Extension[STDGTI04]
# epiclccorr:- Done.
# epiclccorr:- Doing Exposure and Dead Time Correction: /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EXPOSU04
# ** epiclccorr: warning (PNTimingRand), Randomization for PN Timing or Burst not implemented
# epiclccorr:- closing data set /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits
# epiclccorr:- Exposure Correction Done.
# epiclccorr:- Relative Corrections Done.
# epiclccorr:- Calculating spectrum...
# epiclccorr:- Executing (invoked): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='( CCDNR in [4] && gti(/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_500to3000eV_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [32:36] && PI in [500:) ) || ( CCDNR in [4] && gti(/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_500to3000eV_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [40:44] && PI in [500:) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc spectralbinsize=50 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# epiclccorr:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:34:08.000
# epiclccorr::evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='( CCDNR in [4] && gti(/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_500to3000eV_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [32:36] && PI in [500:) ) || ( CCDNR in [4] && gti(/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_500to3000eV_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [40:44] && PI in [500:) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc spectralbinsize=50 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# epiclccorr::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:34:08.000
# epiclccorr::evselect:- selected 5416690 rows from the input table.
# ** epiclccorr::evselect: warning (ExpBadDssGlobal), A filtering expression has been specified which may not allow for calculation of a uniform exposure for all events.  Please ensure that all TIME related filters are applied uniformly.
# ** epiclccorr::evselect: warning (NonStandardSpectrum), The standard PI channel range for PN is 0-20479. Detector matrices can not be created for this spectrum and spectral fitting will not be possible.
# epiclccorr::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:34:33.000
# epiclccorr:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:34:33.000
# epiclccorr:- Done.
# epiclccorr:- Calculating arfgen...
# epiclccorr:- Executing (invoked): arfgen spectrumset=spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc rmfset=response.ds withrmfset=no arfset=src_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:34:33.000
# epiclccorr::arfgen:- Executing (routine): arfgen spectrumset=spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc rmfset=response.ds withrmfset=no arfset=src_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:34:33.000
# epiclccorr::arfgen:- Opening spectrumset spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- Closing spectrumset spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc.
# epiclccorr::arfgen:- Computing source position from region extent..
# epiclccorr::arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# epiclccorr::arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# epiclccorr::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# epiclccorr::arfgen:- detector map binning will be: xbins: 57 ybins: 55
# epiclccorr::arfgen:- Constructing a flat detector map with  xmin=-8545 xmax=8635 xbins=57 ymin=-1065 ymax=15454 ybins=55
# epiclccorr::arfgen:- PSF type: 3 [ELLBETA] will be used
# epiclccorr::arfgen:- Opening arfset src_ancillary.ds...
# Making file temp_badcol.ds
# epiclccorr::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# epiclccorr::arfgen:- Writing energy data into dataset ..
# epiclccorr::arfgen:- Calculating Area curve ...
# epiclccorr::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# epiclccorr::arfgen:- Bad pixel & chip gap fraction: ~0.4448886274 %
# epiclccorr::arfgen:- Writing area data into dataset ..
# epiclccorr::arfgen:- Closing arfset src_ancillary.ds.
# epiclccorr::arfgen:- Opening spectrumset spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- Opened spectrumset spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- Opened table spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- current backscale value is: 1
# epiclccorr::arfgen:- deleted attspectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- Backscale value is: 13472764
# epiclccorr::arfgen:- added attspectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- closed specspectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:35:03.000
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:35:03.000
# epiclccorr:- Done.
# epiclccorr:- Reading Spectrum... spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc
# epiclccorr:- Reading ancillary file... spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc
# epiclccorr:- Done.
# epiclccorr:- Calculating arfgen...
# epiclccorr:- Executing (invoked): arfgen spectrumset=spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc rmfset=response.ds withrmfset=no arfset=on_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=yes detxbins=1 detybins=1 withdetbins=no psfenergy=2 filterdss=no filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=tel sourcex=0 sourcey=0 withsourcepos=yes extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:35:03.000
# epiclccorr::arfgen:- Executing (routine): arfgen spectrumset=spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc rmfset=response.ds withrmfset=no arfset=on_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=yes detxbins=1 detybins=1 withdetbins=no psfenergy=2 filterdss=no filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=tel sourcex=0 sourcey=0 withsourcepos=yes extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:35:03.000
# epiclccorr::arfgen:- Opening spectrumset spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- Closing spectrumset spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc.
# epiclccorr::arfgen:- Using a source position in TEL coordinates of x=0 y=0
# epiclccorr::arfgen:- This corresponds to a position in DET coordinates of DETX=1283.63 DETY=382.834
# epiclccorr::arfgen:-  The source position in focal plane coords is  theta=0 phi=0
# epiclccorr::arfgen:- Taking detector map bounds from the parameters detxoffset and detyoffset ...
# epiclccorr::arfgen:- detector map binning will be: xbins: 8 ybins: 8
# epiclccorr::arfgen:- Constructing a flat detector map with  xmin=83.63452736 xmax=2483.634527 xbins=8 ymin=-817.1664529 ymax=1582.833547 ybins=8
# epiclccorr::arfgen:- Opening arfset on_ancillary.ds...
# epiclccorr::arfgen:- Writing energy data into dataset ..
# epiclccorr::arfgen:- Calculating Area curve ...
# epiclccorr::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# epiclccorr::arfgen:- Bad pixel & chip gap fraction: ~0 %
# epiclccorr::arfgen:- Writing area data into dataset ..
# epiclccorr::arfgen:- Closing arfset on_ancillary.ds.
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:35:08.000
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:35:08.000
# epiclccorr:- Done.
# epiclccorr:- Reading ancillary file... spectrum_PN_source_lightcurve_raw_500to3000eV_bin283sec.lc
# epiclccorr:- Done.
# epiclccorr:- Weighted Mean 3.408936305320330984
# epiclccorr:- selected 30717 rows from the source input table.
# epiclccorr:- Closing event file dataset
# epiclccorr:- Extraction region lies in CCD number 4
# epiclccorr:- Calculating the relative corrections for each CCD...
# epiclccorr:- STDGTI04 extension found
# epiclccorr:- Processing GTI extension: STDGTI04 corresponding to CCD 4
# epiclccorr:- Doing GTI Correction...
# epiclccorr:- GTI Extension[STDGTI04]
# epiclccorr:- Done.
# epiclccorr:- Doing Exposure and Dead Time Correction: /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EXPOSU04
# epiclccorr:- closing data set /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits
# epiclccorr:- Exposure Correction Done.
# epiclccorr:- Relative Corrections Done.
# epiclccorr:- Calculating spectrum...
# epiclccorr:- Executing (invoked): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='( CCDNR in [4] && gti(/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_500to3000eV_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [3:5] && PI in [500:) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum_PN_lightcurve_background_raw_500to3000eV_bin283sec.lc spectralbinsize=50 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# epiclccorr:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:36:09.000
# epiclccorr::evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='( CCDNR in [4] && gti(/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_500to3000eV_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [3:5] && PI in [500:) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum_PN_lightcurve_background_raw_500to3000eV_bin283sec.lc spectralbinsize=50 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# epiclccorr::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:36:09.000
# epiclccorr::evselect:- selected 30717 rows from the input table.
# ** epiclccorr::evselect: warning (NonStandardSpectrum), The standard PI channel range for PN is 0-20479. Detector matrices can not be created for this spectrum and spectral fitting will not be possible.
# epiclccorr::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:36:25.000
# epiclccorr:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:36:25.000
# epiclccorr:- Done.
# epiclccorr:- Calculating arfgen...
# epiclccorr:- Executing (invoked): arfgen spectrumset=spectrum_PN_lightcurve_background_raw_500to3000eV_bin283sec.lc rmfset=response.ds withrmfset=no arfset=bkg_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=yes modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:36:25.000
# epiclccorr::arfgen:- Executing (routine): arfgen spectrumset=spectrum_PN_lightcurve_background_raw_500to3000eV_bin283sec.lc rmfset=response.ds withrmfset=no arfset=bkg_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=yes modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:36:25.000
# epiclccorr::arfgen:- Opening spectrumset spectrum_PN_lightcurve_background_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- Closing spectrumset spectrum_PN_lightcurve_background_raw_500to3000eV_bin283sec.lc.
# epiclccorr::arfgen:- Computing source position from region extent..
# epiclccorr::arfgen:- Using a source position in DET coordinates of x=2852 y=-195.132
# epiclccorr::arfgen:-  The source position in focal plane coords is  theta=83.5677 phi=5.93011
# epiclccorr::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# epiclccorr::arfgen:- detector map binning will be: xbins: 55 ybins: 55
# epiclccorr::arfgen:- Constructing a flat detector map with  xmin=-5406 xmax=11110 xbins=55 ymin=-1064 ymax=15453 ybins=55
# epiclccorr::arfgen:- Opening arfset bkg_ancillary.ds...
# Making file temp_badcol.ds
# epiclccorr::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# epiclccorr::arfgen:- Writing energy data into dataset ..
# epiclccorr::arfgen:- Calculating Area curve ...
# epiclccorr::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# epiclccorr::arfgen:- Bad pixel & chip gap fraction: ~0.5690072639 %
# epiclccorr::arfgen:- Writing area data into dataset ..
# epiclccorr::arfgen:- Closing arfset bkg_ancillary.ds.
# epiclccorr::arfgen:- Opening spectrumset spectrum_PN_lightcurve_background_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- Opened spectrumset spectrum_PN_lightcurve_background_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- Opened table spectrum_PN_lightcurve_background_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- current backscale value is: 1
# epiclccorr::arfgen:- deleted attspectrum_PN_lightcurve_background_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- Backscale value is: 3942240
# epiclccorr::arfgen:- added attspectrum_PN_lightcurve_background_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- closed specspectrum_PN_lightcurve_background_raw_500to3000eV_bin283sec.lc...
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:36:27.000
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:36:27.000
# epiclccorr:- Done.
# epiclccorr:- Reading Spectrum... spectrum_PN_lightcurve_background_raw_500to3000eV_bin283sec.lc
# epiclccorr:- Substracting background...
# epiclccorr:- Checking Source and Background Binning
# epiclccorr:- Source Start Time: 673308775.717167
# epiclccorr:- Background Start Time: 673308775.717167
# epiclccorr:- Source Stop Time: 673420277.717167
# epiclccorr:- Background Stop Time: 673420277.717167
# epiclccorr:- Source BACKSCALE: 13472764
# epiclccorr:- Background BACKSCALE: 3942240
# epiclccorr:- Done.
# epiclccorr:- Applying Absolute Correction...
# epiclccorr:- Done.
# epiclccorr:- Creating SRC_GTIS GTIs...
# epiclccorr:- Done.
# epiclccorr:- Creating BKG_GTIS GTIs...
# epiclccorr:- Done.
# epiclccorr:- Removing GTI information from DSS...
# epiclccorr:- Done
# epiclccorr:- Extracting PI information from DSS...
# epiclccorr:- Done
# epiclccorr:- LightCurve Destructor
# epiclccorr:- Done
# epiclccorr:- LightCurve Destructor
# epiclccorr:- Done
# epiclccorr:- epiclccorr (epiclccorr-1.23.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:36:27.000
# ** epiclccorr: warning (SummaryOfWarnings),
#    warning PNTimingRand silently occurred 1 times
# Executing:
# evselect table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EP&&(PATTERN<=4)&&(RAWX in [32:36] || RAWX in [40:44])&&(PI in [3000:6000])' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='no' spectrumset='spectrum.fits' spectralbinsize='5' withspecranges='no' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='yes' rateset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_3000to6000eV_bin283sec.lc' timecolumn='TIME' timebinsize='283' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='yes' makeratecolumn='yes' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EP&&(PATTERN<=4)&&(RAWX in [32:36] || RAWX in [40:44])&&(PI in [3000:6000])' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_3000to6000eV_bin283sec.lc timecolumn=TIME timebinsize=283 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=yes makeratecolumn=yes withrateset=yes histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:36:27.000
# evselect:- selected 2529131 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:36:35.000
# Executing:
# evselect table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='#XMMEA_EP&&(PATTERN<=4)&&(RAWX in [3:5])&&(PI in [3000:6000])' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='no' spectrumset='spectrum.fits' spectralbinsize='5' withspecranges='no' specchannelmin='0' specchannelmax='11999' nonStandardSpec='no' withrateset='yes' rateset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_3000to6000eV_bin283sec.lc' timecolumn='TIME' timebinsize='283' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='yes' makeratecolumn='yes' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='#XMMEA_EP&&(PATTERN<=4)&&(RAWX in [3:5])&&(PI in [3000:6000])' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum.fits spectralbinsize=5 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=no rateset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_3000to6000eV_bin283sec.lc timecolumn=TIME timebinsize=283 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=yes makeratecolumn=yes withrateset=yes histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:36:35.000
# evselect:- selected 11837 rows from the input table.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:36:40.000
# Executing:
# epiclccorr srctslist='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_3000to6000eV_bin283sec.lc' eventlist='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' outset='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_3000to6000eV_bin283sec.lc' withbkgset='yes' bkgtslist='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_3000to6000eV_bin283sec.lc' applyabsolutecorrections='yes' withdetbins='no' detxbins='5' detybins='5' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' allcamera='no'
# epiclccorr:- Executing (routine): epiclccorr srctslist=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_3000to6000eV_bin283sec.lc eventlist=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits outset=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_3000to6000eV_bin283sec.lc bkgtslist=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_3000to6000eV_bin283sec.lc withbkgset=yes detxbins=5 detybins=5 withdetbins=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no applyabsolutecorrections=yes allcamera=no  -w 1 -V 4
# epiclccorr:- epiclccorr (epiclccorr-1.23.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:36:40.000
# epiclccorr:- selected 4593539 rows from the source input table.
# epiclccorr:- Closing event file dataset
# epiclccorr:- Extraction region lies in CCD number 4
# epiclccorr:- Calculating the relative corrections for each CCD...
# epiclccorr:- STDGTI04 extension found
# epiclccorr:- Processing GTI extension: STDGTI04 corresponding to CCD 4
# epiclccorr:- STDGTI04 extension found
# epiclccorr:- Processing GTI extension: STDGTI04 corresponding to CCD 4
# epiclccorr:- Doing GTI Correction...
# epiclccorr:- GTI Extension[STDGTI04]
# epiclccorr:- GTI Extension[STDGTI04]
# epiclccorr:- Done.
# epiclccorr:- Doing Exposure and Dead Time Correction: /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EXPOSU04
# ** epiclccorr: warning (PNTimingRand), Randomization for PN Timing or Burst not implemented
# epiclccorr:- closing data set /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits
# epiclccorr:- Exposure Correction Done.
# epiclccorr:- Relative Corrections Done.
# epiclccorr:- Calculating spectrum...
# epiclccorr:- Executing (invoked): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='( CCDNR in [4] && gti(/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_3000to6000eV_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [32:36] && PI in [3000:) ) || ( CCDNR in [4] && gti(/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_3000to6000eV_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [40:44] && PI in [3000:) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum_PN_source_lightcurve_raw_3000to6000eV_bin283sec.lc spectralbinsize=50 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# epiclccorr:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:37:51.000
# epiclccorr::evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='( CCDNR in [4] && gti(/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_3000to6000eV_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [32:36] && PI in [3000:) ) || ( CCDNR in [4] && gti(/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_source_lightcurve_raw_3000to6000eV_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [40:44] && PI in [3000:) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum_PN_source_lightcurve_raw_3000to6000eV_bin283sec.lc spectralbinsize=50 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# epiclccorr::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:37:51.000
# epiclccorr::evselect:- selected 4593539 rows from the input table.
# ** epiclccorr::evselect: warning (ExpBadDssGlobal), A filtering expression has been specified which may not allow for calculation of a uniform exposure for all events.  Please ensure that all TIME related filters are applied uniformly.
# ** epiclccorr::evselect: warning (NonStandardSpectrum), The standard PI channel range for PN is 0-20479. Detector matrices can not be created for this spectrum and spectral fitting will not be possible.
# epiclccorr::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:38:15.000
# epiclccorr:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:38:15.000
# epiclccorr:- Done.
# epiclccorr:- Calculating arfgen...
# epiclccorr:- Executing (invoked): arfgen spectrumset=spectrum_PN_source_lightcurve_raw_3000to6000eV_bin283sec.lc rmfset=response.ds withrmfset=no arfset=src_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:38:15.000
# ...
# epiclccorr::arfgen:- PSF type: 3 [ELLBETA] will be used
# epiclccorr::arfgen:- Opening arfset src_ancillary.ds...
# Making file temp_badcol.ds
# epiclccorr::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# epiclccorr::arfgen:- Writing energy data into dataset ..
# epiclccorr::arfgen:- Calculating Area curve ...
# epiclccorr::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# epiclccorr::arfgen:- Bad pixel & chip gap fraction: ~0.4448886274 %
# epiclccorr::arfgen:- Writing area data into dataset ..
# epiclccorr::arfgen:- Closing arfset src_ancillary.ds.
# epiclccorr::arfgen:- Opening spectrumset spectrum_PN_source_lightcurve_raw_8000to10000eV_bin283sec.lc...
# epiclccorr::arfgen:- Opened spectrumset spectrum_PN_source_lightcurve_raw_8000to10000eV_bin283sec.lc...
# epiclccorr::arfgen:- Opened table spectrum_PN_source_lightcurve_raw_8000to10000eV_bin283sec.lc...
# epiclccorr::arfgen:- current backscale value is: 1
# epiclccorr::arfgen:- deleted attspectrum_PN_source_lightcurve_raw_8000to10000eV_bin283sec.lc...
# epiclccorr::arfgen:- Backscale value is: 13472764
# epiclccorr::arfgen:- added attspectrum_PN_source_lightcurve_raw_8000to10000eV_bin283sec.lc...
# epiclccorr::arfgen:- closed specspectrum_PN_source_lightcurve_raw_8000to10000eV_bin283sec.lc...
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:46:01.000
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:46:01.000
# epiclccorr:- Done.
# epiclccorr:- Reading Spectrum... spectrum_PN_source_lightcurve_raw_8000to10000eV_bin283sec.lc
# epiclccorr:- Reading ancillary file... spectrum_PN_source_lightcurve_raw_8000to10000eV_bin283sec.lc
# epiclccorr:- Done.
# epiclccorr:- Calculating arfgen...
# epiclccorr:- Executing (invoked): arfgen spectrumset=spectrum_PN_source_lightcurve_raw_8000to10000eV_bin283sec.lc rmfset=response.ds withrmfset=no arfset=on_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=yes detxbins=1 detybins=1 withdetbins=no psfenergy=2 filterdss=no filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=tel sourcex=0 sourcey=0 withsourcepos=yes extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:46:01.000
# epiclccorr::arfgen:- Executing (routine): arfgen spectrumset=spectrum_PN_source_lightcurve_raw_8000to10000eV_bin283sec.lc rmfset=response.ds withrmfset=no arfset=on_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=yes detxbins=1 detybins=1 withdetbins=no psfenergy=2 filterdss=no filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=tel sourcex=0 sourcey=0 withsourcepos=yes extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:46:01.000
# epiclccorr::arfgen:- Opening spectrumset spectrum_PN_source_lightcurve_raw_8000to10000eV_bin283sec.lc...
# epiclccorr::arfgen:- Closing spectrumset spectrum_PN_source_lightcurve_raw_8000to10000eV_bin283sec.lc.
# epiclccorr::arfgen:- Using a source position in TEL coordinates of x=0 y=0
# epiclccorr::arfgen:- This corresponds to a position in DET coordinates of DETX=1283.63 DETY=382.834
# epiclccorr::arfgen:-  The source position in focal plane coords is  theta=0 phi=0
# epiclccorr::arfgen:- Taking detector map bounds from the parameters detxoffset and detyoffset ...
# epiclccorr::arfgen:- detector map binning will be: xbins: 8 ybins: 8
# epiclccorr::arfgen:- Constructing a flat detector map with  xmin=83.63452736 xmax=2483.634527 xbins=8 ymin=-817.1664529 ymax=1582.833547 ybins=8
# epiclccorr::arfgen:- Opening arfset on_ancillary.ds...
# epiclccorr::arfgen:- Writing energy data into dataset ..
# epiclccorr::arfgen:- Calculating Area curve ...
# epiclccorr::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# epiclccorr::arfgen:- Bad pixel & chip gap fraction: ~0 %
# epiclccorr::arfgen:- Writing area data into dataset ..
# epiclccorr::arfgen:- Closing arfset on_ancillary.ds.
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:46:09.000
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:46:09.000
# epiclccorr:- Done.
# epiclccorr:- Reading ancillary file... spectrum_PN_source_lightcurve_raw_8000to10000eV_bin283sec.lc
# epiclccorr:- Done.
# epiclccorr:- Weighted Mean 3.745515781689277013
# epiclccorr:- selected 6070 rows from the source input table.
# epiclccorr:- Closing event file dataset
# epiclccorr:- Extraction region lies in CCD number 4
# epiclccorr:- Calculating the relative corrections for each CCD...
# epiclccorr:- STDGTI04 extension found
# epiclccorr:- Processing GTI extension: STDGTI04 corresponding to CCD 4
# epiclccorr:- Doing GTI Correction...
# epiclccorr:- GTI Extension[STDGTI04]
# epiclccorr:- Done.
# epiclccorr:- Doing Exposure and Dead Time Correction: /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EXPOSU04
# epiclccorr:- closing data set /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits
# epiclccorr:- Exposure Correction Done.
# epiclccorr:- Relative Corrections Done.
# epiclccorr:- Calculating spectrum...
# epiclccorr:- Executing (invoked): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='( CCDNR in [4] && gti(/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [3:5] && PI in [8000:) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum_PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc spectralbinsize=50 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# epiclccorr:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:47:09.000
# epiclccorr::evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits:EVENTS filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='( CCDNR in [4] && gti(/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc:STDGTI04,TIME) && FLAG&0xcfa0000==0 && FLAG&0xcfa0000==0 && PATTERN in (:4] && RAWX in [3:5] && PI in [8000:) )' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=spectrum_PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc spectralbinsize=50 specchannelmin=0 specchannelmax=11999 withspecranges=no nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# epiclccorr::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:47:09.000
# epiclccorr::evselect:- selected 6070 rows from the input table.
# ** epiclccorr::evselect: warning (NonStandardSpectrum), The standard PI channel range for PN is 0-20479. Detector matrices can not be created for this spectrum and spectral fitting will not be possible.
# epiclccorr::evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:47:25.000
# epiclccorr:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:47:25.000
# epiclccorr:- Done.
# epiclccorr:- Calculating arfgen...
# epiclccorr:- Executing (invoked): arfgen spectrumset=spectrum_PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc rmfset=response.ds withrmfset=no arfset=bkg_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=yes modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:47:25.000
# epiclccorr::arfgen:- Executing (routine): arfgen spectrumset=spectrum_PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc rmfset=response.ds withrmfset=no arfset=bkg_ancillary.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=yes modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-08T10:47:25.000
# epiclccorr::arfgen:- Opening spectrumset spectrum_PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc...
# epiclccorr::arfgen:- Closing spectrumset spectrum_PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc.
# epiclccorr::arfgen:- Computing source position from region extent..
# epiclccorr::arfgen:- Using a source position in DET coordinates of x=2852 y=-195.132
# epiclccorr::arfgen:-  The source position in focal plane coords is  theta=83.5677 phi=5.93011
# epiclccorr::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# epiclccorr::arfgen:- detector map binning will be: xbins: 55 ybins: 55
# epiclccorr::arfgen:- Constructing a flat detector map with  xmin=-5406 xmax=11110 xbins=55 ymin=-1064 ymax=15453 ybins=55
# epiclccorr::arfgen:- Opening arfset bkg_ancillary.ds...
# Making file temp_badcol.ds
# epiclccorr::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# epiclccorr::arfgen:- Writing energy data into dataset ..
# epiclccorr::arfgen:- Calculating Area curve ...
# epiclccorr::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# epiclccorr::arfgen:- Bad pixel & chip gap fraction: ~0.5690072639 %
# epiclccorr::arfgen:- Writing area data into dataset ..
# epiclccorr::arfgen:- Closing arfset bkg_ancillary.ds.
# epiclccorr::arfgen:- Opening spectrumset spectrum_PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc...
# epiclccorr::arfgen:- Opened spectrumset spectrum_PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc...
# epiclccorr::arfgen:- Opened table spectrum_PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc...
# epiclccorr::arfgen:- current backscale value is: 1
# epiclccorr::arfgen:- deleted attspectrum_PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc...
# epiclccorr::arfgen:- Backscale value is: 3942240
# epiclccorr::arfgen:- added attspectrum_PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc...
# epiclccorr::arfgen:- closed specspectrum_PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc...
# epiclccorr::arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:47:27.000
# epiclccorr:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:47:27.000
# epiclccorr:- Done.
# epiclccorr:- Reading Spectrum... spectrum_PN_lightcurve_background_raw_8000to10000eV_bin283sec.lc
# epiclccorr:- Substracting background...
# epiclccorr:- Checking Source and Background Binning
# epiclccorr:- Source Start Time: 673308775.717167
# epiclccorr:- Background Start Time: 673308775.717167
# epiclccorr:- Source Stop Time: 673420277.717167
# epiclccorr:- Background Stop Time: 673420277.717167
# epiclccorr:- Source BACKSCALE: 13472764
# epiclccorr:- Background BACKSCALE: 3942240
# epiclccorr:- Done.
# epiclccorr:- Applying Absolute Correction...
# epiclccorr:- Done.
# epiclccorr:- Creating SRC_GTIS GTIs...
# epiclccorr:- Done.
# epiclccorr:- Creating BKG_GTIS GTIs...
# epiclccorr:- Done.
# epiclccorr:- Removing GTI information from DSS...
# epiclccorr:- Done
# epiclccorr:- Extracting PI information from DSS...
# epiclccorr:- Done
# epiclccorr:- LightCurve Destructor
# epiclccorr:- Done
# epiclccorr:- LightCurve Destructor
# epiclccorr:- Done
# epiclccorr:- epiclccorr (epiclccorr-1.23.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-08T10:47:27.000
# ** epiclccorr: warning (SummaryOfWarnings),
#    warning PNTimingRand silently occurred 1 times
# All the energy-resolved light curves produced: ['/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_500to3000eV_bin283sec.lc', '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_3000to6000eV_bin283sec.lc', '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_6000to8000eV_bin283sec.lc', '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_8000to10000eV_bin283sec.lc']

# %% [markdown]
# After the script has finished we have out corrected light curves printed out, we have written them below:

# %%
band1 = '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_500to3000eV_bin283sec.lc'
band2 = '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_3000to6000eV_bin283sec.lc'
band3 = '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_6000to8000eV_bin283sec.lc'
band4 = '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_lccorr_8000to10000eV_bin283sec.lc'

# %% [markdown]
# Now we can plot all the energy-resolved light curves.

# %%
# Inspect the light curves
fileNames = [band1, band2, band3, band4]
names = ['0.5-3.0 keV', '3.0-6.0 keV', '6.0-8.0 keV', '8.0-10.0 keV']

plotVelaX1LC(fileNames, names, threshold=None, figname="energyresolved_lightcurves.png", yLog=True, connect_points=False)

# %% [markdown]
# * ### Pulse by pulse analysis

# %% [markdown]
# If the user would like to explore further in depth analysis to observe variability it is possible to do a pulse-by-pulse analysis. We take the pulse of Vela X-1 to be $P= 283.44$ s in accordance with Diez et al. (2022).
#
# We can use the SAS task `tabgtigen` to select GTI files for each pulse period throughout the observation. Below we run a custom script written in Python which should create all the GTI files by running a loop.

# %%
# !python3 /media/user/Vela-work/XMM-SAS-Datalabs-Paper/scripts/gtiloop.py
# Out:
# startsas - WARNING - Executing /usr/local/SAS/xmmsas_20230412_1735/lib/python/pysas/startsas/startsas.py {'odfid': '', 'workdir': '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan', 'sasfiles': 'yes', 'sas_ccf': '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif', 'sas_odf': '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS', 'level': 'ODF', 'cifbuild_opts': '', 'odfingest_opts': ''}
#
#
#         Starting SAS session
#
#         Working directory = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan
#
#
# SAS_CCF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif
# SAS_ODF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS
# TIME-OBS: 673308775.717167
# TIME-END: 673420053.221235
# Creating 283.44-second GTI files...
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673308775.717_673309059.157.fits' expression='TIME >= 673308775.717167 && TIME < 673309059.1571671' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673308775.717_673309059.157.fits expression='TIME >= 673308775.717167 && TIME < 673309059.1571671' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:04.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:17.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673309059.157_673309342.597.fits' expression='TIME >= 673309059.1571671 && TIME < 673309342.5971671' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673309059.157_673309342.597.fits expression='TIME >= 673309059.1571671 && TIME < 673309342.5971671' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:17.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:19.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673309342.597_673309626.037.fits' expression='TIME >= 673309342.5971671 && TIME < 673309626.0371672' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673309342.597_673309626.037.fits expression='TIME >= 673309342.5971671 && TIME < 673309626.0371672' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:19.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:20.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673309626.037_673309909.477.fits' expression='TIME >= 673309626.0371672 && TIME < 673309909.4771672' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673309626.037_673309909.477.fits expression='TIME >= 673309626.0371672 && TIME < 673309909.4771672' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:20.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:21.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673309909.477_673310192.917.fits' expression='TIME >= 673309909.4771672 && TIME < 673310192.9171673' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673309909.477_673310192.917.fits expression='TIME >= 673309909.4771672 && TIME < 673310192.9171673' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:21.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:22.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673310192.917_673310476.357.fits' expression='TIME >= 673310192.9171673 && TIME < 673310476.3571674' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673310192.917_673310476.357.fits expression='TIME >= 673310192.9171673 && TIME < 673310476.3571674' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:22.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:24.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673310476.357_673310759.797.fits' expression='TIME >= 673310476.3571674 && TIME < 673310759.7971674' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673310476.357_673310759.797.fits expression='TIME >= 673310476.3571674 && TIME < 673310759.7971674' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:24.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:25.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673310759.797_673311043.237.fits' expression='TIME >= 673310759.7971674 && TIME < 673311043.2371675' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673310759.797_673311043.237.fits expression='TIME >= 673310759.7971674 && TIME < 673311043.2371675' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:25.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:26.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673311043.237_673311326.677.fits' expression='TIME >= 673311043.2371675 && TIME < 673311326.6771675' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673311043.237_673311326.677.fits expression='TIME >= 673311043.2371675 && TIME < 673311326.6771675' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:26.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:27.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673311326.677_673311610.117.fits' expression='TIME >= 673311326.6771675 && TIME < 673311610.1171676' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673311326.677_673311610.117.fits expression='TIME >= 673311326.6771675 && TIME < 673311610.1171676' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:27.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:29.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673311610.117_673311893.557.fits' expression='TIME >= 673311610.1171676 && TIME < 673311893.5571676' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673311610.117_673311893.557.fits expression='TIME >= 673311610.1171676 && TIME < 673311893.5571676' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:29.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:31.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673311893.557_673312176.997.fits' expression='TIME >= 673311893.5571676 && TIME < 673312176.9971677' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673311893.557_673312176.997.fits expression='TIME >= 673311893.5571676 && TIME < 673312176.9971677' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:31.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:32.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673312176.997_673312460.437.fits' expression='TIME >= 673312176.9971677 && TIME < 673312460.4371678' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673312176.997_673312460.437.fits expression='TIME >= 673312176.9971677 && TIME < 673312460.4371678' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:32.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:33.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673312460.437_673312743.877.fits' expression='TIME >= 673312460.4371678 && TIME < 673312743.8771678' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673312460.437_673312743.877.fits expression='TIME >= 673312460.4371678 && TIME < 673312743.8771678' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:33.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:38.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673312743.877_673313027.317.fits' expression='TIME >= 673312743.8771678 && TIME < 673313027.3171679' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673312743.877_673313027.317.fits expression='TIME >= 673312743.8771678 && TIME < 673313027.3171679' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:38.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:39.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673313027.317_673313310.757.fits' expression='TIME >= 673313027.3171679 && TIME < 673313310.7571679' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673313027.317_673313310.757.fits expression='TIME >= 673313027.3171679 && TIME < 673313310.7571679' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:39.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:40.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673313310.757_673313594.197.fits' expression='TIME >= 673313310.7571679 && TIME < 673313594.197168' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673313310.757_673313594.197.fits expression='TIME >= 673313310.7571679 && TIME < 673313594.197168' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:40.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:43.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673313594.197_673313877.637.fits' expression='TIME >= 673313594.197168 && TIME < 673313877.637168' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673313594.197_673313877.637.fits expression='TIME >= 673313594.197168 && TIME < 673313877.637168' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:43.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:44.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673313877.637_673314161.077.fits' expression='TIME >= 673313877.637168 && TIME < 673314161.0771681' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673313877.637_673314161.077.fits expression='TIME >= 673313877.637168 && TIME < 673314161.0771681' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:44.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:46.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673314161.077_673314444.517.fits' expression='TIME >= 673314161.0771681 && TIME < 673314444.5171682' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673314161.077_673314444.517.fits expression='TIME >= 673314161.0771681 && TIME < 673314444.5171682' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:46.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:47.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673314444.517_673314727.957.fits' expression='TIME >= 673314444.5171682 && TIME < 673314727.9571682' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673314444.517_673314727.957.fits expression='TIME >= 673314444.5171682 && TIME < 673314727.9571682' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:47.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:48.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673314727.957_673315011.397.fits' expression='TIME >= 673314727.9571682 && TIME < 673315011.3971683' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673314727.957_673315011.397.fits expression='TIME >= 673314727.9571682 && TIME < 673315011.3971683' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:48.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:49.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673315011.397_673315294.837.fits' expression='TIME >= 673315011.3971683 && TIME < 673315294.8371683' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673315011.397_673315294.837.fits expression='TIME >= 673315011.3971683 && TIME < 673315294.8371683' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:49.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:50.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673315294.837_673315578.277.fits' expression='TIME >= 673315294.8371683 && TIME < 673315578.2771684' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673315294.837_673315578.277.fits expression='TIME >= 673315294.8371683 && TIME < 673315578.2771684' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:50.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:51.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673315578.277_673315861.717.fits' expression='TIME >= 673315578.2771684 && TIME < 673315861.7171685' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673315578.277_673315861.717.fits expression='TIME >= 673315578.2771684 && TIME < 673315861.7171685' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:51.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:52.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673315861.717_673316145.157.fits' expression='TIME >= 673315861.7171685 && TIME < 673316145.1571685' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673315861.717_673316145.157.fits expression='TIME >= 673315861.7171685 && TIME < 673316145.1571685' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:52.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:53.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673316145.157_673316428.597.fits' expression='TIME >= 673316145.1571685 && TIME < 673316428.5971686' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673316145.157_673316428.597.fits expression='TIME >= 673316145.1571685 && TIME < 673316428.5971686' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:53.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:54.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673316428.597_673316712.037.fits' expression='TIME >= 673316428.5971686 && TIME < 673316712.0371686' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673316428.597_673316712.037.fits expression='TIME >= 673316428.5971686 && TIME < 673316712.0371686' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:54.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:55.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673316712.037_673316995.477.fits' expression='TIME >= 673316712.0371686 && TIME < 673316995.4771687' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673316712.037_673316995.477.fits expression='TIME >= 673316712.0371686 && TIME < 673316995.4771687' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:56.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:57.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673316995.477_673317278.917.fits' expression='TIME >= 673316995.4771687 && TIME < 673317278.9171687' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673316995.477_673317278.917.fits expression='TIME >= 673316995.4771687 && TIME < 673317278.9171687' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:57.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:58.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673317278.917_673317562.357.fits' expression='TIME >= 673317278.9171687 && TIME < 673317562.3571688' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673317278.917_673317562.357.fits expression='TIME >= 673317278.9171687 && TIME < 673317562.3571688' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:58.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:19:59.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673317562.357_673317845.797.fits' expression='TIME >= 673317562.3571688 && TIME < 673317845.7971689' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673317562.357_673317845.797.fits expression='TIME >= 673317562.3571688 && TIME < 673317845.7971689' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:19:59.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:00.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673317845.797_673318129.237.fits' expression='TIME >= 673317845.7971689 && TIME < 673318129.2371689' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673317845.797_673318129.237.fits expression='TIME >= 673317845.7971689 && TIME < 673318129.2371689' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:00.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:02.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673318129.237_673318412.677.fits' expression='TIME >= 673318129.2371689 && TIME < 673318412.677169' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673318129.237_673318412.677.fits expression='TIME >= 673318129.2371689 && TIME < 673318412.677169' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:02.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:03.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673318412.677_673318696.117.fits' expression='TIME >= 673318412.677169 && TIME < 673318696.117169' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673318412.677_673318696.117.fits expression='TIME >= 673318412.677169 && TIME < 673318696.117169' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:03.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:04.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673318696.117_673318979.557.fits' expression='TIME >= 673318696.117169 && TIME < 673318979.5571691' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673318696.117_673318979.557.fits expression='TIME >= 673318696.117169 && TIME < 673318979.5571691' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:04.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:05.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673318979.557_673319262.997.fits' expression='TIME >= 673318979.5571691 && TIME < 673319262.9971691' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673318979.557_673319262.997.fits expression='TIME >= 673318979.5571691 && TIME < 673319262.9971691' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:05.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:06.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673319262.997_673319546.437.fits' expression='TIME >= 673319262.9971691 && TIME < 673319546.4371692' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673319262.997_673319546.437.fits expression='TIME >= 673319262.9971691 && TIME < 673319546.4371692' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:06.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:07.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673319546.437_673319829.877.fits' expression='TIME >= 673319546.4371692 && TIME < 673319829.8771693' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673319546.437_673319829.877.fits expression='TIME >= 673319546.4371692 && TIME < 673319829.8771693' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:07.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:08.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673319829.877_673320113.317.fits' expression='TIME >= 673319829.8771693 && TIME < 673320113.3171693' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673319829.877_673320113.317.fits expression='TIME >= 673319829.8771693 && TIME < 673320113.3171693' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:08.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:09.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673320113.317_673320396.757.fits' expression='TIME >= 673320113.3171693 && TIME < 673320396.7571694' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673320113.317_673320396.757.fits expression='TIME >= 673320113.3171693 && TIME < 673320396.7571694' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:09.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:10.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673320396.757_673320680.197.fits' expression='TIME >= 673320396.7571694 && TIME < 673320680.1971694' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673320396.757_673320680.197.fits expression='TIME >= 673320396.7571694 && TIME < 673320680.1971694' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:11.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:12.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673320680.197_673320963.637.fits' expression='TIME >= 673320680.1971694 && TIME < 673320963.6371695' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673320680.197_673320963.637.fits expression='TIME >= 673320680.1971694 && TIME < 673320963.6371695' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:12.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:13.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673320963.637_673321247.077.fits' expression='TIME >= 673320963.6371695 && TIME < 673321247.0771695' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673320963.637_673321247.077.fits expression='TIME >= 673320963.6371695 && TIME < 673321247.0771695' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:13.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:14.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673321247.077_673321530.517.fits' expression='TIME >= 673321247.0771695 && TIME < 673321530.5171696' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673321247.077_673321530.517.fits expression='TIME >= 673321247.0771695 && TIME < 673321530.5171696' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:14.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:15.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673321530.517_673321813.957.fits' expression='TIME >= 673321530.5171696 && TIME < 673321813.9571697' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673321530.517_673321813.957.fits expression='TIME >= 673321530.5171696 && TIME < 673321813.9571697' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:15.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:17.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673321813.957_673322097.397.fits' expression='TIME >= 673321813.9571697 && TIME < 673322097.3971697' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673321813.957_673322097.397.fits expression='TIME >= 673321813.9571697 && TIME < 673322097.3971697' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:17.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:18.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673322097.397_673322380.837.fits' expression='TIME >= 673322097.3971697 && TIME < 673322380.8371698' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673322097.397_673322380.837.fits expression='TIME >= 673322097.3971697 && TIME < 673322380.8371698' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:18.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:19.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673322380.837_673322664.277.fits' expression='TIME >= 673322380.8371698 && TIME < 673322664.2771698' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673322380.837_673322664.277.fits expression='TIME >= 673322380.8371698 && TIME < 673322664.2771698' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:19.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:20.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673322664.277_673322947.717.fits' expression='TIME >= 673322664.2771698 && TIME < 673322947.7171699' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673322664.277_673322947.717.fits expression='TIME >= 673322664.2771698 && TIME < 673322947.7171699' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:20.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:21.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673322947.717_673323231.157.fits' expression='TIME >= 673322947.7171699 && TIME < 673323231.1571699' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673322947.717_673323231.157.fits expression='TIME >= 673322947.7171699 && TIME < 673323231.1571699' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:21.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:23.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673323231.157_673323514.597.fits' expression='TIME >= 673323231.1571699 && TIME < 673323514.59717' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673323231.157_673323514.597.fits expression='TIME >= 673323231.1571699 && TIME < 673323514.59717' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:23.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:24.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673323514.597_673323798.037.fits' expression='TIME >= 673323514.59717 && TIME < 673323798.03717' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673323514.597_673323798.037.fits expression='TIME >= 673323514.59717 && TIME < 673323798.03717' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:24.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:25.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673323798.037_673324081.477.fits' expression='TIME >= 673323798.03717 && TIME < 673324081.4771701' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673323798.037_673324081.477.fits expression='TIME >= 673323798.03717 && TIME < 673324081.4771701' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:25.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:26.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673324081.477_673324364.917.fits' expression='TIME >= 673324081.4771701 && TIME < 673324364.9171702' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673324081.477_673324364.917.fits expression='TIME >= 673324081.4771701 && TIME < 673324364.9171702' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:26.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:27.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673324364.917_673324648.357.fits' expression='TIME >= 673324364.9171702 && TIME < 673324648.3571702' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673324364.917_673324648.357.fits expression='TIME >= 673324364.9171702 && TIME < 673324648.3571702' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:20:27.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:20:28.000
# Executing:
# ...
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673414782.277_673415065.717.fits' expression='TIME >= 673414782.2771884 && TIME < 673415065.7171885' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673414782.277_673415065.717.fits expression='TIME >= 673414782.2771884 && TIME < 673415065.7171885' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:25:50.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:25:51.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673415065.717_673415349.157.fits' expression='TIME >= 673415065.7171885 && TIME < 673415349.1571885' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673415065.717_673415349.157.fits expression='TIME >= 673415065.7171885 && TIME < 673415349.1571885' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:25:51.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:25:52.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673415349.157_673415632.597.fits' expression='TIME >= 673415349.1571885 && TIME < 673415632.5971886' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673415349.157_673415632.597.fits expression='TIME >= 673415349.1571885 && TIME < 673415632.5971886' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:25:52.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:25:53.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673415632.597_673415916.037.fits' expression='TIME >= 673415632.5971886 && TIME < 673415916.0371886' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673415632.597_673415916.037.fits expression='TIME >= 673415632.5971886 && TIME < 673415916.0371886' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:25:53.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:25:53.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673415916.037_673416199.477.fits' expression='TIME >= 673415916.0371886 && TIME < 673416199.4771887' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673415916.037_673416199.477.fits expression='TIME >= 673415916.0371886 && TIME < 673416199.4771887' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:25:53.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:25:54.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673416199.477_673416482.917.fits' expression='TIME >= 673416199.4771887 && TIME < 673416482.9171888' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673416199.477_673416482.917.fits expression='TIME >= 673416199.4771887 && TIME < 673416482.9171888' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:25:54.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:25:55.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673416482.917_673416766.357.fits' expression='TIME >= 673416482.9171888 && TIME < 673416766.3571888' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673416482.917_673416766.357.fits expression='TIME >= 673416482.9171888 && TIME < 673416766.3571888' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:25:55.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:25:56.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673416766.357_673417049.797.fits' expression='TIME >= 673416766.3571888 && TIME < 673417049.7971889' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673416766.357_673417049.797.fits expression='TIME >= 673416766.3571888 && TIME < 673417049.7971889' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:25:56.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:25:57.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673417049.797_673417333.237.fits' expression='TIME >= 673417049.7971889 && TIME < 673417333.2371889' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673417049.797_673417333.237.fits expression='TIME >= 673417049.7971889 && TIME < 673417333.2371889' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:25:57.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:25:58.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673417333.237_673417616.677.fits' expression='TIME >= 673417333.2371889 && TIME < 673417616.677189' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673417333.237_673417616.677.fits expression='TIME >= 673417333.2371889 && TIME < 673417616.677189' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:25:58.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:25:58.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673417616.677_673417900.117.fits' expression='TIME >= 673417616.677189 && TIME < 673417900.117189' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673417616.677_673417900.117.fits expression='TIME >= 673417616.677189 && TIME < 673417900.117189' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:25:58.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:25:59.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673417900.117_673418183.557.fits' expression='TIME >= 673417900.117189 && TIME < 673418183.5571891' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673417900.117_673418183.557.fits expression='TIME >= 673417900.117189 && TIME < 673418183.5571891' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:25:59.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:26:00.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673418183.557_673418466.997.fits' expression='TIME >= 673418183.5571891 && TIME < 673418466.9971892' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673418183.557_673418466.997.fits expression='TIME >= 673418183.5571891 && TIME < 673418466.9971892' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:26:00.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:26:01.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673418466.997_673418750.437.fits' expression='TIME >= 673418466.9971892 && TIME < 673418750.4371892' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673418466.997_673418750.437.fits expression='TIME >= 673418466.9971892 && TIME < 673418750.4371892' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:26:01.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:26:02.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673418750.437_673419033.877.fits' expression='TIME >= 673418750.4371892 && TIME < 673419033.8771893' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673418750.437_673419033.877.fits expression='TIME >= 673418750.4371892 && TIME < 673419033.8771893' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:26:02.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:26:02.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673419033.877_673419317.317.fits' expression='TIME >= 673419033.8771893 && TIME < 673419317.3171893' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673419033.877_673419317.317.fits expression='TIME >= 673419033.8771893 && TIME < 673419317.3171893' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:26:02.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:26:03.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673419317.317_673419600.757.fits' expression='TIME >= 673419317.3171893 && TIME < 673419600.7571894' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673419317.317_673419600.757.fits expression='TIME >= 673419317.3171893 && TIME < 673419600.7571894' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:26:03.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:26:04.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673419600.757_673419884.197.fits' expression='TIME >= 673419600.7571894 && TIME < 673419884.1971895' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673419600.757_673419884.197.fits expression='TIME >= 673419600.7571894 && TIME < 673419884.1971895' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:26:04.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:26:05.000
# Executing:
# tabgtigen table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' gtiset='./gti_files/gti_673419884.197_673420167.637.fits' expression='TIME >= 673419884.1971895 && TIME < 673420167.6371895' timecolumn='TIME' prefraction='0.5' postfraction='0.5' mingtisize='0.0'
# tabgtigen:- Executing (routine): tabgtigen table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits gtiset=./gti_files/gti_673419884.197_673420167.637.fits expression='TIME >= 673419884.1971895 && TIME < 673420167.6371895' timecolumn=TIME prefraction=0.5 postfraction=0.5 mingtisize=0  -w 1 -V 4
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T09:26:05.000
# tabgtigen:- tabgtigen (tabgtigen-2.13)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T09:26:06.000
# GTI files created in ./gti_files.

# %% [markdown]
# Now we can produce spectra for the each GTI file for further analysis using the second custom python script, which will run a loop.

# %%
# !python3 /media/user/Vela-work/XMM-SAS-Datalabs-Paper/scripts/loopgtispectra.py
# Out:
# startsas - WARNING - Executing /usr/local/SAS/xmmsas_20230412_1735/lib/python/pysas/startsas/startsas.py {'odfid': '', 'workdir': '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan', 'sasfiles': 'yes', 'sas_ccf': '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif', 'sas_odf': '/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS', 'level': 'ODF', 'cifbuild_opts': '', 'odfingest_opts': ''}
#
#
#         Starting SAS session
#
#         Working directory = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan
#
#
# SAS_CCF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/ccf.cif
# SAS_ODF = /media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/3553_0841890201_SCX00000SUM.SAS
# Processing gti_673308775.717_673309059.157.fits...
# Warning: No need to include withspecranges. Assumed withspecranges=yes
# Executing:
# evselect table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44]) && (gti(./gti_files/gti_673308775.717_673309059.157.fits,TIME))' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='./spectra/spectrum_gti_673308775.717_673309059.157.fits' spectralbinsize='5' withspecranges='yes' specchannelmin='0' specchannelmax='20479' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44]) && (gti(./gti_files/gti_673308775.717_673309059.157.fits,TIME))' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=./spectra/spectrum_gti_673308775.717_673309059.157.fits spectralbinsize=5 specchannelmin=0 specchannelmax=20479 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:28:46.000
# evselect:- selected 18785 rows from the input table.
# ** evselect: warning (DifferentAttributeValues), Attribute `TIMESYS' has different value in `/tmp/fileg6fEFU:STDGTI04' (TDB) and `./gti_files/gti_673308775.717_673309059.157.fits:STDGTI' (TT) - please make sure it makes sense to merge the GTI tables
# ** evselect: warning (ExpBadDssGlobal), A filtering expression has been specified which may not allow for calculation of a uniform exposure for all events.  Please ensure that all TIME related filters are applied uniformly.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:28:52.000
# ** evselect: warning (SummaryOfWarnings),
#    warning DifferentAttributeValues silently occurred 3 times
# Executing:
# backscale spectrumset='./spectra/spectrum_gti_673308775.717_673309059.157.fits' badpixlocation='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=./spectra/spectrum_gti_673308775.717_673309059.157.fits badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:28:52.000
# backscale:- Executing (routine): arfgen spectrumset=./spectra/spectrum_gti_673308775.717_673309059.157.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:28:52.000
# backscale::arfgen:- Opening spectrumset ./spectra/spectrum_gti_673308775.717_673309059.157.fits...
# backscale::arfgen:- Closing spectrumset ./spectra/spectrum_gti_673308775.717_673309059.157.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# backscale::arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-8545 xmax=8635 xbins=1 ymin=-1065 ymax=15454 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# ** backscale::arfgen: warning (zeroSumDetmap), The filtered detector map has a zero normalisation - returning zero area. Try using a flat detector map and/or more bins
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0.1429431873 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset ./spectra/spectrum_gti_673308775.717_673309059.157.fits...
# backscale::arfgen:- Opened spectrumset ./spectra/spectrum_gti_673308775.717_673309059.157.fits...
# backscale::arfgen:- Opened table ./spectra/spectrum_gti_673308775.717_673309059.157.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att./spectra/spectrum_gti_673308775.717_673309059.157.fits...
# backscale::arfgen:- Backscale value is: 13407164
# backscale::arfgen:- added att./spectra/spectrum_gti_673308775.717_673309059.157.fits...
# backscale::arfgen:- closed spec./spectra/spectrum_gti_673308775.717_673309059.157.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:29:19.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:29:19.000
# Executing:
# rmfgen rmfset='./spectra/PN_gti_673308775.717_673309059.157.rmf' threshold='1e-06' withenergybins='no' energymin='0' energymax='15' nenergybins='30' spectrumset='./spectra/spectrum_gti_673308775.717_673309059.157.fits' format='var' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='yes' detxbins='160' detybins='160' correctforpileup='no' raweventfile='rawevents.ds' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withrmfset='no' psfenergy='2' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='no' modelquantumeff='no' modelfiltertrans='no' modelcontamination='no' modelee='yes' modelootcorr='no' eegridfactor='100' withbadpixcorr='no' badpixlocation='notSpecified' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset='' psfmodel='notSpecified' withbadpixres='no' badpixelresolution='2' applyxcaladjustment='no' acceptchanrange='no' applyabsfluxcorr='no'
# rmfgen:- Executing (routine): rmfgen rmfset=./spectra/PN_gti_673308775.717_673309059.157.rmf threshold=1e-06 withenergybins=no energymin=0 energymax=15 nenergybins=30 spectrumset=./spectra/spectrum_gti_673308775.717_673309059.157.fits format=var detmaptype=psf detmaparray=detmapfile.ds: withdetbounds=no detxoffset=1200 detyoffset=1200 detxbins=160 detybins=160 withdetbins=yes raweventfile=rawevents.ds correctforpileup=no filterdss=yes withfilteredset=no filteredset=filteredpixellist.ds withrmfset=no psfenergy=2 withsourcepos=no sourcecoords=eqpos sourcex=0 sourcey=0 extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=no modelee=yes modelootcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no psfmodel=notSpecified badpixelresolution=2 withbadpixres=no applyxcaladjustment=no acceptchanrange=no applyabsfluxcorr=no  -w 1 -V 4
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:29:19.000
# Set to: notSpecified
# rmfgen:- Opening spectrumset ./spectra/spectrum_gti_673308775.717_673309059.157.fits...
# rmfgen:- Closing spectrumset ./spectra/spectrum_gti_673308775.717_673309059.157.fits.
# rmfgen:- Computing source position from region extent..
# rmfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# rmfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# rmfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# rmfgen:- detector map binning will be: xbins: 160 ybins: 160
# rmfgen:- Constructing a psf detector map with  xmin=-8545 xmax=8635 xbins=160 ymin=-1065 ymax=15454 ybins=160
# rmfgen:- PSF type: 5 [HIGH] will be used
# rmfgen:-  Creating RmfDataServer...
# rmfgen:-  EventGrades:4 FastTiming 37
# rmfgen:-  RmfDataServer created ok.
# rmfgen:- Opening data set ...
# rmfgen:- Opened data set.
# rmfgen:- Adding MATRIX table. There will be 2067 rows in table
# rmfgen:- Initialising table iterator ..
# rmfgen:- Populating table ..
# rmfgen:- Adding EBOUNDS extension ...
# rmfgen:-  Cleanup ...
# rmfgen:-  Closing data set ...
# rmfgen:-  Closed data set.
# rmfgen:-  Cleanup complete.
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:30:01.000
# Executing:
# arfgen spectrumset='./spectra/spectrum_gti_673308775.717_673309059.157.fits' withrmfset='yes' rmfset='./spectra/PN_gti_673308775.717_673309059.157.rmf' arfset='./spectra/PN_gti_673308775.717_673309059.157.arf' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='no' detxbins='5' detybins='5' psfenergy='2' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='yes' modelquantumeff='yes' modelfiltertrans='yes' modelcontamination='yes' modelee='yes' modelootcorr='yes' applyxcaladjustment='no' applyabsfluxcorr='yes' eegridfactor='100' withbadpixcorr='yes' badpixlocation='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' psfmodel='ELLBETA' withbadpixres='no' badpixelresolution='2' badpixmaptype='flat' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset=''
# arfgen:- Executing (routine): arfgen spectrumset=./spectra/spectrum_gti_673308775.717_673309059.157.fits rmfset=./spectra/PN_gti_673308775.717_673309059.157.rmf withrmfset=yes arfset=./spectra/PN_gti_673308775.717_673309059.157.arf detmaptype=psf detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=yes eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:30:01.000
# arfgen:- Opening spectrumset ./spectra/spectrum_gti_673308775.717_673309059.157.fits...
# arfgen:- Closing spectrumset ./spectra/spectrum_gti_673308775.717_673309059.157.fits.
# arfgen:- Computing source position from region extent..
# arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# arfgen:- detector map binning will be: xbins: 57 ybins: 55
# arfgen:- Constructing a psf detector map with  xmin=-8545 xmax=8635 xbins=57 ymin=-1065 ymax=15454 ybins=55
# arfgen:- PSF type: 3 [ELLBETA] will be used
# arfgen:- Opening arfset ./spectra/PN_gti_673308775.717_673309059.157.arf...
# Making file temp_badcol.ds
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- Writing energy data into dataset ..
# arfgen:- Calculating Area curve ...
# arfgen:- Calculating Area curve ...50.4999999 2067 15997.49947
# arfgen:- Bad pixel & chip gap fraction: ~0.4448886274 %
# arfgen:- Writing area data into dataset ..
# arfgen:- Closing arfset ./spectra/PN_gti_673308775.717_673309059.157.arf.
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:37:31.000
# Executing:
# specgroup spectrumset='./spectra/spectrum_gti_673308775.717_673309059.157.fits' overwrite='no' groupedset='./spectra/PN_spectrum_grp_gti_673308775.717_673309059.157.fits' withbgdset='no' backgndset='' withCounts='yes' mincounts='25' withminSN='no' minSN='5' withratioabovebgnd='no' ratioabovebgnd='' withoversampling='yes' oversample='3' withtemplate='no' grouptemplate='grptemplate.ds' withranges='no' ranges='' withRegularBins='no' regbinstart='' regbinend='' regbinwid='' units='CHAN' withrmfset='yes' rmfset='./spectra/PN_gti_673308775.717_673309059.157.rmf' witharfset='yes' arfset='./spectra/PN_gti_673308775.717_673309059.157.arf' addfilenames='yes' hightolow='no' lastbin='addtogroup' setbad='CCF'
# specgroup:- Executing (routine): specgroup spectrumset=./spectra/spectrum_gti_673308775.717_673309059.157.fits groupedset=./spectra/PN_spectrum_grp_gti_673308775.717_673309059.157.fits overwrite=no backgndset='' withbgdset=no mincounts=25 withCounts=yes minSN=5 withminSN=no ratioabovebgnd=0 withratioabovebgnd=no oversample=3 withoversampling=yes grouptemplate=grptemplate.ds withtemplate=no ranges='' withranges=no regbinstart=0 regbinend=0 regbinwid=0 withRegularBins=no units=CHAN rmfset=./spectra/PN_gti_673308775.717_673309059.157.rmf withrmfset=yes arfset=./spectra/PN_gti_673308775.717_673309059.157.arf witharfset=yes addfilenames=yes hightolow=no lastbin=addtogroup setbad=CCF  -w 1 -V 4
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:37:31.000
# specgroup:- Prepared spectrum ./spectra/PN_spectrum_grp_gti_673308775.717_673309059.157.fits with 173 groups
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:37:31.000
# Processing gti_673309059.157_673309342.597.fits...
# Warning: No need to include withspecranges. Assumed withspecranges=yes
# Executing:
# evselect table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44]) && (gti(./gti_files/gti_673309059.157_673309342.597.fits,TIME))' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='./spectra/spectrum_gti_673309059.157_673309342.597.fits' spectralbinsize='5' withspecranges='yes' specchannelmin='0' specchannelmax='20479' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44]) && (gti(./gti_files/gti_673309059.157_673309342.597.fits,TIME))' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=./spectra/spectrum_gti_673309059.157_673309342.597.fits spectralbinsize=5 specchannelmin=0 specchannelmax=20479 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:37:31.000
# evselect:- selected 16586 rows from the input table.
# ** evselect: warning (DifferentAttributeValues), Attribute `TIMESYS' has different value in `/tmp/fileuo2bLS:STDGTI04' (TDB) and `./gti_files/gti_673309059.157_673309342.597.fits:STDGTI' (TT) - please make sure it makes sense to merge the GTI tables
# ** evselect: warning (ExpBadDssGlobal), A filtering expression has been specified which may not allow for calculation of a uniform exposure for all events.  Please ensure that all TIME related filters are applied uniformly.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:37:37.000
# ** evselect: warning (SummaryOfWarnings),
#    warning DifferentAttributeValues silently occurred 3 times
# Executing:
# backscale spectrumset='./spectra/spectrum_gti_673309059.157_673309342.597.fits' badpixlocation='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=./spectra/spectrum_gti_673309059.157_673309342.597.fits badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:37:37.000
# backscale:- Executing (routine): arfgen spectrumset=./spectra/spectrum_gti_673309059.157_673309342.597.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:37:37.000
# backscale::arfgen:- Opening spectrumset ./spectra/spectrum_gti_673309059.157_673309342.597.fits...
# backscale::arfgen:- Closing spectrumset ./spectra/spectrum_gti_673309059.157_673309342.597.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# backscale::arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-8545 xmax=8635 xbins=1 ymin=-1065 ymax=15454 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# ** backscale::arfgen: warning (zeroSumDetmap), The filtered detector map has a zero normalisation - returning zero area. Try using a flat detector map and/or more bins
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0.1429431873 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset ./spectra/spectrum_gti_673309059.157_673309342.597.fits...
# backscale::arfgen:- Opened spectrumset ./spectra/spectrum_gti_673309059.157_673309342.597.fits...
# backscale::arfgen:- Opened table ./spectra/spectrum_gti_673309059.157_673309342.597.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att./spectra/spectrum_gti_673309059.157_673309342.597.fits...
# backscale::arfgen:- Backscale value is: 13407164
# backscale::arfgen:- added att./spectra/spectrum_gti_673309059.157_673309342.597.fits...
# backscale::arfgen:- closed spec./spectra/spectrum_gti_673309059.157_673309342.597.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:38:06.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:38:06.000
# Executing:
# rmfgen rmfset='./spectra/PN_gti_673309059.157_673309342.597.rmf' threshold='1e-06' withenergybins='no' energymin='0' energymax='15' nenergybins='30' spectrumset='./spectra/spectrum_gti_673309059.157_673309342.597.fits' format='var' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='yes' detxbins='160' detybins='160' correctforpileup='no' raweventfile='rawevents.ds' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withrmfset='no' psfenergy='2' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='no' modelquantumeff='no' modelfiltertrans='no' modelcontamination='no' modelee='yes' modelootcorr='no' eegridfactor='100' withbadpixcorr='no' badpixlocation='notSpecified' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset='' psfmodel='notSpecified' withbadpixres='no' badpixelresolution='2' applyxcaladjustment='no' acceptchanrange='no' applyabsfluxcorr='no'
# rmfgen:- Executing (routine): rmfgen rmfset=./spectra/PN_gti_673309059.157_673309342.597.rmf threshold=1e-06 withenergybins=no energymin=0 energymax=15 nenergybins=30 spectrumset=./spectra/spectrum_gti_673309059.157_673309342.597.fits format=var detmaptype=psf detmaparray=detmapfile.ds: withdetbounds=no detxoffset=1200 detyoffset=1200 detxbins=160 detybins=160 withdetbins=yes raweventfile=rawevents.ds correctforpileup=no filterdss=yes withfilteredset=no filteredset=filteredpixellist.ds withrmfset=no psfenergy=2 withsourcepos=no sourcecoords=eqpos sourcex=0 sourcey=0 extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=no modelee=yes modelootcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no psfmodel=notSpecified badpixelresolution=2 withbadpixres=no applyxcaladjustment=no acceptchanrange=no applyabsfluxcorr=no  -w 1 -V 4
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:38:06.000
# Set to: notSpecified
# rmfgen:- Opening spectrumset ./spectra/spectrum_gti_673309059.157_673309342.597.fits...
# rmfgen:- Closing spectrumset ./spectra/spectrum_gti_673309059.157_673309342.597.fits.
# rmfgen:- Computing source position from region extent..
# rmfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# rmfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# rmfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# rmfgen:- detector map binning will be: xbins: 160 ybins: 160
# rmfgen:- Constructing a psf detector map with  xmin=-8545 xmax=8635 xbins=160 ymin=-1065 ymax=15454 ybins=160
# rmfgen:- PSF type: 5 [HIGH] will be used
# rmfgen:-  Creating RmfDataServer...
# rmfgen:-  EventGrades:4 FastTiming 37
# rmfgen:-  RmfDataServer created ok.
# rmfgen:- Opening data set ...
# rmfgen:- Opened data set.
# rmfgen:- Adding MATRIX table. There will be 2067 rows in table
# rmfgen:- Initialising table iterator ..
# rmfgen:- Populating table ..
# rmfgen:- Adding EBOUNDS extension ...
# rmfgen:-  Cleanup ...
# rmfgen:-  Closing data set ...
# rmfgen:-  Closed data set.
# rmfgen:-  Cleanup complete.
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:38:47.000
# Executing:
# arfgen spectrumset='./spectra/spectrum_gti_673309059.157_673309342.597.fits' withrmfset='yes' rmfset='./spectra/PN_gti_673309059.157_673309342.597.rmf' arfset='./spectra/PN_gti_673309059.157_673309342.597.arf' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='no' detxbins='5' detybins='5' psfenergy='2' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='yes' modelquantumeff='yes' modelfiltertrans='yes' modelcontamination='yes' modelee='yes' modelootcorr='yes' applyxcaladjustment='no' applyabsfluxcorr='yes' eegridfactor='100' withbadpixcorr='yes' badpixlocation='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' psfmodel='ELLBETA' withbadpixres='no' badpixelresolution='2' badpixmaptype='flat' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset=''
# arfgen:- Executing (routine): arfgen spectrumset=./spectra/spectrum_gti_673309059.157_673309342.597.fits rmfset=./spectra/PN_gti_673309059.157_673309342.597.rmf withrmfset=yes arfset=./spectra/PN_gti_673309059.157_673309342.597.arf detmaptype=psf detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=yes eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:38:47.000
# arfgen:- Opening spectrumset ./spectra/spectrum_gti_673309059.157_673309342.597.fits...
# arfgen:- Closing spectrumset ./spectra/spectrum_gti_673309059.157_673309342.597.fits.
# arfgen:- Computing source position from region extent..
# arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# arfgen:- detector map binning will be: xbins: 57 ybins: 55
# arfgen:- Constructing a psf detector map with  xmin=-8545 xmax=8635 xbins=57 ymin=-1065 ymax=15454 ybins=55
# arfgen:- PSF type: 3 [ELLBETA] will be used
# arfgen:- Opening arfset ./spectra/PN_gti_673309059.157_673309342.597.arf...
# Making file temp_badcol.ds
# arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# arfgen:- Writing energy data into dataset ..
# arfgen:- Calculating Area curve ...
# arfgen:- Calculating Area curve ...50.4999999 2067 15997.49947
# arfgen:- Bad pixel & chip gap fraction: ~0.4448886274 %
# arfgen:- Writing area data into dataset ..
# arfgen:- Closing arfset ./spectra/PN_gti_673309059.157_673309342.597.arf.
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:46:14.000
# Executing:
# specgroup spectrumset='./spectra/spectrum_gti_673309059.157_673309342.597.fits' overwrite='no' groupedset='./spectra/PN_spectrum_grp_gti_673309059.157_673309342.597.fits' withbgdset='no' backgndset='' withCounts='yes' mincounts='25' withminSN='no' minSN='5' withratioabovebgnd='no' ratioabovebgnd='' withoversampling='yes' oversample='3' withtemplate='no' grouptemplate='grptemplate.ds' withranges='no' ranges='' withRegularBins='no' regbinstart='' regbinend='' regbinwid='' units='CHAN' withrmfset='yes' rmfset='./spectra/PN_gti_673309059.157_673309342.597.rmf' witharfset='yes' arfset='./spectra/PN_gti_673309059.157_673309342.597.arf' addfilenames='yes' hightolow='no' lastbin='addtogroup' setbad='CCF'
# specgroup:- Executing (routine): specgroup spectrumset=./spectra/spectrum_gti_673309059.157_673309342.597.fits groupedset=./spectra/PN_spectrum_grp_gti_673309059.157_673309342.597.fits overwrite=no backgndset='' withbgdset=no mincounts=25 withCounts=yes minSN=5 withminSN=no ratioabovebgnd=0 withratioabovebgnd=no oversample=3 withoversampling=yes grouptemplate=grptemplate.ds withtemplate=no ranges='' withranges=no regbinstart=0 regbinend=0 regbinwid=0 withRegularBins=no units=CHAN rmfset=./spectra/PN_gti_673309059.157_673309342.597.rmf withrmfset=yes arfset=./spectra/PN_gti_673309059.157_673309342.597.arf witharfset=yes addfilenames=yes hightolow=no lastbin=addtogroup setbad=CCF  -w 1 -V 4
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:46:14.000
# specgroup:- Prepared spectrum ./spectra/PN_spectrum_grp_gti_673309059.157_673309342.597.fits with 162 groups
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:46:14.000
# Processing gti_673309342.597_673309626.037.fits...
# Warning: No need to include withspecranges. Assumed withspecranges=yes
# Executing:
# evselect table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44]) && (gti(./gti_files/gti_673309342.597_673309626.037.fits,TIME))' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='./spectra/spectrum_gti_673309342.597_673309626.037.fits' spectralbinsize='5' withspecranges='yes' specchannelmin='0' specchannelmax='20479' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44]) && (gti(./gti_files/gti_673309342.597_673309626.037.fits,TIME))' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=./spectra/spectrum_gti_673309342.597_673309626.037.fits spectralbinsize=5 specchannelmin=0 specchannelmax=20479 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:46:14.000
# evselect:- selected 17279 rows from the input table.
# ** evselect: warning (DifferentAttributeValues), Attribute `TIMESYS' has different value in `/tmp/fileIEmlxo:STDGTI04' (TDB) and `./gti_files/gti_673309342.597_673309626.037.fits:STDGTI' (TT) - please make sure it makes sense to merge the GTI tables
# ** evselect: warning (ExpBadDssGlobal), A filtering expression has been specified which may not allow for calculation of a uniform exposure for all events.  Please ensure that all TIME related filters are applied uniformly.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:46:19.000
# ** evselect: warning (SummaryOfWarnings),
#    warning DifferentAttributeValues silently occurred 3 times
# Executing:
# backscale spectrumset='./spectra/spectrum_gti_673309342.597_673309626.037.fits' badpixlocation='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=./spectra/spectrum_gti_673309342.597_673309626.037.fits badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:46:19.000
# backscale:- Executing (routine): arfgen spectrumset=./spectra/spectrum_gti_673309342.597_673309626.037.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:46:19.000
# backscale::arfgen:- Opening spectrumset ./spectra/spectrum_gti_673309342.597_673309626.037.fits...
# backscale::arfgen:- Closing spectrumset ./spectra/spectrum_gti_673309342.597_673309626.037.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# backscale::arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-8545 xmax=8635 xbins=1 ymin=-1065 ymax=15454 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# ** backscale::arfgen: warning (zeroSumDetmap), The filtered detector map has a zero normalisation - returning zero area. Try using a flat detector map and/or more bins
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0.1429431873 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset ./spectra/spectrum_gti_673309342.597_673309626.037.fits...
# backscale::arfgen:- Opened spectrumset ./spectra/spectrum_gti_673309342.597_673309626.037.fits...
# backscale::arfgen:- Opened table ./spectra/spectrum_gti_673309342.597_673309626.037.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att./spectra/spectrum_gti_673309342.597_673309626.037.fits...
# backscale::arfgen:- Backscale value is: 13407164
# backscale::arfgen:- added att./spectra/spectrum_gti_673309342.597_673309626.037.fits...
# backscale::arfgen:- closed spec./spectra/spectrum_gti_673309342.597_673309626.037.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:46:46.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:46:46.000
# Executing:
# rmfgen rmfset='./spectra/PN_gti_673309342.597_673309626.037.rmf' threshold='1e-06' withenergybins='no' energymin='0' energymax='15' nenergybins='30' spectrumset='./spectra/spectrum_gti_673309342.597_673309626.037.fits' format='var' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='yes' detxbins='160' detybins='160' correctforpileup='no' raweventfile='rawevents.ds' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withrmfset='no' psfenergy='2' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='no' modelquantumeff='no' modelfiltertrans='no' modelcontamination='no' modelee='yes' modelootcorr='no' eegridfactor='100' withbadpixcorr='no' badpixlocation='notSpecified' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset='' psfmodel='notSpecified' withbadpixres='no' badpixelresolution='2' applyxcaladjustment='no' acceptchanrange='no' applyabsfluxcorr='no'
# rmfgen:- Executing (routine): rmfgen rmfset=./spectra/PN_gti_673309342.597_673309626.037.rmf threshold=1e-06 withenergybins=no energymin=0 energymax=15 nenergybins=30 spectrumset=./spectra/spectrum_gti_673309342.597_673309626.037.fits format=var detmaptype=psf detmaparray=detmapfile.ds: withdetbounds=no detxoffset=1200 detyoffset=1200 detxbins=160 detybins=160 withdetbins=yes raweventfile=rawevents.ds correctforpileup=no filterdss=yes withfilteredset=no filteredset=filteredpixellist.ds withrmfset=no psfenergy=2 withsourcepos=no sourcecoords=eqpos sourcex=0 sourcey=0 extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=no modelee=yes modelootcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no psfmodel=notSpecified badpixelresolution=2 withbadpixres=no applyxcaladjustment=no acceptchanrange=no applyabsfluxcorr=no  -w 1 -V 4
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:46:46.000
# Set to: notSpecified
# rmfgen:- Opening spectrumset ./spectra/spectrum_gti_673309342.597_673309626.037.fits...
# rmfgen:- Closing spectrumset ./spectra/spectrum_gti_673309342.597_673309626.037.fits.
# rmfgen:- Computing source position from region extent..
# rmfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# rmfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# rmfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# rmfgen:- detector map binning will be: xbins: 160 ybins: 160
# rmfgen:- Constructing a psf detector map with  xmin=-8545 xmax=8635 xbins=160 ymin=-1065 ymax=15454 ybins=160
# rmfgen:- PSF type: 5 [HIGH] will be used
# rmfgen:-  Creating RmfDataServer...
# rmfgen:-  EventGrades:4 FastTiming 37
# rmfgen:-  RmfDataServer created ok.
# rmfgen:- Opening data set ...
# rmfgen:- Opened data set.
# rmfgen:- Adding MATRIX table. There will be 2067 rows in table
# rmfgen:- Initialising table iterator ..
# rmfgen:- Populating table ..
# rmfgen:- Adding EBOUNDS extension ...
# rmfgen:-  Cleanup ...
# rmfgen:-  Closing data set ...
# rmfgen:-  Closed data set.
# rmfgen:-  Cleanup complete.
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-15T18:47:28.000
# Executing:
# arfgen spectrumset='./spectra/spectrum_gti_673309342.597_673309626.037.fits' withrmfset='yes' rmfset='./spectra/PN_gti_673309342.597_673309626.037.rmf' arfset='./spectra/PN_gti_673309342.597_673309626.037.arf' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='no' detxbins='5' detybins='5' psfenergy='2' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='yes' modelquantumeff='yes' modelfiltertrans='yes' modelcontamination='yes' modelee='yes' modelootcorr='yes' applyxcaladjustment='no' applyabsfluxcorr='yes' eegridfactor='100' withbadpixcorr='yes' badpixlocation='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' psfmodel='ELLBETA' withbadpixres='no' badpixelresolution='2' badpixmaptype='flat' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset=''
# arfgen:- Executing (routine): arfgen spectrumset=./spectra/spectrum_gti_673309342.597_673309626.037.fits rmfset=./spectra/PN_gti_673309342.597_673309626.037.rmf withrmfset=yes arfset=./spectra/PN_gti_673309342.597_673309626.037.arf detmaptype=psf detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=yes eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-15T18:47:28.000
# arfgen:- Opening spectrumset ./spectra/spectrum_gti_673309342.597_673309626.037.fits...
# arfgen:- Closing spectrumset ./spectra/spectrum_gti_673309342.597_673309626.037.fits.
# arfgen:- Computing source position from region extent..
# arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# ...
# specgroup:- Executing (routine): specgroup spectrumset=./spectra/spectrum_gti_673342788.517_673343071.957.fits groupedset=./spectra/PN_spectrum_grp_gti_673342788.517_673343071.957.fits overwrite=no backgndset='' withbgdset=no mincounts=25 withCounts=yes minSN=5 withminSN=no ratioabovebgnd=0 withratioabovebgnd=no oversample=3 withoversampling=yes grouptemplate=grptemplate.ds withtemplate=no ranges='' withranges=no regbinstart=0 regbinend=0 regbinwid=0 withRegularBins=no units=CHAN rmfset=./spectra/PN_gti_673342788.517_673343071.957.rmf withrmfset=yes arfset=./spectra/PN_gti_673342788.517_673343071.957.arf witharfset=yes addfilenames=yes hightolow=no lastbin=addtogroup setbad=CCF  -w 1 -V 4
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-16T12:10:11.000
# specgroup:- Prepared spectrum ./spectra/PN_spectrum_grp_gti_673342788.517_673343071.957.fits with 146 groups
# specgroup:- specgroup (specgroup-1.7.1)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-16T12:10:11.000
# Processing gti_673343071.957_673343355.397.fits...
# Warning: No need to include withspecranges. Assumed withspecranges=yes
# Executing:
# evselect table='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' keepfilteroutput='no' withfilteredset='no' filteredset='filtered.fits' destruct='yes' flagcolumn='EVFLAG' flagbit='-1' filtertype='expression' dssblock='' expression='(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44]) && (gti(./gti_files/gti_673343071.957_673343355.397.fits,TIME))' writedss='yes' cleandss='no' updateexposure='yes' filterexposure='yes' blockstocopy='' attributestocopy='' energycolumn='PI' withzcolumn='no' zcolumn='WEIGHT' withzerrorcolumn='no' zerrorcolumn='EWEIGHT' ignorelegallimits='no' withimageset='no' imageset='image.fits' xcolumn='RAWX' ycolumn='RAWY' imagebinning='imageSize' ximagebinsize='1' yimagebinsize='1' squarepixels='no' ximagesize='600' yimagesize='600' withxranges='no' ximagemin='1' ximagemax='640' withyranges='no' yimagemin='1' yimagemax='640' withimagedatatype='no' imagedatatype='Real64' withcelestialcenter='no' raimagecenter='0' decimagecenter='0' withspectrumset='yes' spectrumset='./spectra/spectrum_gti_673343071.957_673343355.397.fits' spectralbinsize='5' withspecranges='yes' specchannelmin='0' specchannelmax='20479' nonStandardSpec='no' withrateset='no' rateset='rate.fits' timecolumn='TIME' timebinsize='1' withtimeranges='no' timemin='0' timemax='1000' maketimecolumn='no' makeratecolumn='no' withhistogramset='no' histogramset='histo.fits' histogramcolumn='TIME' histogrambinsize='1' withhistoranges='no' histogrammin='0' histogrammax='1000'
# evselect:- Executing (routine): evselect table=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits filteredset=filtered.fits withfilteredset=no keepfilteroutput=no flagcolumn=EVFLAG flagbit=-1 destruct=yes dssblock='' expression='(FLAG==0) && (PATTERN<=4) && (RAWX in [32:36] || RAWX in [40:44]) && (gti(./gti_files/gti_673343071.957_673343355.397.fits,TIME))' filtertype=expression cleandss=no updateexposure=yes filterexposure=yes writedss=yes blockstocopy='' attributestocopy='' energycolumn=PI zcolumn=WEIGHT zerrorcolumn=EWEIGHT withzerrorcolumn=no withzcolumn=no ignorelegallimits=no imageset=image.fits xcolumn=RAWX ycolumn=RAWY ximagebinsize=1 yimagebinsize=1 squarepixels=no ximagesize=600 yimagesize=600 imagebinning=imageSize ximagemin=1 ximagemax=640 withxranges=no yimagemin=1 yimagemax=640 withyranges=no imagedatatype=Real64 withimagedatatype=no raimagecenter=0 decimagecenter=0 withcelestialcenter=no withimageset=no spectrumset=./spectra/spectrum_gti_673343071.957_673343355.397.fits spectralbinsize=5 specchannelmin=0 specchannelmax=20479 withspecranges=yes nonStandardSpec=no withspectrumset=yes rateset=rate.fits timecolumn=TIME timebinsize=1 timemin=0 timemax=1000 withtimeranges=no maketimecolumn=no makeratecolumn=no withrateset=no histogramset=histo.fits histogramcolumn=TIME histogrambinsize=1 histogrammin=0 histogrammax=1000 withhistoranges=no withhistogramset=no  -w 1 -V 4
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-16T12:10:11.000
# evselect:- selected 12186 rows from the input table.
# ** evselect: warning (DifferentAttributeValues), Attribute `TIMESYS' has different value in `/tmp/fileGIqDYp:STDGTI04' (TDB) and `./gti_files/gti_673343071.957_673343355.397.fits:STDGTI' (TT) - please make sure it makes sense to merge the GTI tables
# ** evselect: warning (ExpBadDssGlobal), A filtering expression has been specified which may not allow for calculation of a uniform exposure for all events.  Please ensure that all TIME related filters are applied uniformly.
# evselect:- evselect (evselect-3.71.2)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-16T12:10:16.000
# ** evselect: warning (SummaryOfWarnings),
#    warning DifferentAttributeValues silently occurred 3 times
# Executing:
# backscale spectrumset='./spectra/spectrum_gti_673343071.957_673343355.397.fits' badpixlocation='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' withbadpixcorr='yes' useodfatt='no' ignoreoutoffov='yes' withbadpixres='no' badpixelresolution='2'
# backscale:- Executing (routine): backscale spectrumset=./spectra/spectrum_gti_673343071.957_673343355.397.fits badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits withbadpixcorr=yes useodfatt=no ignoreoutoffov=yes badpixelresolution=2 withbadpixres=no  -w 1 -V 4
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-16T12:10:16.000
# backscale:- Executing (routine): arfgen spectrumset=./spectra/spectrum_gti_673343071.957_673343355.397.fits rmfset=response.ds withrmfset=no arfset=deletearf.ds detmaptype=flat detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=1 detybins=1 withdetbins=yes psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=yes modelee=no modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=no eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=yes keeparfset=no useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-16T12:10:16.000
# backscale::arfgen:- Opening spectrumset ./spectra/spectrum_gti_673343071.957_673343355.397.fits...
# backscale::arfgen:- Closing spectrumset ./spectra/spectrum_gti_673343071.957_673343355.397.fits.
# backscale::arfgen:- Computing source position from region extent..
# backscale::arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# backscale::arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# backscale::arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# backscale::arfgen:- detector map binning will be: xbins: 1 ybins: 1
# backscale::arfgen:- Constructing a flat detector map with  xmin=-8545 xmax=8635 xbins=1 ymin=-1065 ymax=15454 ybins=1
# backscale::arfgen:- Opening arfset deletearf.ds...
# Making file temp_badcol.ds
# backscale::arfgen:- WCS info for the columns temp_badcol.ds:BADPIX04:RAWX and temp_badcol.ds:BADPIX04:RAWX is either non-existent or incomplete. Assuming a 1:1 mapping
# backscale::arfgen:- Writing energy data into dataset ..
# backscale::arfgen:- Calculating Area curve ...
# backscale::arfgen:- Calculating Area curve ...50.5 2067 15997.5
# ** backscale::arfgen: warning (zeroSumDetmap), The filtered detector map has a zero normalisation - returning zero area. Try using a flat detector map and/or more bins
# backscale::arfgen:- Bad pixel & chip gap fraction: ~0.1429431873 %
# backscale::arfgen:- Writing area data into dataset ..
# backscale::arfgen:- Closing arfset deletearf.ds.
# backscale::arfgen:- Opening spectrumset ./spectra/spectrum_gti_673343071.957_673343355.397.fits...
# backscale::arfgen:- Opened spectrumset ./spectra/spectrum_gti_673343071.957_673343355.397.fits...
# backscale::arfgen:- Opened table ./spectra/spectrum_gti_673343071.957_673343355.397.fits...
# backscale::arfgen:- current backscale value is: 1
# backscale::arfgen:- deleted att./spectra/spectrum_gti_673343071.957_673343355.397.fits...
# backscale::arfgen:- Backscale value is: 13407164
# backscale::arfgen:- added att./spectra/spectrum_gti_673343071.957_673343355.397.fits...
# backscale::arfgen:- closed spec./spectra/spectrum_gti_673343071.957_673343355.397.fits...
# backscale:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-16T12:10:48.000
# backscale:- backscale (backscale-1.6)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-16T12:10:48.000
# Executing:
# rmfgen rmfset='./spectra/PN_gti_673343071.957_673343355.397.rmf' threshold='1e-06' withenergybins='no' energymin='0' energymax='15' nenergybins='30' spectrumset='./spectra/spectrum_gti_673343071.957_673343355.397.fits' format='var' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='yes' detxbins='160' detybins='160' correctforpileup='no' raweventfile='rawevents.ds' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withrmfset='no' psfenergy='2' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='no' modelquantumeff='no' modelfiltertrans='no' modelcontamination='no' modelee='yes' modelootcorr='no' eegridfactor='100' withbadpixcorr='no' badpixlocation='notSpecified' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset='' psfmodel='notSpecified' withbadpixres='no' badpixelresolution='2' applyxcaladjustment='no' acceptchanrange='no' applyabsfluxcorr='no'
# rmfgen:- Executing (routine): rmfgen rmfset=./spectra/PN_gti_673343071.957_673343355.397.rmf threshold=1e-06 withenergybins=no energymin=0 energymax=15 nenergybins=30 spectrumset=./spectra/spectrum_gti_673343071.957_673343355.397.fits format=var detmaptype=psf detmaparray=detmapfile.ds: withdetbounds=no detxoffset=1200 detyoffset=1200 detxbins=160 detybins=160 withdetbins=yes raweventfile=rawevents.ds correctforpileup=no filterdss=yes withfilteredset=no filteredset=filteredpixellist.ds withrmfset=no psfenergy=2 withsourcepos=no sourcecoords=eqpos sourcex=0 sourcey=0 extendedsource=no modeleffarea=no modelquantumeff=no modelfiltertrans=no modelcontamination=no modelee=yes modelootcorr=no eegridfactor=100 withbadpixcorr=no badpixlocation=notSpecified setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no psfmodel=notSpecified badpixelresolution=2 withbadpixres=no applyxcaladjustment=no acceptchanrange=no applyabsfluxcorr=no  -w 1 -V 4
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-16T12:10:48.000
# Set to: notSpecified
# rmfgen:- Opening spectrumset ./spectra/spectrum_gti_673343071.957_673343355.397.fits...
# rmfgen:- Closing spectrumset ./spectra/spectrum_gti_673343071.957_673343355.397.fits.
# rmfgen:- Computing source position from region extent..
# rmfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# rmfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# rmfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# rmfgen:- detector map binning will be: xbins: 160 ybins: 160
# rmfgen:- Constructing a psf detector map with  xmin=-8545 xmax=8635 xbins=160 ymin=-1065 ymax=15454 ybins=160
# rmfgen:- PSF type: 5 [HIGH] will be used
# rmfgen:-  Creating RmfDataServer...
# rmfgen:-  EventGrades:4 FastTiming 37
# rmfgen:-  RmfDataServer created ok.
# rmfgen:- Opening data set ...
# rmfgen:- Opened data set.
# rmfgen:- Adding MATRIX table. There will be 2067 rows in table
# rmfgen:- Initialising table iterator ..
# rmfgen:- Populating table ..
# rmfgen:- Adding EBOUNDS extension ...
# rmfgen:-  Cleanup ...
# rmfgen:-  Closing data set ...
# rmfgen:-  Closed data set.
# rmfgen:-  Cleanup complete.
# rmfgen:- rmfgen (rmfgen-2.8.7)  [xmmsas_20230412_1735-21.0.0] ended:    2025-01-16T12:11:30.000
# Executing:
# arfgen spectrumset='./spectra/spectrum_gti_673343071.957_673343355.397.fits' withrmfset='yes' rmfset='./spectra/PN_gti_673343071.957_673343355.397.rmf' arfset='./spectra/PN_gti_673343071.957_673343355.397.arf' detmaptype='psf' detmaparray='detmapfile.ds:' withdetbounds='no' detxoffset='1200' detyoffset='1200' withdetbins='no' detxbins='5' detybins='5' psfenergy='2' filterdss='yes' withfilteredset='no' filteredset='filteredpixellist.ds' withsourcepos='no' sourcecoords='eqpos' sourcex='0' sourcey='0' extendedsource='no' modeleffarea='yes' modelquantumeff='yes' modelfiltertrans='yes' modelcontamination='yes' modelee='yes' modelootcorr='yes' applyxcaladjustment='no' applyabsfluxcorr='yes' eegridfactor='100' withbadpixcorr='yes' badpixlocation='/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits' psfmodel='ELLBETA' withbadpixres='no' badpixelresolution='2' badpixmaptype='flat' setbackscale='no' keeparfset='yes' useodfatt='no' ignoreoutoffov='yes' crossregionarf='no' crossreg_spectrumset=''
# arfgen:- Executing (routine): arfgen spectrumset=./spectra/spectrum_gti_673343071.957_673343355.397.fits rmfset=./spectra/PN_gti_673343071.957_673343355.397.rmf withrmfset=yes arfset=./spectra/PN_gti_673343071.957_673343355.397.arf detmaptype=psf detmaparray=detmapfile.ds: detxoffset=1200 detyoffset=1200 withdetbounds=no detxbins=5 detybins=5 withdetbins=no psfenergy=2 filterdss=yes filteredset=filteredpixellist.ds withfilteredset=no sourcecoords=eqpos sourcex=0 sourcey=0 withsourcepos=no extendedsource=no modeleffarea=yes modelquantumeff=yes modelfiltertrans=yes modelcontamination=yes modelee=yes modelootcorr=yes applyxcaladjustment=no applyabsfluxcorr=yes eegridfactor=100 withbadpixcorr=yes badpixlocation=/media/user/Vela-work/XMM-SAS-Datalabs-Paper/VelaX1data07Jan/PN_clean_evt.fits psfmodel=ELLBETA badpixelresolution=2 withbadpixres=no badpixmaptype=flat setbackscale=no keeparfset=yes useodfatt=no ignoreoutoffov=yes crossreg_spectrumset='' crossregionarf=no  -w 1 -V 4
# arfgen:- arfgen (arfgen-1.104)  [xmmsas_20230412_1735-21.0.0] started:  2025-01-16T12:11:30.000
# arfgen:- Opening spectrumset ./spectra/spectrum_gti_673343071.957_673343355.397.fits...
# arfgen:- Closing spectrumset ./spectra/spectrum_gti_673343071.957_673343355.397.fits.
# arfgen:- Computing source position from region extent..
# arfgen:- Using a source position in DET coordinates of x=45 y=-195.132
# arfgen:-  The source position in focal plane coords is  theta=68.3374 phi=3.57818
# arfgen:- Computing detector map bounds from the region selection information stored in the spectrum ...
# arfgen:- detector map binning will be: xbins: 57 ybins: 55
# arfgen:- Constructing a psf detector map with  xmin=-8545 xmax=8635 xbins=57 ymin=-1065 ymax=15454 ybins=55
# arfgen:- PSF type: 3 [ELLBETA] will be used
# arfgen:- Opening arfset ./spectra/PN_gti_673343071.957_673343355.397.arf...

# %% [markdown]
# After this point it is up to the user to do further spectral analysis.

# %% [markdown]
# ***
# ### Conclusions
#
# Congrats!✨
#
# By following this thread you have:
#
# * processed ODF files for the X-ray binary Vela X-1.
# * applied calibration in timing mode.
# * produced lightcurves of the source and the background.
# * checked and corrected for plie-up.
# * produced an average spectrum of the object and plotted it using pyXspec.
# * produced for different observation phases
# * produced a spectrum for each pulse period of the binary
#
# This shows how a further analysis can be done on an object observed by XMM-Newton in the XMM-Newton-SAS Datalab, where you can swiftly get your data and analyse it with all the major tools necessary available at your disposal. The further analysis and model fitting of the object can be advanced by the reader, by exploring the tools at disposal by pyXspec, for more information please refer to the [pyXspec information page](https://heasarc.gsfc.nasa.gov/xanadu/xspec/python/html/index.html).
